# %%
import pandas as pd
from math import log2
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statistics
import altair as alt



max_number_of_observable_metrics=5

#hz is the number
def equation_for_midi_number(hz):
    return 12*log2(hz/440) +69
    


# N is themidi number

def equation_for_hertz(n):
    return 440* 2**((n-69)/12)

def equation_for_harmonics(number_of_harmonics, midi_number):
    all_harmonics = []
    hertz = equation_for_hertz(midi_number)
    for i in range(number_of_harmonics):
        
        all_harmonics.append((i+1)*hertz)
    
    return all_harmonics
        

note_df = pd.DataFrame()


piano_range = range(21, 109)
piano_notes = ['A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#']
piano_octave = [str(i) for i in range(0, 9)]

##populating dataframe columns
piano_note_index = 0
piano_octave_index = 0
for midi_number in piano_range:
    if piano_note_index %12 == 3:
        piano_octave_index += 1

    note_name = piano_notes[piano_note_index % 12] + piano_octave[piano_octave_index]
    note_df[note_name]= equation_for_harmonics(10,midi_number)
    
    piano_note_index += 1


note_df
# Out:
#       A0         A#0          B0          C1         C#1          D1  \
# 0   27.5   29.135235   30.867706   32.703196   34.647829   36.708096
# 1   55.0   58.270470   61.735413   65.406391   69.295658   73.416192
# 2   82.5   87.405705   92.603119   98.109587  103.943487  110.124288
# 3  110.0  116.540940  123.470825  130.812783  138.591315  146.832384
# 4  137.5  145.676175  154.338532  163.515978  173.239144  183.540480
# 5  165.0  174.811411  185.206238  196.219174  207.886973  220.248576
# 6  192.5  203.946646  216.073944  228.922370  242.534802  256.956672
# 7  220.0  233.081881  246.941651  261.625565  277.182631  293.664768
# 8  247.5  262.217116  277.809357  294.328761  311.830460  330.372864
# 9  275.0  291.352351  308.677063  327.031957  346.478289  367.080960
#
#           D#1          E1          F1         F#1  ...           D#7  \
# 0   38.890873   41.203445   43.653529   46.249303  ...   2489.015870
# 1   77.781746   82.406889   87.307058   92.498606  ...   4978.031740
# 2  116.672619  123.610334  130.960587  138.747909  ...   7467.047609
# 3  155.563492  164.813778  174.614116  184.997211  ...   9956.063479
# 4  194.454365  206.017223  218.267645  231.246514  ...  12445.079349
# 5  233.345238  247.220668  261.921174  277.495817  ...  14934.095219
# 6  272.236111  288.424112  305.574703  323.745120  ...  17423.111088
# 7  311.126984  329.627557  349.228231  369.994423  ...  19912.126958
# 8  350.017857  370.831002  392.881760  416.243726  ...  22401.142828
# 9  388.908730  412.034446  436.535289  462.493028  ...  24890.158698
#
#              E7            F7           F#7            G7           G#7  \
# 0   2637.020455   2793.825851   2959.955382   3135.963488   3322.437581
# 1   5274.040911   5587.651703   5919.910763   6271.926976   6644.875161
# 2   7911.061366   8381.477554   8879.866145   9407.890464   9967.312742
# 3  10548.081821  11175.303406  11839.821527  12543.853951  13289.750323
# 4  13185.102277  13969.129257  14799.776908  15679.817439  16612.187903
# 5  15822.122732  16762.955109  17759.732290  18815.780927  19934.625484
# 6  18459.143187  19556.780960  20719.687672  21951.744415  23257.063064
# 7  21096.163642  22350.606812  23679.643054  25087.707903  26579.500645
# 8  23733.184098  25144.432663  26639.598435  28223.671391  29901.938226
# 9  26370.204553  27938.258515  29599.553817  31359.634879  33224.375806
#
#         A7           A#7           B7            C8
# 0   3520.0   3729.310092   3951.06641   4186.009045
# 1   7040.0   7458.620184   7902.13282   8372.018090
# 2  10560.0  11187.930276  11853.19923  12558.027134
# 3  14080.0  14917.240369  15804.26564  16744.036179
# 4  17600.0  18646.550461  19755.33205  20930.045224
# 5  21120.0  22375.860553  23706.39846  25116.054269
# 6  24640.0  26105.170645  27657.46487  29302.063314
# 7  28160.0  29834.480737  31608.53128  33488.072358
# 8  31680.0  33563.790829  35559.59769  37674.081403
# 9  35200.0  37293.100921  39510.66410  41860.090448
#
# [10 rows x 88 columns]

# %%
# Assuming df is your dataframe
fundamental_df = note_df.drop(note_df.index[1:10])
fundamental_df.reset_index(drop=True, inplace=True)
fundamental_df
# Out:
#      A0        A#0         B0         C1        C#1         D1        D#1  \
# 0  27.5  29.135235  30.867706  32.703196  34.647829  36.708096  38.890873
#
#           E1         F1        F#1  ...         D#7           E7           F7  \
# 0  41.203445  43.653529  46.249303  ...  2489.01587  2637.020455  2793.825851
#
#            F#7           G7          G#7      A7          A#7          B7  \
# 0  2959.955382  3135.963488  3322.437581  3520.0  3729.310092  3951.06641
#
#             C8
# 0  4186.009045
#
# [1 rows x 88 columns]

# %%
def calculate_period_dataframe(note_names:list,note_df ,max=13):
    df = pd.DataFrame()
    for note_name in note_names:
        df[note_name]= 1/note_df[note_name][0]

    ## calculating period
    for i in range(1,max):
        list_of_periods = []
        for note_name in note_names:
            list_of_periods.append((1/(note_df[note_name][0]))*i)

        df.loc[i] = list_of_periods
    # note_period_c3 = (1/note_c3[0]) * (i)
    # note_period_e3 = (1/note_e3[0]) * (i)
    # note_period_g3 = (1/note_g3[0]) * (i)
    # note_period_c4 = (1/note_c4[0]) * (i)
    # dataframe_demos.loc[i] = [note_period_c3, note_period_e3, note_period_g3, note_period_c4]


    
    return df

note_names = ['C3', 'D#3', 'G3', 'A#3']
period_df = calculate_period_dataframe(note_names, fundamental_df)  
period_df
# Out:
#           C3       D#3        G3       A#3
# 1   0.007645  0.006428  0.005102  0.004290
# 2   0.015289  0.012856  0.010204  0.008581
# 3   0.022934  0.019285  0.015306  0.012871
# 4   0.030578  0.025713  0.020408  0.017161
# 5   0.038223  0.032141  0.025511  0.021452
# 6   0.045867  0.038569  0.030613  0.025742
# 7   0.053512  0.044998  0.035715  0.030032
# 8   0.061156  0.051426  0.040817  0.034323
# 9   0.068801  0.057854  0.045919  0.038613
# 10  0.076445  0.064282  0.051021  0.042903
# 11  0.084090  0.070711  0.056123  0.047194
# 12  0.091734  0.077139  0.061225  0.051484

# %% [markdown]
# ### Ahora, intentaremos hacer algo loco, encontrar las cotas menores y mayores
# Algoritmo es T(n)=2n

# %%
def finding_min_difference_with_lower_upper_bound(period_df):
    '''
    This function will assume that the first and last note are the lower and upper bounds
    Since bass is the first note, and it oscillates less, than the last note

    Algorithm goes as follows:
    loop until last note max index is reached

    then, for each note, we will take the difference between the last note and the bass note
    and divide by the mean of the two notes. We will store, the keys, the division and 
    then sort by division results. 

    each time the difference of last-bass is positive we will increment the bass,
    then when the difference is negative, we will increment the last note
    '''
    notes = period_df.columns
    range_to_consider = len(period_df[notes[0]].values)

    ## bass
    bass =  period_df[notes[0]].values

    last_note = period_df[notes[-1]].values

    ## algorithm
    i, j = 0,0

    ## array to store all dicts info
    ratio_dicts = []

    while i < range_to_consider and j < range_to_consider:
        bass_note = bass[i]
        last_note_value = last_note[j]

        difference = last_note_value - bass_note
        mean = (last_note_value + bass_note) / 2
        ratio = abs(difference/mean)
        ratio_dicts.append({
            'bass': i,
            'last_note': j,
            'difference': difference,
            'mean': mean,
            'ratio': ratio,
            'bass_value':bass_note,
            'last_note_value':last_note_value
        })

        if difference > 0:
            i += 1
        else:
            j += 1
        
    return pd.DataFrame(sorted(ratio_dicts, key=lambda x: x['ratio'] ))

# %%
notes =['C3','A#3']
period_df = calculate_period_dataframe(notes, fundamental_df, max=16)
bound_df = finding_min_difference_with_lower_upper_bound(period_df)
bound_df
# Out:
#     bass  last_note  difference      mean     ratio  bass_value  \
# 0      4          8    0.000390  0.038418  0.010164    0.038223
# 1      3          6   -0.000546  0.030305  0.018006    0.030578
# 2      7         13   -0.001091  0.060610  0.018006    0.061156
# 3      5         10    0.001327  0.046530  0.028511    0.045867
# 4      6         11   -0.002028  0.052498  0.038621    0.053512
# 5      6         12    0.002263  0.054643  0.041411    0.053512
# 6      7         14    0.003199  0.062756  0.050975    0.061156
# 7      2          4   -0.001482  0.022193  0.066772    0.022934
# 8      5          9   -0.002964  0.044385  0.066772    0.045867
# 9      8         14   -0.004446  0.066578  0.066772    0.068801
# 10     7         12   -0.005382  0.058465  0.092050    0.061156
# 11     4          7   -0.003900  0.036273  0.107515    0.038223
# 12     2          5    0.002808  0.024338  0.115396    0.022934
# 13     0          1    0.000936  0.008113  0.115396    0.007645
# 14     1          3    0.001872  0.016225  0.115396    0.015289
# 15     3          7    0.003745  0.032450  0.115396    0.030578
# 16     6         10   -0.006318  0.050353  0.125473    0.053512
# 17     1          2   -0.002418  0.014080  0.171734    0.015289
# 18     3          5   -0.004836  0.028160  0.171734    0.030578
# 19     5          8   -0.007254  0.042240  0.171734    0.045867
# 20     2          3   -0.005772  0.020047  0.287926    0.022934
# 21     0          0   -0.003354  0.005967  0.562081    0.007645
# 22     1          1   -0.006708  0.011935  0.562081    0.015289
#
#     last_note_value
# 0          0.038613
# 1          0.030032
# 2          0.060065
# 3          0.047194
# 4          0.051484
# 5          0.055774
# 6          0.064355
# 7          0.021452
# 8          0.042903
# 9          0.064355
# 10         0.055774
# 11         0.034323
# 12         0.025742
# 13         0.008581
# 14         0.017161
# 15         0.034323
# 16         0.047194
# 17         0.012871
# 18         0.025742
# 19         0.038613
# 20         0.017161
# 21         0.004290
# 22         0.008581

# %% [markdown]
# ### ahora, si cojo cada uno de esos elementos de upper y lower, se reducirá la búsqueda a n^2logn?
#  mira, por cada uno de estos pares
# 1. go through every array, and perform binary search...

# %%
def binary_search_with_bounds(period_df,lower_bound,upper_bound,mean_bound):
    

    """
    this binary search goes as follows:
    1. We first take a pivot, which is between lower and upper bound,
    2. we then substract period against mean. 
    3. we compare if that is the lowest, if it is, take pivot as candidate
    4. if positive, we go to right leaf, if negative we go to left
    5. at the end return candidate for each 
    """

    notes = period_df.columns
    ## only take medium ones
    notes = notes[ 1 : -1]

    chosen_winners = []
    all_found = []
    for note in notes:

        ### here we begin binary loop

        low = lower_bound
        upper = upper_bound
        
        candidate_index = 0
        candidate_difference = 1000
        candidate_value = 10000
        # updated= True
        note_values = period_df[note].values
        # print(note_values)


        complete_note_differences = []

        while low<=upper:
            # updated = False

            middle = (low + upper) // 2

            difference = mean_bound - note_values[middle]


            if(candidate_difference>abs(difference)):
                candidate_difference =  abs(difference)
                candidate_index = middle
                candidate_value = note_values[middle]
            complete_note_differences.append({
                'index':middle,
                'value': note_values[middle],
                'abs_difference': abs(difference),
                'difference':difference
            })
            ## update middle
            if difference >0:
                low=middle+1
            else:
                upper = middle-1

        #### now we store the necessary information, the chosen one and everything
        all_found.append(
            {'note': note,
             'values':complete_note_differences}
        )
        chosen_winners.append(
            {'note': note,
             'candidate_index': candidate_index,
             'candidate_difference':candidate_difference,
             'candidate_value': candidate_value}
        )
    return all_found,chosen_winners

            
            
        

def choosing_bounds_binary_search(period_df, bounds_df):
    
    # notes in period_df to get bass and last
    notes = period_df.columns
    # bass =  bounds_df[notes[0]].values
    # last_note =  bounds_df[notes[-1]].values
    each_pair_values = []
    for i,row in bound_df.iterrows():
        bass_value = int(row['bass'])
        last_note_value = int(row['last_note'])
        mean_bound = row['mean']
        all_found, chosen_winners = binary_search_with_bounds(period_df,bass_value,last_note_value, mean_bound)
        

        ### interestingly enough, could i then here, normalize, and standard deviation?
        values=[row['bass_value']]
         ## indeces
        indices_to_observe=[row['bass']]
        for d in chosen_winners:
            values.append(d['candidate_value'])
            indices_to_observe.append(d['candidate_index'])
        indices_to_observe.append(row['last_note'])
        values.append(row['last_note_value'])


       


        ## normalizing, and calculating standard deviation and mean
        

        minimum = min(values)
        maximum = max(values)
        mean_vals = sum(values)/len(values)

        ##normalizing
        norm_vals = []
        for v in values:
            normed = (v-minimum)/(maximum-minimum)
            norm_vals.append(normed)
        std_= statistics.stdev(norm_vals)

        observable_metrics = {
            't_values':values,
            'mean_t_sub': mean_vals,
            'std_normed':std_,
            'indices':indices_to_observe,
            'difference':maximum-minimum,
            'difference_ratio': (maximum-minimum)/mean_vals,
        }

        




        each_pair_values.append({
            "all_found":all_found,
            'chosen_winners':chosen_winners,
            'observable_metrics':observable_metrics
            
        }
        )
        
    return each_pair_values

# %%
each_pair = choosing_bounds_binary_search(period_df,bound_df)
for bp_i, bp_v in bound_df.iterrows():
    print(f'bound_pair #{bp_i} with vals bass={bp_v["bass"]} and last_note{bp_v["last_note"]}')
    print('all_found',each_pair[bp_i]['all_found'])
    print('winner',each_pair[bp_i]['chosen_winners'])
# Out:
# bound_pair #0 with vals bass=4.0 and last_note8.0
# all_found []
# winner []
# bound_pair #1 with vals bass=3.0 and last_note6.0
# all_found []
# winner []
# bound_pair #2 with vals bass=7.0 and last_note13.0
# all_found []
# winner []
# bound_pair #3 with vals bass=5.0 and last_note10.0
# all_found []
# winner []
# bound_pair #4 with vals bass=6.0 and last_note11.0
# all_found []
# winner []
# bound_pair #5 with vals bass=6.0 and last_note12.0
# all_found []
# winner []
# bound_pair #6 with vals bass=7.0 and last_note14.0
# all_found []
# winner []
# bound_pair #7 with vals bass=2.0 and last_note4.0
# all_found []
# winner []
# bound_pair #8 with vals bass=5.0 and last_note9.0
# all_found []
# winner []
# bound_pair #9 with vals bass=8.0 and last_note14.0
# all_found []
# winner []
# bound_pair #10 with vals bass=7.0 and last_note12.0
# all_found []
# winner []
# bound_pair #11 with vals bass=4.0 and last_note7.0
# all_found []
# winner []
# bound_pair #12 with vals bass=2.0 and last_note5.0
# all_found []
# winner []
# bound_pair #13 with vals bass=0.0 and last_note1.0
# all_found []
# winner []
# bound_pair #14 with vals bass=1.0 and last_note3.0
# all_found []
# winner []
# bound_pair #15 with vals bass=3.0 and last_note7.0
# all_found []
# winner []
# bound_pair #16 with vals bass=6.0 and last_note10.0
# all_found []
# winner []
# bound_pair #17 with vals bass=1.0 and last_note2.0
# all_found []
# winner []
# bound_pair #18 with vals bass=3.0 and last_note5.0
# all_found []
# winner []
# bound_pair #19 with vals bass=5.0 and last_note8.0
# all_found []
# winner []
# bound_pair #20 with vals bass=2.0 and last_note3.0
# all_found []
# winner []
# bound_pair #21 with vals bass=0.0 and last_note0.0
# all_found []
# winner []
# bound_pair #22 with vals bass=1.0 and last_note1.0
# all_found []
# winner []

# %% [markdown]
# ## recap.
# - Un algoritmo que comienza por definir upper, lowerbounds, es t(n)=2n
# - se sortean estos pares usando delta_t/meanT
# - luego por cada par que encontró (n pares) ve por cada nota (n) y haz binary_search(logn) donde la diferencia de ese indice y la media de upper y lower sea la más pequeña
# - Cuando finalice y encuentre todos los candidatos de cada par, entonces, min difference de min max
#
#
# voy a ver que da

# %%
# note_names = ['D3','A3','D4','A4','D5','F#5']
##minor C 7
note_names = ['C3','D#3','G3','A#3']


##major triad
# note_names = ['C3','E3','G3']
# # minor triad
# note_names = ['C3','D#3','G3']
## major 7
# note_names = ['C#3','D3', 'F#3', 'A3']
# D major scale
# note_names = ['D3','E3', 'F#3','G3' ,'A3', 'B3','C#4','D4']	
# note_names =['D3','F3','A3']
# note_names = ['A2','E3', 'A3', 'A4', 'C#5', 'E5']
# note_names = ['B2', 'F#3', 'B3', 'F#4','B4','D5']

period_df = calculate_period_dataframe(note_names,fundamental_df,max=20)
period_df
# Out:
#           C3       D#3        G3       A#3
# 1   0.007645  0.006428  0.005102  0.004290
# 2   0.015289  0.012856  0.010204  0.008581
# 3   0.022934  0.019285  0.015306  0.012871
# 4   0.030578  0.025713  0.020408  0.017161
# 5   0.038223  0.032141  0.025511  0.021452
# 6   0.045867  0.038569  0.030613  0.025742
# 7   0.053512  0.044998  0.035715  0.030032
## we will see if our method seems ok????
observable_metrics=[]
for item in each_pair:
    observable_metrics.append(item['observable_metrics'])
sorted(observable_metrics, key=lambda x: x['difference'])
# Out:
# [{'t_values': [0.0764451286594286,
#    0.077138921583987,
#    0.0765315032938209,
#    0.0772260801285022],
#   'mean_t_sub': 0.07683540841643467,
#   'std_normed': 0.5171978772513034,
#   'indices': [9.0, 11, 14, 17.0],
#   'difference': 0.0007809514690736014,
#   'difference_ratio': 0.010163952859350718},
#  {'t_values': [0.03057805146377144,
#    0.03214121732666125,
#    0.030612601317528357,
#    0.03003236449441752],
#   'mean_t_sub': 0.030841058650594638,
#   'std_normed': 0.42990142473837273,
#   'indices': [3.0, 4, 5, 6.0],
#   'difference': 0.0021088528322437336,
#   'difference_ratio': 0.0683780948032753},
#  {'t_values': [0.04586707719565716,
#    0.04499770425732575,
#    0.04591890197629254,
#    0.04719371563408468],
#   'mean_t_sub': 0.04599434976584003,
#   'std_normed': 0.4118252683853573,
#   'indices': [5.0, 6, 8, 10.0],
#   'difference': 0.0021960113767589273,
#   'difference_ratio': 0.04774524235996273},
#  {'t_values': [0.01528902573188572,
#    0.0128564869306645,
#    0.015306300658764179,
#    0.012871013354750365],
#   'mean_t_sub': 0.014080706669016192,
#   'std_normed': 0.5736152715746295,
#   'indices': [1.0, 1, 2, 2.0],
#   'difference': 0.002449813728099678,
#   'difference_ratio': 0.17398372011330626},
#  {'t_values': [0.05351159006160002,
#    0.051425947722658,
#    0.0510210021958806,
#    0.05148405341900146],
#   'mean_t_sub': 0.051860648349785016,
#   'std_normed': 0.4495856218363726,
#   'indices': [6.0, 7, 9, 11.0],
#   'difference': 0.002490587865719422,
#   'difference_ratio': 0.048024618761437966},
#  {'t_values': [0.08408964152537146,
#    0.08356716504931926,
#    0.08163360351340895,
#    0.08151641791341899],
#   'mean_t_sub': 0.08270170700037967,
#   'std_normed': 0.51267756476065,
#   'indices': [10.0, 12, 15, 18.0],
#   'difference': 0.0025732236119524743,
#   'difference_ratio': 0.03111451631754906},
#  {'t_values': [0.0382225643297143,
#    0.0385694607919935,
#    0.04081680175670448,
#    0.0386130400642511],
#   'mean_t_sub': 0.039055466735665845,
#   'std_normed': 0.45761013231820086,
#   'indices': [4.0, 5, 7, 8.0],
#   'difference': 0.0025942374269901786,
#   'difference_ratio': 0.06642443795508644},
#  {'t_values': [0.02293353859782858,
#    0.025712973861329,
#    0.0255105010979403,
#    0.02574202670950073],
#   'mean_t_sub': 0.024974760066649657,
#   'std_normed': 0.4859216753517771,
#   'indices': [2.0, 3, 4, 5.0],
#   'difference': 0.0028084881116721486,
#   'difference_ratio': 0.11245305677320587},
#  {'t_values': [0.04586707719565716,
#    0.04499770425732575,
#    0.04591890197629254,
#    0.04290337784916789],
#   'mean_t_sub': 0.04492176531961083,
#   'std_normed': 0.4677078141567277,
#   'indices': [5.0, 6, 8, 9.0],
#   'difference': 0.0030155241271246497,
#   'difference_ratio': 0.06712835316398856},
#  {'t_values': [0.06115610292754288,
#    0.0642824346533225,
#    0.061225202635056715,
#    0.06435506677375183],
#   'mean_t_sub': 0.06275470174741848,
#   'std_normed': 0.5647053075401802,
#   'indices': [7.0, 9, 11, 14.0],
#   'difference': 0.0031989638462089492,
#   'difference_ratio': 0.050975684006665585},
#  {'t_values': [0.00764451286594286,
#    0.00642824346533225,
#    0.00510210021958806,
#    0.004290337784916789],
#   'mean_t_sub': 0.00586629858394499,
#   'std_normed': 0.4403767514006966,
#   'indices': [0.0, 0, 0, 0.0],
#   'difference': 0.0033541750810260713,
#   'difference_ratio': 0.5717702624625771},
#  {'t_values': [0.06115610292754288,
#    0.057854191187990255,
#    0.061225202635056715,
#    0.06006472898883504],
#   'mean_t_sub': 0.06007505643485622,
#   'std_normed': 0.466652555972158,
#   'indices': [7.0, 8, 11, 13.0],
#   'difference': 0.0033710114470664604,
#   'difference_ratio': 0.056113329676550444},
#  {'t_values': [0.02293353859782858,
#    0.01928473039599675,
#    0.02040840087835224,
#    0.021451688924583944],
#   'mean_t_sub': 0.02101958969919038,
#   'std_normed': 0.4255528810505849,
#   'indices': [2.0, 2, 3, 4.0],
#   'difference': 0.0036488082018318324,
#   'difference_ratio': 0.17359083854868845},
#  {'t_values': [0.03057805146377144,
#    0.03214121732666125,
#    0.030612601317528357,
#    0.03432270227933431],
#   'mean_t_sub': 0.03191364309682384,
#   'std_normed': 0.470990781665877,
#   'indices': [3.0, 4, 5, 7.0],
#   'difference': 0.0037446508155628694,
#   'difference_ratio': 0.11733698983227492},
#  {'t_values': [0.00764451286594286,
#    0.00642824346533225,
#    0.01020420043917612,
#    0.008580675569833577],
#   'mean_t_sub': 0.008214408085071201,
#   'std_normed': 0.4217590684854799,
#   'indices': [0.0, 0, 1, 1.0],
#   'difference': 0.003775956973843869,
#   'difference_ratio': 0.45967487063447243},
#  {'t_values': [0.01528902573188572,
#    0.01928473039599675,
#    0.015306300658764179,
#    0.017161351139667155],
#   'mean_t_sub': 0.01676035198157845,
#   'std_normed': 0.4751230473850039,
#   'indices': [1.0, 2, 2, 3.0],
#   'difference': 0.003995704664111029,
#   'difference_ratio': 0.23840219277630728},
#  {'t_values': [0.06880061579348574,
#    0.07071067811865475,
#    0.07142940307423283,
#    0.07293574234358541],
#   'mean_t_sub': 0.07096910983248969,
#   'std_normed': 0.41532634942451946,
#   'indices': [8.0, 10, 13, 16.0],
#   'difference': 0.004135126550099663,
#   'difference_ratio': 0.05826656921384408},
#  {'t_values': [0.0764451286594286,
#    0.077138921583987,
#    0.0765315032938209,
#    0.07293574234358541],
#   'mean_t_sub': 0.07576282397020548,
#   'std_normed': 0.45437936877397106,
#   'indices': [9.0, 11, 14, 16.0],
#   'difference': 0.004203179240401589,
#   'difference_ratio': 0.055478122648312755},
#  {'t_values': [0.0382225643297143,
#    0.0385694607919935,
#    0.035714701537116415,
#    0.03432270227933431],
#   'mean_t_sub': 0.036707357234539634,
#   'std_normed': 0.4794117364034809,
#   'indices': [4.0, 5, 6, 7.0],
#   'difference': 0.004246758512659189,
#   'difference_ratio': 0.11569229801875303},
#  {'t_values': [0.05351159006160002,
#    0.057854191187990255,
#    0.056123102415468654,
#    0.05577439120391825],
#   'mean_t_sub': 0.055815818717244295,
#   'std_normed': 0.41108474396252837,
#   'indices': [6.0, 8, 10, 12.0],
#   'difference': 0.004342601126390233,
#   'difference_ratio': 0.07780233679612025},
#  {'t_values': [0.06880061579348574,
#    0.07071067811865475,
#    0.06632730285464478,
#    0.06864540455866862],
#   'mean_t_sub': 0.06862100033136348,
#   'std_normed': 0.409387038658246,
#   'indices': [8.0, 10, 12, 15.0],
#   'difference': 0.0043833752640099755,
#   'difference_ratio': 0.06387804378897312},
#  {'t_values': [0.06880061579348574,
#    0.0642824346533225,
#    0.06632730285464478,
#    0.06435506677375183],
#   'mean_t_sub': 0.06594135501880122,
#   'std_normed': 0.47111603109444194,
#   'indices': [8.0, 9, 12, 14.0],
#   'difference': 0.004518181140163238,
#   'difference_ratio': 0.06851817253186583},
#  {'t_values': [0.03057805146377144,
#    0.025712973861329,
#    0.030612601317528357,
#    0.02574202670950073],
#   'mean_t_sub': 0.028161413338032383,
#   'std_normed': 0.5736152715746295,
#   'indices': [3.0, 3, 5, 5.0],
#   'difference': 0.004899627456199356,
#   'difference_ratio': 0.17398372011330626},
#  {'t_values': [0.06115610292754288,
#    0.057854191187990255,
#    0.056123102415468654,
#    0.05577439120391825],
#   'mean_t_sub': 0.05772694693373001,
#   'std_normed': 0.4571702662148069,
#   'indices': [7.0, 8, 10, 12.0],
#   'difference': 0.00538171172362463,
#   'difference_ratio': 0.09322702844137563},
#  {'t_values': [0.02293353859782858,
#    0.01928473039599675,
#    0.02040840087835224,
#    0.017161351139667155],
#   'mean_t_sub': 0.019947005252961184,
#   'std_normed': 0.416396961243226,
#   'indices': [2.0, 2, 3, 3.0],
#   'difference': 0.005772187458161427,
#   'difference_ratio': 0.28937614368475345},
#  {'t_values': [0.05351159006160002,
#    0.051425947722658,
#    0.0510210021958806,
#    0.04719371563408468],
#   'mean_t_sub': 0.05078806390355582,
#   'std_normed': 0.4167543215173285,
#   'indices': [6.0, 7, 9, 10.0],
#   'difference': 0.006317874427515344,
#   'difference_ratio': 0.12439683543583575},
#  {'t_values': [0.01528902573188572,
#    0.0128564869306645,
#    0.01020420043917612,
#    0.008580675569833577],
#   'mean_t_sub': 0.01173259716788998,
#   'std_normed': 0.4403767514006966,
#   'indices': [1.0, 1, 1, 1.0],
#   'difference': 0.006708350162052143,
#   'difference_ratio': 0.5717702624625771},
#  {'t_values': [0.08408964152537146,
#    0.08356716504931926,
#    0.08163360351340895,
#    0.0772260801285022],
#   'mean_t_sub': 0.08162912255415047,
#   'std_normed': 0.4545259721147253,
#   'indices': [10.0, 12, 15, 17.0],
#   'difference': 0.006863561396869264,
#   'difference_ratio': 0.08408226356122069},
#  {'t_values': [0.04586707719565716,
#    0.04499770425732575,
#    0.04081680175670448,
#    0.0386130400642511],
#   'mean_t_sub': 0.042573655818484615,
#   'std_normed': 0.47418428425550363,
#   'indices': [5.0, 6, 7, 8.0],
#   'difference': 0.0072540371314060645,
#   'difference_ratio': 0.17038793103261077}]

# %% [markdown]
# ### Graficaré el mean_t_sub, y notas

# %%
period_df = calculate_period_dataframe(note_names,fundamental_df,max=20)
period_df
# Out:
#           C3       D#3        G3       A#3
# 1   0.007645  0.006428  0.005102  0.004290
# 2   0.015289  0.012856  0.010204  0.008581
# 3   0.022934  0.019285  0.015306  0.012871
# 4   0.030578  0.025713  0.020408  0.017161
# 5   0.038223  0.032141  0.025511  0.021452
# 6   0.045867  0.038569  0.030613  0.025742
# 7   0.053512  0.044998  0.035715  0.030032
# 8   0.061156  0.051426  0.040817  0.034323
# 9   0.068801  0.057854  0.045919  0.038613
# 10  0.076445  0.064282  0.051021  0.042903
# 11  0.084090  0.070711  0.056123  0.047194
# 12  0.091734  0.077139  0.061225  0.051484
# 13  0.099379  0.083567  0.066327  0.055774
# 14  0.107023  0.089995  0.071429  0.060065
# 15  0.114668  0.096424  0.076532  0.064355
# 16  0.122312  0.102852  0.081634  0.068645
# 17  0.129957  0.109280  0.086736  0.072936
# 18  0.137601  0.115708  0.091838  0.077226
# 19  0.145246  0.122137  0.096940  0.081516

# %%
def take_period_def_extract_winners(period_df,observable_metrics):
    note_names = period_df.columns
    new_df = {
        'note_name':[],
        't_values':[],
        # 't_value_in_met':[],
        'cycle_or_t':[],
        'winner_num':[],
    }
    count=0
    for item in observable_metrics:
        print(item)
        indices = item['indices']
        print('indices:', indices)
        count+=1
        
        values = item['t_values']
        print('values:', values)
        for i in range(len(indices)):
            note_name = note_names[i]
            new_df['note_name'].append(note_name)
            new_df['t_values'].append(values[i])
            new_df['cycle_or_t'].append(indices[i])
            new_df['winner_num'].append(count)
            # new_df['t_value_in_met'].append(values[i])
    return pd.DataFrame(new_df)

# %%
top_3_observable_metrics = sorted(observable_metrics, key=lambda x: x['difference'])
top_3_observable_metrics
# Out:
# [{'t_values': [0.0764451286594286,
#    0.077138921583987,
#    0.0765315032938209,
#    0.0772260801285022],
#   'mean_t_sub': 0.07683540841643467,
#   'std_normed': 0.5171978772513034,
#   'indices': [9.0, 11, 14, 17.0],
#   'difference': 0.0007809514690736014,
#   'difference_ratio': 0.010163952859350718},
#  {'t_values': [0.03057805146377144,
#    0.03214121732666125,
#    0.030612601317528357,
#    0.03003236449441752],
#   'mean_t_sub': 0.030841058650594638,
#   'std_normed': 0.42990142473837273,
#   'indices': [3.0, 4, 5, 6.0],
#   'difference': 0.0021088528322437336,
#   'difference_ratio': 0.0683780948032753},
#  {'t_values': [0.04586707719565716,
#    0.04499770425732575,
#    0.04591890197629254,
#    0.04719371563408468],
#   'mean_t_sub': 0.04599434976584003,
#   'std_normed': 0.4118252683853573,
#   'indices': [5.0, 6, 8, 10.0],
#   'difference': 0.0021960113767589273,
#   'difference_ratio': 0.04774524235996273},
#  {'t_values': [0.01528902573188572,
#    0.0128564869306645,
#    0.015306300658764179,
#    0.012871013354750365],
#   'mean_t_sub': 0.014080706669016192,
#   'std_normed': 0.5736152715746295,
#   'indices': [1.0, 1, 2, 2.0],
#   'difference': 0.002449813728099678,
#   'difference_ratio': 0.17398372011330626},
#  {'t_values': [0.05351159006160002,
#    0.051425947722658,
#    0.0510210021958806,
#    0.05148405341900146],
#   'mean_t_sub': 0.051860648349785016,
#   'std_normed': 0.4495856218363726,
#   'indices': [6.0, 7, 9, 11.0],
#   'difference': 0.002490587865719422,
#   'difference_ratio': 0.048024618761437966},
#  {'t_values': [0.08408964152537146,
#    0.08356716504931926,
#    0.08163360351340895,
#    0.08151641791341899],
#   'mean_t_sub': 0.08270170700037967,
#   'std_normed': 0.51267756476065,
#   'indices': [10.0, 12, 15, 18.0],
#   'difference': 0.0025732236119524743,
#   'difference_ratio': 0.03111451631754906},
#  {'t_values': [0.0382225643297143,
#    0.0385694607919935,
#    0.04081680175670448,
#    0.0386130400642511],
#   'mean_t_sub': 0.039055466735665845,
#   'std_normed': 0.45761013231820086,
#   'indices': [4.0, 5, 7, 8.0],
#   'difference': 0.0025942374269901786,
#   'difference_ratio': 0.06642443795508644},
#  {'t_values': [0.02293353859782858,
#    0.025712973861329,
#    0.0255105010979403,
#    0.02574202670950073],
#   'mean_t_sub': 0.024974760066649657,
#   'std_normed': 0.4859216753517771,
#   'indices': [2.0, 3, 4, 5.0],
#   'difference': 0.0028084881116721486,
#   'difference_ratio': 0.11245305677320587},
#  {'t_values': [0.04586707719565716,
#    0.04499770425732575,
#    0.04591890197629254,
#    0.04290337784916789],
#   'mean_t_sub': 0.04492176531961083,
#   'std_normed': 0.4677078141567277,
#   'indices': [5.0, 6, 8, 9.0],
#   'difference': 0.0030155241271246497,
#   'difference_ratio': 0.06712835316398856},
#  {'t_values': [0.06115610292754288,
#    0.0642824346533225,
#    0.061225202635056715,
#    0.06435506677375183],
#   'mean_t_sub': 0.06275470174741848,
#   'std_normed': 0.5647053075401802,
#   'indices': [7.0, 9, 11, 14.0],
#   'difference': 0.0031989638462089492,
#   'difference_ratio': 0.050975684006665585},
#  {'t_values': [0.00764451286594286,
#    0.00642824346533225,
#    0.00510210021958806,
#    0.004290337784916789],
#   'mean_t_sub': 0.00586629858394499,
#   'std_normed': 0.4403767514006966,
#   'indices': [0.0, 0, 0, 0.0],
#   'difference': 0.0033541750810260713,
#   'difference_ratio': 0.5717702624625771},
#  {'t_values': [0.06115610292754288,
#    0.057854191187990255,
#    0.061225202635056715,
#    0.06006472898883504],
#   'mean_t_sub': 0.06007505643485622,
#   'std_normed': 0.466652555972158,
#   'indices': [7.0, 8, 11, 13.0],
#   'difference': 0.0033710114470664604,
#   'difference_ratio': 0.056113329676550444},
#  {'t_values': [0.02293353859782858,
#    0.01928473039599675,
#    0.02040840087835224,
#    0.021451688924583944],
#   'mean_t_sub': 0.02101958969919038,
#   'std_normed': 0.4255528810505849,
#   'indices': [2.0, 2, 3, 4.0],
#   'difference': 0.0036488082018318324,
#   'difference_ratio': 0.17359083854868845},
#  {'t_values': [0.03057805146377144,
#    0.03214121732666125,
#    0.030612601317528357,
#    0.03432270227933431],
#   'mean_t_sub': 0.03191364309682384,
#   'std_normed': 0.470990781665877,
#   'indices': [3.0, 4, 5, 7.0],
#   'difference': 0.0037446508155628694,
#   'difference_ratio': 0.11733698983227492},
#  {'t_values': [0.00764451286594286,
#    0.00642824346533225,
#    0.01020420043917612,
#    0.008580675569833577],
#   'mean_t_sub': 0.008214408085071201,
#   'std_normed': 0.4217590684854799,
#   'indices': [0.0, 0, 1, 1.0],
#   'difference': 0.003775956973843869,
#   'difference_ratio': 0.45967487063447243},
#  {'t_values': [0.01528902573188572,
#    0.01928473039599675,
#    0.015306300658764179,
#    0.017161351139667155],
#   'mean_t_sub': 0.01676035198157845,
#   'std_normed': 0.4751230473850039,
#   'indices': [1.0, 2, 2, 3.0],
#   'difference': 0.003995704664111029,
#   'difference_ratio': 0.23840219277630728},
#  {'t_values': [0.06880061579348574,
#    0.07071067811865475,
#    0.07142940307423283,
#    0.07293574234358541],
#   'mean_t_sub': 0.07096910983248969,
#   'std_normed': 0.41532634942451946,
#   'indices': [8.0, 10, 13, 16.0],
#   'difference': 0.004135126550099663,
#   'difference_ratio': 0.05826656921384408},
#  {'t_values': [0.0764451286594286,
#    0.077138921583987,
#    0.0765315032938209,
#    0.07293574234358541],
#   'mean_t_sub': 0.07576282397020548,
#   'std_normed': 0.45437936877397106,
#   'indices': [9.0, 11, 14, 16.0],
#   'difference': 0.004203179240401589,
#   'difference_ratio': 0.055478122648312755},
#  {'t_values': [0.0382225643297143,
#    0.0385694607919935,
#    0.035714701537116415,
#    0.03432270227933431],
#   'mean_t_sub': 0.036707357234539634,
#   'std_normed': 0.4794117364034809,
#   'indices': [4.0, 5, 6, 7.0],
#   'difference': 0.004246758512659189,
#   'difference_ratio': 0.11569229801875303},
#  {'t_values': [0.05351159006160002,
#    0.057854191187990255,
#    0.056123102415468654,
#    0.05577439120391825],
#   'mean_t_sub': 0.055815818717244295,
#   'std_normed': 0.41108474396252837,
#   'indices': [6.0, 8, 10, 12.0],
#   'difference': 0.004342601126390233,
#   'difference_ratio': 0.07780233679612025},
#  {'t_values': [0.06880061579348574,
#    0.07071067811865475,
#    0.06632730285464478,
#    0.06864540455866862],
#   'mean_t_sub': 0.06862100033136348,
#   'std_normed': 0.409387038658246,
#   'indices': [8.0, 10, 12, 15.0],
#   'difference': 0.0043833752640099755,
#   'difference_ratio': 0.06387804378897312},
#  {'t_values': [0.06880061579348574,
#    0.0642824346533225,
#    0.06632730285464478,
#    0.06435506677375183],
#   'mean_t_sub': 0.06594135501880122,
#   'std_normed': 0.47111603109444194,
#   'indices': [8.0, 9, 12, 14.0],
#   'difference': 0.004518181140163238,
#   'difference_ratio': 0.06851817253186583},
#  {'t_values': [0.03057805146377144,
#    0.025712973861329,
#    0.030612601317528357,
#    0.02574202670950073],
#   'mean_t_sub': 0.028161413338032383,
#   'std_normed': 0.5736152715746295,
#   'indices': [3.0, 3, 5, 5.0],
#   'difference': 0.004899627456199356,
#   'difference_ratio': 0.17398372011330626},
#  {'t_values': [0.06115610292754288,
#    0.057854191187990255,
#    0.056123102415468654,
#    0.05577439120391825],
#   'mean_t_sub': 0.05772694693373001,
#   'std_normed': 0.4571702662148069,
#   'indices': [7.0, 8, 10, 12.0],
#   'difference': 0.00538171172362463,
#   'difference_ratio': 0.09322702844137563},
#  {'t_values': [0.02293353859782858,
#    0.01928473039599675,
#    0.02040840087835224,
#    0.017161351139667155],
#   'mean_t_sub': 0.019947005252961184,
#   'std_normed': 0.416396961243226,
#   'indices': [2.0, 2, 3, 3.0],
#   'difference': 0.005772187458161427,
#   'difference_ratio': 0.28937614368475345},
#  {'t_values': [0.05351159006160002,
#    0.051425947722658,
#    0.0510210021958806,
#    0.04719371563408468],
#   'mean_t_sub': 0.05078806390355582,
#   'std_normed': 0.4167543215173285,
#   'indices': [6.0, 7, 9, 10.0],
#   'difference': 0.006317874427515344,
#   'difference_ratio': 0.12439683543583575},
#  {'t_values': [0.01528902573188572,
#    0.0128564869306645,
#    0.01020420043917612,
#    0.008580675569833577],
#   'mean_t_sub': 0.01173259716788998,
#   'std_normed': 0.4403767514006966,
#   'indices': [1.0, 1, 1, 1.0],
#   'difference': 0.006708350162052143,
#   'difference_ratio': 0.5717702624625771},
#  {'t_values': [0.08408964152537146,
#    0.08356716504931926,
#    0.08163360351340895,
#    0.0772260801285022],
#   'mean_t_sub': 0.08162912255415047,
#   'std_normed': 0.4545259721147253,
#   'indices': [10.0, 12, 15, 17.0],
#   'difference': 0.006863561396869264,
#   'difference_ratio': 0.08408226356122069},
#  {'t_values': [0.04586707719565716,
#    0.04499770425732575,
#    0.04081680175670448,
#    0.0386130400642511],
#   'mean_t_sub': 0.042573655818484615,
#   'std_normed': 0.47418428425550363,
#   'indices': [5.0, 6, 7, 8.0],
#   'difference': 0.0072540371314060645,
#   'difference_ratio': 0.17038793103261077}]

# %%
extracted_winners = take_period_def_extract_winners(period_df,top_3_observable_metrics[:max_number_of_observable_metrics])
extracted_winners
# Out:
# {'t_values': [0.0764451286594286, 0.077138921583987, 0.0765315032938209, 0.0772260801285022], 'mean_t_sub': 0.07683540841643467, 'std_normed': 0.5171978772513034, 'indices': [9.0, 11, 14, 17.0], 'difference': 0.0007809514690736014, 'difference_ratio': 0.010163952859350718}
# indices: [9.0, 11, 14, 17.0]
# values: [0.0764451286594286, 0.077138921583987, 0.0765315032938209, 0.0772260801285022]
# {'t_values': [0.03057805146377144, 0.03214121732666125, 0.030612601317528357, 0.03003236449441752], 'mean_t_sub': 0.030841058650594638, 'std_normed': 0.42990142473837273, 'indices': [3.0, 4, 5, 6.0], 'difference': 0.0021088528322437336, 'difference_ratio': 0.0683780948032753}
# indices: [3.0, 4, 5, 6.0]
# values: [0.03057805146377144, 0.03214121732666125, 0.030612601317528357, 0.03003236449441752]
# {'t_values': [0.04586707719565716, 0.04499770425732575, 0.04591890197629254, 0.04719371563408468], 'mean_t_sub': 0.04599434976584003, 'std_normed': 0.4118252683853573, 'indices': [5.0, 6, 8, 10.0], 'difference': 0.0021960113767589273, 'difference_ratio': 0.04774524235996273}
# indices: [5.0, 6, 8, 10.0]
# values: [0.04586707719565716, 0.04499770425732575, 0.04591890197629254, 0.04719371563408468]
# {'t_values': [0.01528902573188572, 0.0128564869306645, 0.015306300658764179, 0.012871013354750365], 'mean_t_sub': 0.014080706669016192, 'std_normed': 0.5736152715746295, 'indices': [1.0, 1, 2, 2.0], 'difference': 0.002449813728099678, 'difference_ratio': 0.17398372011330626}
# indices: [1.0, 1, 2, 2.0]
# values: [0.01528902573188572, 0.0128564869306645, 0.015306300658764179, 0.012871013354750365]
# {'t_values': [0.05351159006160002, 0.051425947722658, 0.0510210021958806, 0.05148405341900146], 'mean_t_sub': 0.051860648349785016, 'std_normed': 0.4495856218363726, 'indices': [6.0, 7, 9, 11.0], 'difference': 0.002490587865719422, 'difference_ratio': 0.048024618761437966}
# indices: [6.0, 7, 9, 11.0]
# values: [0.05351159006160002, 0.051425947722658, 0.0510210021958806, 0.05148405341900146]
#    note_name  t_values  cycle_or_t  winner_num
# 0         C3  0.076445         9.0           1
# 1        D#3  0.077139        11.0           1
# 2         G3  0.076532        14.0           1
# 3        A#3  0.077226        17.0           1
# 4         C3  0.030578         3.0           2
# 5        D#3  0.032141         4.0           2
# 6         G3  0.030613         5.0           2
# 7        A#3  0.030032         6.0           2
# 8         C3  0.045867         5.0           3
# 9        D#3  0.044998         6.0           3
# 10        G3  0.045919         8.0           3
# 11       A#3  0.047194        10.0           3
# 12        C3  0.015289         1.0           4
# 13       D#3  0.012856         1.0           4
# 14        G3  0.015306         2.0           4
# 15       A#3  0.012871         2.0           4
# 16        C3  0.053512         6.0           5
# 17       D#3  0.051426         7.0           5
# 18        G3  0.051021         9.0           5
# 19       A#3  0.051484        11.0           5

# %%
### what interests me, create chart of the period df, with all cycle numbers, t values and notes. 
period_df, period_df.shape
long_period_df = period_df.reset_index().melt(id_vars='index')
long_period_df.columns = ['cycle_or_t', 'note_name', 't_values']
long_period_df['cycle_or_t'] = long_period_df['cycle_or_t'] -1
# long_period_df['cycle_or_t'] = long_period_df['cycle_or_t'].astype(str)
long_period_df
long_period_df[long_period_df['cycle_or_t']>=20]
# Out:
# Empty DataFrame
# Columns: [cycle_or_t, note_name, t_values]
# Index: []

# %%
chart3 = alt.Chart(long_period_df).mark_bar(
    opacity=0.1,
    clip=True
    # xOffset=0.5
).encode(
    x=alt.X('t_values', title='Period',scale=alt.Scale(domain=[0, 0.08])),
    y=alt.Y('cycle_or_t:Q', title='Cycle' ),
    color=alt.Color('note_name', title='Note'),
).properties(
    width=600,
    height=300
)
chart3
# Out:
# alt.Chart(...)

# %%
chart1= alt.Chart(extracted_winners).mark_bar(
    opacity=0.6,
).encode(
    x=alt.X('t_values', scale=alt.Scale(domain=[0, 0.08])),
    y=alt.Y('cycle_or_t'),
    color='note_name',
    # tooltip=['note_name','t_values','cycle_or_t'],
).properties(
    width=600,
    height=300
)
chart1
# Out:
# alt.Chart(...)

# %%
top_3_observable_metrics = sorted(observable_metrics, key=lambda x: x['difference'])[:max_number_of_observable_metrics]
observable_df = pd.DataFrame(top_3_observable_metrics)
observable_df.sort_values(by='mean_t_sub',inplace=True)
## adding 1,2,3, order values to sorted by mean
observable_df['order'] = range(1,max_number_of_observable_metrics+1)
observable_df
# Out:
#                                             t_values  mean_t_sub  std_normed  \
# 3  [0.01528902573188572, 0.0128564869306645, 0.01...    0.014081    0.573615
# 1  [0.03057805146377144, 0.03214121732666125, 0.0...    0.030841    0.429901
# 2  [0.04586707719565716, 0.04499770425732575, 0.0...    0.045994    0.411825
# 4  [0.05351159006160002, 0.051425947722658, 0.051...    0.051861    0.449586
# 0  [0.0764451286594286, 0.077138921583987, 0.0765...    0.076835    0.517198
#
#                indices  difference  difference_ratio  order
# 3     [1.0, 1, 2, 2.0]    0.002450          0.173984      1
# 1     [3.0, 4, 5, 6.0]    0.002109          0.068378      2
# 2    [5.0, 6, 8, 10.0]    0.002196          0.047745      3
# 4    [6.0, 7, 9, 11.0]    0.002491          0.048025      4
# 0  [9.0, 11, 14, 17.0]    0.000781          0.010164      5

# %% [markdown]
# En este momento probaré lo de harmonious

# %%
(0.000275/0.030509)
# Out:
# 0.009013733652364877

# %%
## adding min t_value to observable_df, 
observable_df['t_value_min'] = [min(r['t_values']) for i,r in observable_df.iterrows()]
observable_df['t_value_max'] = [max(r['t_values']) for i,r in observable_df.iterrows()]


observable_df
# Out:
#                                             t_values  mean_t_sub  std_normed  \
# 3  [0.01528902573188572, 0.0128564869306645, 0.01...    0.014081    0.573615
# 1  [0.03057805146377144, 0.03214121732666125, 0.0...    0.030841    0.429901
# 2  [0.04586707719565716, 0.04499770425732575, 0.0...    0.045994    0.411825
# 4  [0.05351159006160002, 0.051425947722658, 0.051...    0.051861    0.449586
# 0  [0.0764451286594286, 0.077138921583987, 0.0765...    0.076835    0.517198
#
#                indices  difference  difference_ratio  order  t_value_min  \
# 3     [1.0, 1, 2, 2.0]    0.002450          0.173984      1     0.012856
# 1     [3.0, 4, 5, 6.0]    0.002109          0.068378      2     0.030032
# 2    [5.0, 6, 8, 10.0]    0.002196          0.047745      3     0.044998
# 4    [6.0, 7, 9, 11.0]    0.002491          0.048025      4     0.051021
# 0  [9.0, 11, 14, 17.0]    0.000781          0.010164      5     0.076445
#
#    t_value_max
# 3     0.015306
# 1     0.032141
# 2     0.047194
# 4     0.053512
# 0     0.077226

# %%
def add_max_cycle(observable_df):
    for i, row in observable_df.iterrows():
        indices = row['indices']
        max_cycle = max(indices)
        observable_df.at[i, 'max_cycle'] = max_cycle

    

add_max_cycle(observable_df)

# %%
chart2 = alt.Chart(observable_df).mark_bar(
    color='black'
).encode(
    x=alt.X('mean_t_sub').scale(domain=[0, 0.08]),
    y=alt.Y('order'),
    
)

chart4 = alt.Chart(observable_df).mark_text(
    color='black',
    align='center',
    dy=-10,
    fontSize=12,
).encode(
    x=alt.X('mean_t_sub').scale(domain=[0, 0.08]),
    y=alt.Y('max_cycle:Q'),
    text=alt.Text('difference:Q', format='.3s', ),
    
)
(chart1+chart2+chart3+chart4).properties(
    width=300,
    height=250,
    title='Mean note period in Cmin7 (C3,D#3,G3,A#3) Chord'
    # title='Mean note period in C Major (C3,E3,G3,C4) Triad',
).configure_title(
    fontSize=16,
)
# Out:
# alt.LayerChart(...)

# %%
# Sample frequency array (in Hertz)
frequencies =fundamental_df[note_names].to_numpy().flatten()  # C4, E4, G4 notes
note_names
# Out:
# ['C3', 'D#3', 'G3', 'A#3']

# %%
# Function to generate sine wave data
def generate_sine_waves(frequencies, note_names, duration=1.0, sample_rate=1000):
    t = np.linspace(0, duration, int(sample_rate * duration))
    data = []
    
    for f_ind in range(len(frequencies)):
        freq = frequencies[f_ind]
        note_name = note_names[f_ind]
        # Calculate sine wave values: sin(2π * frequency * time)
        y_values = np.sin(2 * np.pi * freq * t)  
        
        # Create DataFrame entries for this frequency
        for i in range(len(t)):
            data.append({
                'time': t[i],
                'amplitude': y_values[i],
                'frequency': f"{freq} Hz",
                'note_name':note_name
            })
            
    return pd.DataFrame(data)

# Generate the data
sine_df = generate_sine_waves(frequencies, note_names,duration=((1/frequencies[-1])*18), sample_rate=10000)
sine_df
# Out:
#           time     amplitude              frequency note_name
# 0     0.000000  0.000000e+00   130.8127826502993 Hz        C3
# 1     0.000100  8.223354e-02   130.8127826502993 Hz        C3
# 2     0.000200  1.639100e-01   130.8127826502993 Hz        C3
# 3     0.000300  2.444762e-01   130.8127826502993 Hz        C3
# 4     0.000401  3.233864e-01   130.8127826502993 Hz        C3
# ...        ...           ...                    ...       ...
# 3083  0.076825 -5.536630e-01  233.08188075904496 Hz       A#3
# 3084  0.076926 -4.260005e-01  233.08188075904496 Hz       A#3
# 3085  0.077026 -2.891878e-01  233.08188075904496 Hz       A#3
# 3086  0.077126 -1.461636e-01  233.08188075904496 Hz       A#3
# 3087  0.077226 -4.408728e-15  233.08188075904496 Hz       A#3
#
# [3088 rows x 4 columns]

# %%
# Create Altair visualization
chart = alt.Chart(sine_df).mark_line(
    opacity=0.4,
    clip=True
).encode(
    x=alt.X('time:Q', title='Time (seconds)', scale=alt.Scale(domain=[0, 0.040])),
    y=alt.Y('amplitude:Q', title='Amplitude'),
    color=alt.Color('note_name:N', title='Note Name')
).properties(
    width=500,
    height=250,
    title='Sine Waves at Different Frequencies'
)

chart
# Out:
# alt.Chart(...)

# %%
min_difference =min(observable_df['difference'])
max_difference =max(observable_df['difference'])

# %%
rect_chart = alt.Chart(observable_df).mark_rect(
    opacity=0.5,
    clip=True
).encode(
    x=alt.X('t_value_min', scale=alt.Scale(domain=[0, 0.04])),
    x2='t_value_max',
    color=alt.Color('difference', scale=alt.Scale(domain=[0,0.0025], range=['green','red']))
)
(chart+rect_chart).configure_title(
    fontSize=16,
    anchor='end',
    color='black'
).properties(
    title='Sine Waves Approximate alignment of C major (C3, E3, G3, C4) Triad',
    width=500,
    height=255,
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Making grid of period_df

# %%
grid_p_df = period_df.melt(ignore_index=False).reset_index()
grid_p_df.columns = ['cycle_or_t', 'note_name', 't_values']
grid_p_df['t_values'] = round(grid_p_df['t_values'] * 10**3,2)

# %%
chart_grid = alt.Chart(grid_p_df).mark_rect(
    color='white',
    stroke='black',
    
).encode(
    x=alt.X('note_name',
            axis=alt.Axis(orient='top',title='Note Name', labelAngle=0),
            sort=note_names),
    y=alt.Y('cycle_or_t:Q',
             scale=alt.Scale(domain=[0,19],reverse=True),
             axis=alt.Axis(title='Cycle', tickCount=20,)),
    
)
text = alt.Chart(grid_p_df).mark_text(baseline='bottom').encode(
        x=alt.X('note_name',
                sort=note_names),
    y=alt.Y('cycle_or_t:Q',
             scale=alt.Scale(domain=[0,19],reverse=True),
             axis=alt.Axis(title='Cycle', tickCount=20)),
    text='t_values',
    
)
chart_grid = chart_grid + text
chart_grid.properties(width=250)
# Out:
# alt.LayerChart(...)

# %%
## changing extracted_winners to match period_df
ext_win = extracted_winners.copy()
ext_win['cycle_or_t_end'] = ext_win['cycle_or_t'] +1
ext_win
# Out:
#    note_name  t_values  cycle_or_t  winner_num  cycle_or_t_end
# 0         C3  0.076445         9.0           1            10.0
# 1        D#3  0.077139        11.0           1            12.0
# 2         G3  0.076532        14.0           1            15.0
# 3        A#3  0.077226        17.0           1            18.0
# 4         C3  0.030578         3.0           2             4.0
# 5        D#3  0.032141         4.0           2             5.0
# 6         G3  0.030613         5.0           2             6.0
# 7        A#3  0.030032         6.0           2             7.0
# 8         C3  0.045867         5.0           3             6.0
# 9        D#3  0.044998         6.0           3             7.0
# 10        G3  0.045919         8.0           3             9.0
# 11       A#3  0.047194        10.0           3            11.0
# 12        C3  0.015289         1.0           4             2.0
# 13       D#3  0.012856         1.0           4             2.0
# 14        G3  0.015306         2.0           4             3.0
# 15       A#3  0.012871         2.0           4             3.0
# 16        C3  0.053512         6.0           5             7.0
# 17       D#3  0.051426         7.0           5             8.0
# 18        G3  0.051021         9.0           5            10.0
# 19       A#3  0.051484        11.0           5            12.0

# %%
note_names
# Out:
# ['C3', 'D#3', 'G3', 'A#3']

# %%
chart_rect_win = alt.Chart(ext_win).mark_rect().encode(
    x=alt.X('note_name',
            axis=alt.Axis(orient='top',title='Note Name', labelAngle=0),
            sort=note_names),
    y=alt.Y('cycle_or_t',
             scale=alt.Scale(domain=[0,19],reverse=True),
             axis=alt.Axis(title='Cycle', tickCount=20,)),
    y2='cycle_or_t_end',
    color=alt.Color('winner_num:O',title='Winner Order Preference', scale=alt.Scale(scheme='goldgreen'))
)
chart_rect_win
# Out:
# alt.Chart(...)

# %%
(chart_grid+chart_rect_win+text).properties(width=250, title='Winning Cycles of the Cmin7').configure_title(
fontSize=16,
anchor='middle',	
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Making bound df visualization with rectangles

# %%
## mixing bound_df with note_names

bdf = bound_df[['bass','last_note','ratio','bass_value','last_note_value']].copy()
bdf.sort_values(by='ratio', ascending=True, inplace=True)
bdf['winners']= range(1,len(bdf)+1)


bass_bdf = bdf[['bass','bass_value','winners']].copy()
bass_bdf['note_name'] = note_names[0]
bass_bdf.rename(columns={'bass':'cycle_or_t'}, inplace=True)
# bass_bdf['cycle_or_t'] = bass_bdf['cycle_or_t'] +1

bass_bdf
# Out:
#     cycle_or_t  bass_value  winners note_name
# 0            8    0.068801        1        C3
# 1            4    0.038223        2        C3
# 2            9    0.076445        3        C3
# 3            3    0.030578        4        C3
# 4            7    0.061156        5        C3
# 5            5    0.045867        6        C3
# 6           10    0.084090        7        C3
# 7            6    0.053512        8        C3
# 8            6    0.053512        9        C3
# 9            9    0.076445       10        C3
# 10           7    0.061156       11        C3
# 11           8    0.068801       12        C3
# 12           2    0.022934       13        C3
# 13           5    0.045867       14        C3
# 14           8    0.068801       15        C3
# 15          10    0.084090       16        C3
# 16           7    0.061156       17        C3
# 17           4    0.038223       18        C3
# 18           2    0.022934       19        C3
# 19           0    0.007645       20        C3
# 20           1    0.015289       21        C3
# 21           3    0.030578       22        C3
# 22           6    0.053512       23        C3
# 23           1    0.015289       24        C3
# 24           3    0.030578       25        C3
# 25           5    0.045867       26        C3
# 26           2    0.022934       27        C3
# 27           0    0.007645       28        C3
# 28           1    0.015289       29        C3

# %%
last_note = bdf[['last_note','last_note_value','winners']].copy()
last_note['note_name'] = note_names[-1]
last_note.rename(columns={'last_note':'cycle_or_t'}, inplace=True)
# last_note['cycle_or_t'] = last_note['cycle_or_t'] +1

last_note
# Out:
#     cycle_or_t  last_note_value  winners note_name
# 0           15         0.068645        1       A#3
# 1            8         0.038613        2       A#3
# 2           17         0.077226        3       A#3
# 3            6         0.030032        4       A#3
# 4           13         0.060065        5       A#3
# 5           10         0.047194        6       A#3
# 6           18         0.081516        7       A#3
# 7           11         0.051484        8       A#3
# 8           12         0.055774        9       A#3
# 9           16         0.072936       10       A#3
# 10          14         0.064355       11       A#3
# 11          16         0.072936       12       A#3
# 12           4         0.021452       13       A#3
# 13           9         0.042903       14       A#3
# 14          14         0.064355       15       A#3
# 15          17         0.077226       16       A#3
# 16          12         0.055774       17       A#3
# 17           7         0.034323       18       A#3
# 18           5         0.025742       19       A#3
# 19           1         0.008581       20       A#3
# 20           3         0.017161       21       A#3
# 21           7         0.034323       22       A#3
# 22          10         0.047194       23       A#3
# 23           2         0.012871       24       A#3
# 24           5         0.025742       25       A#3
# 25           8         0.038613       26       A#3
# 26           3         0.017161       27       A#3
# 27           0         0.004290       28       A#3
# 28           1         0.008581       29       A#3

# %%
bass_bdf['cycle_or_t_end'] = bass_bdf['cycle_or_t']+1
last_note['cycle_or_t_end'] = last_note['cycle_or_t']+1

### only retrieing top 10  winners
bass_bdf = bass_bdf[bass_bdf['winners']<=10]
last_note = last_note[last_note['winners']<=10]

# %%
bound_chart_bass = alt.Chart(bass_bdf).mark_rect().encode(
    x=alt.X('note_name',
            axis=alt.Axis(orient='top',title='Note Name', labelAngle=0),
            sort=note_names),
    y=alt.Y('cycle_or_t',
             scale=alt.Scale(domain=[0,19],reverse=True),
             axis=alt.Axis(title='Cycle', tickCount=20,)),
    y2='cycle_or_t_end',
    color=alt.Color('winners:O',title='Winner Order Preference', scale=alt.Scale(scheme='yellowgreen'))
)



bound_chart_sop  = alt.Chart(last_note).mark_rect().encode(
    x=alt.X('note_name',
            axis=alt.Axis(orient='top',title='Note Name', labelAngle=0),
            sort=note_names),
    y=alt.Y('cycle_or_t',
             scale=alt.Scale(domain=[0,19],reverse=True),
             axis=alt.Axis(title='Cycle', tickCount=20,)),
    y2='cycle_or_t_end',
    color=alt.Color('winners:O',title='Winner Order Preference', scale=alt.Scale())
)

(chart_grid+bound_chart_bass+bound_chart_sop+text).properties(width=250, title='Bound Candidates C Major Triad').configure_title(
fontSize=16,
anchor='middle',	
)
# Out:
# alt.LayerChart(...)

# %%
#### now make border with grid rectangles

#####
## The table must be note_name[1], note_name [-2] and y=cycle_or_t y2 =last_note_cycle_t_end
###
new_df = pd.DataFrame(
    {
        "note_name":[],
        'before_last':[],
        'cycle_or_t':[],
        'cycle_or_t_end':[],
        'winners':[]
    }
)

after_bass = note_names[1]
before_last = note_names[-2]
for i,r in bass_bdf.iterrows():
    winner_num = r['winners']
    ##searching in bass_df winner
    cycle_to_begin = r['cycle_or_t']
    cycle_to_end = last_note[last_note['winners'] == winner_num]['cycle_or_t'].values[0]+1
    new_df.loc[i] = {
        'note_name':after_bass,
        'before_last':before_last,
        'cycle_or_t':cycle_to_begin,
        'cycle_or_t_end':cycle_to_end,
        'winners':winner_num
    }
new_df
# Out:
#   note_name before_last  cycle_or_t  cycle_or_t_end  winners
# 0       D#3          G3           8              16        1
# 1       D#3          G3           4               9        2
# 2       D#3          G3           9              18        3
# 3       D#3          G3           3               7        4
# 4       D#3          G3           7              14        5
# 5       D#3          G3           5              11        6
# 6       D#3          G3          10              19        7
# 7       D#3          G3           6              12        8
# 8       D#3          G3           6              13        9
# 9       D#3          G3           9              17       10

# %%
## chart

inside_rect = alt.Chart(new_df).mark_rect(
    filled=False,
    strokeWidth=2,
    strokeOpacity=0.5,
    baseline='middle',
    # width=30
    
    
).encode(
    x=alt.X('note_name', sort=note_names,bandPosition=0),
    x2=alt.X2('before_last',bandPosition=1),
    y=alt.Y('cycle_or_t',
             scale=alt.Scale(domain=[0,19],reverse=True),
             axis=alt.Axis(title='Cycle', tickCount=20,)),
    y2='cycle_or_t_end',
    color=alt.Color('winners:O',title='Winner Order Preference', scale=alt.Scale(scheme='rainbow'))

)

# (chart_grid+inside_rect).properties(width=250).to_json()

# %%
(chart_grid+bound_chart_bass+bound_chart_sop+inside_rect+text).properties(width=250, title='Search Candidates C major').configure_title(
fontSize=16,
anchor='middle',	
).configure_view(
    strokeOpacity=0.7
)
# Out:
# alt.LayerChart(...)

# %%
import json
from pprint import pprint
pprint(json.loads((chart_grid+bound_chart_bass+bound_chart_sop+inside_rect+text).properties(width=250).to_json()))
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v5.20.1.json',
#  'config': {'view': {'continuousHeight': 300, 'continuousWidth': 300}},
#  'data': {'name': 'data-3bf4e51a39332d5b9a3693ed1af79138'},
#  'datasets': {'data-1e1b582529a0fc5350aa86294e16bd02': [{'cycle_or_t': 15,
#                                                          'cycle_or_t_end': 16,
#                                                          'last_note_value': 0.06864540455866862,
#                                                          'note_name': 'A#3',
#                                                          'winners': 1},
#                                                         {'cycle_or_t': 8,
#                                                          'cycle_or_t_end': 9,
#                                                          'last_note_value': 0.0386130400642511,
#                                                          'note_name': 'A#3',
#                                                          'winners': 2},
#                                                         {'cycle_or_t': 17,
#                                                          'cycle_or_t_end': 18,
#                                                          'last_note_value': 0.0772260801285022,
#                                                          'note_name': 'A#3',
#                                                          'winners': 3},
#                                                         {'cycle_or_t': 6,
#                                                          'cycle_or_t_end': 7,
#                                                          'last_note_value': 0.03003236449441752,
#                                                          'note_name': 'A#3',
#                                                          'winners': 4},
#                                                         {'cycle_or_t': 13,
#                                                          'cycle_or_t_end': 14,
#                                                          'last_note_value': 0.06006472898883504,
#                                                          'note_name': 'A#3',
#                                                          'winners': 5},
#                                                         {'cycle_or_t': 10,
#                                                          'cycle_or_t_end': 11,
#                                                          'last_note_value': 0.04719371563408468,
#                                                          'note_name': 'A#3',
#                                                          'winners': 6},
#                                                         {'cycle_or_t': 18,
#                                                          'cycle_or_t_end': 19,
#                                                          'last_note_value': 0.08151641791341899,
#                                                          'note_name': 'A#3',
#                                                          'winners': 7},
#                                                         {'cycle_or_t': 11,
#                                                          'cycle_or_t_end': 12,
#                                                          'last_note_value': 0.05148405341900146,
#                                                          'note_name': 'A#3',
#                                                          'winners': 8},
#                                                         {'cycle_or_t': 12,
#                                                          'cycle_or_t_end': 13,
#                                                          'last_note_value': 0.05577439120391825,
#                                                          'note_name': 'A#3',
#                                                          'winners': 9},
#                                                         {'cycle_or_t': 16,
#                                                          'cycle_or_t_end': 17,
#                                                          'last_note_value': 0.07293574234358541,
#                                                          'note_name': 'A#3',
#                                                          'winners': 10}],
#               'data-3bf4e51a39332d5b9a3693ed1af79138': [{'cycle_or_t': 1,
#                                                          'note_name': 'C3',
#                                                          't_values': 7.64},
#                                                         {'cycle_or_t': 2,
#                                                          'note_name': 'C3',
#                                                          't_values': 15.29},
#                                                         {'cycle_or_t': 3,
#                                                          'note_name': 'C3',
#                                                          't_values': 22.93},
#                                                         {'cycle_or_t': 4,
#                                                          'note_name': 'C3',
#                                                          't_values': 30.58},
#                                                         {'cycle_or_t': 5,
#                                                          'note_name': 'C3',
#                                                          't_values': 38.22},
#                                                         {'cycle_or_t': 6,
#                                                          'note_name': 'C3',
#                                                          't_values': 45.87},
#                                                         {'cycle_or_t': 7,
#                                                          'note_name': 'C3',
#                                                          't_values': 53.51},
#                                                         {'cycle_or_t': 8,
#                                                          'note_name': 'C3',
#                                                          't_values': 61.16},
#                                                         {'cycle_or_t': 9,
#                                                          'note_name': 'C3',
#                                                          't_values': 68.8},
#                                                         {'cycle_or_t': 10,
#                                                          'note_name': 'C3',
#                                                          't_values': 76.45},
#                                                         {'cycle_or_t': 11,
#                                                          'note_name': 'C3',
#                                                          't_values': 84.09},
#                                                         {'cycle_or_t': 12,
#                                                          'note_name': 'C3',
#                                                          't_values': 91.73},
#                                                         {'cycle_or_t': 13,
#                                                          'note_name': 'C3',
#                                                          't_values': 99.38},
#                                                         {'cycle_or_t': 14,
#                                                          'note_name': 'C3',
#                                                          't_values': 107.02},
#                                                         {'cycle_or_t': 15,
#                                                          'note_name': 'C3',
#                                                          't_values': 114.67},
#                                                         {'cycle_or_t': 16,
#                                                          'note_name': 'C3',
#                                                          't_values': 122.31},
#                                                         {'cycle_or_t': 17,
#                                                          'note_name': 'C3',
#                                                          't_values': 129.96},
#                                                         {'cycle_or_t': 18,
#                                                          'note_name': 'C3',
#                                                          't_values': 137.6},
#                                                         {'cycle_or_t': 19,
#                                                          'note_name': 'C3',
#                                                          't_values': 145.25},
#                                                         {'cycle_or_t': 1,
#                                                          'note_name': 'D#3',
#                                                          't_values': 6.43},
#                                                         {'cycle_or_t': 2,
#                                                          'note_name': 'D#3',
#                                                          't_values': 12.86},
#                                                         {'cycle_or_t': 3,
#                                                          'note_name': 'D#3',
#                                                          't_values': 19.28},
#                                                         {'cycle_or_t': 4,
#                                                          'note_name': 'D#3',
#                                                          't_values': 25.71},
#                                                         {'cycle_or_t': 5,
#                                                          'note_name': 'D#3',
#                                                          't_values': 32.14},
#                                                         {'cycle_or_t': 6,
#                                                          'note_name': 'D#3',
#                                                          't_values': 38.57},
#                                                         {'cycle_or_t': 7,
#                                                          'note_name': 'D#3',
#                                                          't_values': 45.0},
#                                                         {'cycle_or_t': 8,
#                                                          'note_name': 'D#3',
#                                                          't_values': 51.43},
#                                                         {'cycle_or_t': 9,
#                                                          'note_name': 'D#3',
#                                                          't_values': 57.85},
#                                                         {'cycle_or_t': 10,
#                                                          'note_name': 'D#3',
#                                                          't_values': 64.28},
#                                                         {'cycle_or_t': 11,
#                                                          'note_name': 'D#3',
#                                                          't_values': 70.71},
#                                                         {'cycle_or_t': 12,
#                                                          'note_name': 'D#3',
#                                                          't_values': 77.14},
#                                                         {'cycle_or_t': 13,
#                                                          'note_name': 'D#3',
#                                                          't_values': 83.57},
#                                                         {'cycle_or_t': 14,
#                                                          'note_name': 'D#3',
#                                                          't_values': 90.0},
#                                                         {'cycle_or_t': 15,
#                                                          'note_name': 'D#3',
#                                                          't_values': 96.42},
#                                                         {'cycle_or_t': 16,
#                                                          'note_name': 'D#3',
#                                                          't_values': 102.85},
#                                                         {'cycle_or_t': 17,
#                                                          'note_name': 'D#3',
#                                                          't_values': 109.28},
#                                                         {'cycle_or_t': 18,
#                                                          'note_name': 'D#3',
#                                                          't_values': 115.71},
#                                                         {'cycle_or_t': 19,
#                                                          'note_name': 'D#3',
#                                                          't_values': 122.14},
#                                                         {'cycle_or_t': 1,
#                                                          'note_name': 'G3',
#                                                          't_values': 5.1},
#                                                         {'cycle_or_t': 2,
#                                                          'note_name': 'G3',
#                                                          't_values': 10.2},
#                                                         {'cycle_or_t': 3,
#                                                          'note_name': 'G3',
#                                                          't_values': 15.31},
#                                                         {'cycle_or_t': 4,
#                                                          'note_name': 'G3',
#                                                          't_values': 20.41},
#                                                         {'cycle_or_t': 5,
#                                                          'note_name': 'G3',
#                                                          't_values': 25.51},
#                                                         {'cycle_or_t': 6,
#                                                          'note_name': 'G3',
#                                                          't_values': 30.61},
#                                                         {'cycle_or_t': 7,
#                                                          'note_name': 'G3',
#                                                          't_values': 35.71},
#                                                         {'cycle_or_t': 8,
#                                                          'note_name': 'G3',
#                                                          't_values': 40.82},
#                                                         {'cycle_or_t': 9,
#                                                          'note_name': 'G3',
#                                                          't_values': 45.92},
#                                                         {'cycle_or_t': 10,
#                                                          'note_name': 'G3',
#                                                          't_values': 51.02},
#                                                         {'cycle_or_t': 11,
#                                                          'note_name': 'G3',
#                                                          't_values': 56.12},
#                                                         {'cycle_or_t': 12,
#                                                          'note_name': 'G3',
#                                                          't_values': 61.23},
#                                                         {'cycle_or_t': 13,
#                                                          'note_name': 'G3',
#                                                          't_values': 66.33},
#                                                         {'cycle_or_t': 14,
#                                                          'note_name': 'G3',
#                                                          't_values': 71.43},
#                                                         {'cycle_or_t': 15,
#                                                          'note_name': 'G3',
#                                                          't_values': 76.53},
#                                                         {'cycle_or_t': 16,
#                                                          'note_name': 'G3',
#                                                          't_values': 81.63},
#                                                         {'cycle_or_t': 17,
#                                                          'note_name': 'G3',
#                                                          't_values': 86.74},
#                                                         {'cycle_or_t': 18,
#                                                          'note_name': 'G3',
#                                                          't_values': 91.84},
#                                                         {'cycle_or_t': 19,
#                                                          'note_name': 'G3',
#                                                          't_values': 96.94},
#                                                         {'cycle_or_t': 1,
#                                                          'note_name': 'A#3',
#                                                          't_values': 4.29},
#                                                         {'cycle_or_t': 2,
#                                                          'note_name': 'A#3',
#                                                          't_values': 8.58},
#                                                         {'cycle_or_t': 3,
#                                                          'note_name': 'A#3',
#                                                          't_values': 12.87},
#                                                         {'cycle_or_t': 4,
#                                                          'note_name': 'A#3',
#                                                          't_values': 17.16},
#                                                         {'cycle_or_t': 5,
#                                                          'note_name': 'A#3',
#                                                          't_values': 21.45},
#                                                         {'cycle_or_t': 6,
#                                                          'note_name': 'A#3',
#                                                          't_values': 25.74},
#                                                         {'cycle_or_t': 7,
#                                                          'note_name': 'A#3',
#                                                          't_values': 30.03},
#                                                         {'cycle_or_t': 8,
#                                                          'note_name': 'A#3',
#                                                          't_values': 34.32},
#                                                         {'cycle_or_t': 9,
#                                                          'note_name': 'A#3',
#                                                          't_values': 38.61},
#                                                         {'cycle_or_t': 10,
#                                                          'note_name': 'A#3',
#                                                          't_values': 42.9},
#                                                         {'cycle_or_t': 11,
#                                                          'note_name': 'A#3',
#                                                          't_values': 47.19},
#                                                         {'cycle_or_t': 12,
#                                                          'note_name': 'A#3',
#                                                          't_values': 51.48},
#                                                         {'cycle_or_t': 13,
#                                                          'note_name': 'A#3',
#                                                          't_values': 55.77},
#                                                         {'cycle_or_t': 14,
#                                                          'note_name': 'A#3',
#                                                          't_values': 60.06},
#                                                         {'cycle_or_t': 15,
#                                                          'note_name': 'A#3',
#                                                          't_values': 64.36},
#                                                         {'cycle_or_t': 16,
#                                                          'note_name': 'A#3',
#                                                          't_values': 68.65},
#                                                         {'cycle_or_t': 17,
#                                                          'note_name': 'A#3',
#                                                          't_values': 72.94},
#                                                         {'cycle_or_t': 18,
#                                                          'note_name': 'A#3',
#                                                          't_values': 77.23},
#                                                         {'cycle_or_t': 19,
#                                                          'note_name': 'A#3',
#                                                          't_values': 81.52}],
#               'data-49589aa78c3e860de86e5a075d774f14': [{'before_last': 'G3',
#                                                          'cycle_or_t': 8,
#                                                          'cycle_or_t_end': 16,
#                                                          'note_name': 'D#3',
#                                                          'winners': 1},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 4,
#                                                          'cycle_or_t_end': 9,
#                                                          'note_name': 'D#3',
#                                                          'winners': 2},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 9,
#                                                          'cycle_or_t_end': 18,
#                                                          'note_name': 'D#3',
#                                                          'winners': 3},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 3,
#                                                          'cycle_or_t_end': 7,
#                                                          'note_name': 'D#3',
#                                                          'winners': 4},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 7,
#                                                          'cycle_or_t_end': 14,
#                                                          'note_name': 'D#3',
#                                                          'winners': 5},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 5,
#                                                          'cycle_or_t_end': 11,
#                                                          'note_name': 'D#3',
#                                                          'winners': 6},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 10,
#                                                          'cycle_or_t_end': 19,
#                                                          'note_name': 'D#3',
#                                                          'winners': 7},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 6,
#                                                          'cycle_or_t_end': 12,
#                                                          'note_name': 'D#3',
#                                                          'winners': 8},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 6,
#                                                          'cycle_or_t_end': 13,
#                                                          'note_name': 'D#3',
#                                                          'winners': 9},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 9,
#                                                          'cycle_or_t_end': 17,
#                                                          'note_name': 'D#3',
#                                                          'winners': 10}],
#               'data-81cde38493f8399483b3fb31a2d7e2bf': [{'bass_value': 0.06880061579348574,
#                                                          'cycle_or_t': 8,
#                                                          'cycle_or_t_end': 9,
#                                                          'note_name': 'C3',
#                                                          'winners': 1},
#                                                         {'bass_value': 0.0382225643297143,
#                                                          'cycle_or_t': 4,
#                                                          'cycle_or_t_end': 5,
#                                                          'note_name': 'C3',
#                                                          'winners': 2},
#                                                         {'bass_value': 0.0764451286594286,
#                                                          'cycle_or_t': 9,
#                                                          'cycle_or_t_end': 10,
#                                                          'note_name': 'C3',
#                                                          'winners': 3},
#                                                         {'bass_value': 0.03057805146377144,
#                                                          'cycle_or_t': 3,
#                                                          'cycle_or_t_end': 4,
#                                                          'note_name': 'C3',
#                                                          'winners': 4},
#                                                         {'bass_value': 0.06115610292754288,
#                                                          'cycle_or_t': 7,
#                                                          'cycle_or_t_end': 8,
#                                                          'note_name': 'C3',
#                                                          'winners': 5},
#                                                         {'bass_value': 0.04586707719565716,
#                                                          'cycle_or_t': 5,
#                                                          'cycle_or_t_end': 6,
#                                                          'note_name': 'C3',
#                                                          'winners': 6},
#                                                         {'bass_value': 0.08408964152537146,
#                                                          'cycle_or_t': 10,
#                                                          'cycle_or_t_end': 11,
#                                                          'note_name': 'C3',
#                                                          'winners': 7},
#                                                         {'bass_value': 0.05351159006160002,
#                                                          'cycle_or_t': 6,
#                                                          'cycle_or_t_end': 7,
#                                                          'note_name': 'C3',
#                                                          'winners': 8},
#                                                         {'bass_value': 0.05351159006160002,
#                                                          'cycle_or_t': 6,
#                                                          'cycle_or_t_end': 7,
#                                                          'note_name': 'C3',
#                                                          'winners': 9},
#                                                         {'bass_value': 0.0764451286594286,
#                                                          'cycle_or_t': 9,
#                                                          'cycle_or_t_end': 10,
#                                                          'note_name': 'C3',
#                                                          'winners': 10}]},
#  'layer': [{'encoding': {'x': {'axis': {'labelAngle': 0,
#                                         'orient': 'top',
#                                         'title': 'Note Name'},
#                                'field': 'note_name',
#                                'sort': ['C3', 'D#3', 'G3', 'A#3'],
#                                'type': 'nominal'},
#                          'y': {'axis': {'tickCount': 20, 'title': 'Cycle'},
#                                'field': 'cycle_or_t',
#                                'scale': {'domain': [0, 19], 'reverse': True},
#                                'type': 'quantitative'}},
#             'mark': {'color': 'white', 'stroke': 'black', 'type': 'rect'}},
#            {'encoding': {'text': {'field': 't_values', 'type': 'quantitative'},
#                          'x': {'field': 'note_name',
#                                'sort': ['C3', 'D#3', 'G3', 'A#3'],
#                                'type': 'nominal'},
#                          'y': {'axis': {'tickCount': 20, 'title': 'Cycle'},
#                                'field': 'cycle_or_t',
#                                'scale': {'domain': [0, 19], 'reverse': True},
#                                'type': 'quantitative'}},
#             'mark': {'baseline': 'bottom', 'type': 'text'}},
#            {'data': {'name': 'data-81cde38493f8399483b3fb31a2d7e2bf'},
#             'encoding': {'color': {'field': 'winners',
#                                    'scale': {'scheme': 'yellowgreen'},
#                                    'title': 'Winner Order Preference',
#                                    'type': 'ordinal'},
#                          'x': {'axis': {'labelAngle': 0,
#                                         'orient': 'top',
#                                         'title': 'Note Name'},
#                                'field': 'note_name',
#                                'sort': ['C3', 'D#3', 'G3', 'A#3'],
#                                'type': 'nominal'},
#                          'y': {'axis': {'tickCount': 20, 'title': 'Cycle'},
#                                'field': 'cycle_or_t',
#                                'scale': {'domain': [0, 19], 'reverse': True},
#                                'type': 'quantitative'},
#                          'y2': {'field': 'cycle_or_t_end'}},
#             'mark': {'type': 'rect'}},
#            {'data': {'name': 'data-1e1b582529a0fc5350aa86294e16bd02'},
#             'encoding': {'color': {'field': 'winners',
#                                    'scale': {},
#                                    'title': 'Winner Order Preference',
#                                    'type': 'ordinal'},
#                          'x': {'axis': {'labelAngle': 0,
#                                         'orient': 'top',
#                                         'title': 'Note Name'},
#                                'field': 'note_name',
#                                'sort': ['C3', 'D#3', 'G3', 'A#3'],
#                                'type': 'nominal'},
#                          'y': {'axis': {'tickCount': 20, 'title': 'Cycle'},
#                                'field': 'cycle_or_t',
#                                'scale': {'domain': [0, 19], 'reverse': True},
#                                'type': 'quantitative'},
#                          'y2': {'field': 'cycle_or_t_end'}},
#             'mark': {'type': 'rect'}},
#            {'data': {'name': 'data-49589aa78c3e860de86e5a075d774f14'},
#             'encoding': {'color': {'field': 'winners',
#                                    'scale': {'scheme': 'rainbow'},
#                                    'title': 'Winner Order Preference',
#                                    'type': 'ordinal'},
#                          'x': {'bandPosition': 0,
#                                'field': 'note_name',
#                                'sort': ['C3', 'D#3', 'G3', 'A#3'],
#                                'type': 'nominal'},
#                          'x2': {'bandPosition': 1, 'field': 'before_last'},
#                          'y': {'axis': {'tickCount': 20, 'title': 'Cycle'},
#                                'field': 'cycle_or_t',
#                                'scale': {'domain': [0, 19], 'reverse': True},
#                                'type': 'quantitative'},
#                          'y2': {'field': 'cycle_or_t_end'}},
#             'mark': {'baseline': 'middle',
#                      'filled': False,
#                      'strokeOpacity': 0.5,
#                      'strokeWidth': 2,
#                      'type': 'rect'}},
#            {'data': {'name': 'data-3bf4e51a39332d5b9a3693ed1af79138'},
#             'encoding': {'text': {'field': 't_values', 'type': 'quantitative'},
#                          'x': {'field': 'note_name',
#                                'sort': ['C3', 'D#3', 'G3', 'A#3'],
#                                'type': 'nominal'},
#                          'y': {'axis': {'tickCount': 20, 'title': 'Cycle'},
#                                'field': 'cycle_or_t',
#                                'scale': {'domain': [0, 19], 'reverse': True},
#                                'type': 'quantitative'}},
#             'mark': {'baseline': 'bottom', 'type': 'text'}}],
#  'width': 250}

# %%
t_value_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 t_value_df
#
# NameError: name 't_value_df' is not defined

# %%
type_of_note_and_cycle.join(t_value_df, on=['winners','index'])
type_of_note_and_cycle
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[164], line 1
# ----> 1 type_of_note_and_cycle.join(t_value_df, on=['winners','index'])
#       2 type_of_note_and_cycle
#
# NameError: name 'type_of_note_and_cycle' is not defined

# %% [markdown]
# Faceted delta t and t sub

# %%
#notes 
note_name_mega_array = [
    # ['C3','C4'],
    # ['C3','G3'],
    # ['C3','E3'],
    ['C3', 'E3','G3'],
    ['C3', 'D#3','G3'],
    ['C3','E3','G#3'],
    ['C3','D#3','F#3'],
    ['C3','E3','F#3'],
    ['C3','D3','G3'],
     ['C3','C#3','G#3'],
    # ['C3','D#3'],

    # ['C3','G#3'],
    
    # ['C3','F#3'],
  
    # ['C3','D3'],
    # ['C3','C#3'],
   
    

]

titles=[
        # 'Octave',
        # 'Fifth',
        # 'Major Third',
        'Major Triad',
       
        
        'Minor Triad',
        'Augmented Fifth Triad',
        'Diminished Fifth Triad',
        'Flat Fifth Triad',
        'Suspended 2nd Triad',
        'Maj7th inversion without 3rd',
        
        # 'Minor Third',
        # 'Minor Sixth',
        
        # 'Diminished Fifth',
        
        # 'Major 2nd',
        # 'Minor 2nd',
        

        ]

# %% [markdown]
# Now loop through each and create a graph

# %%
def generate_observable_df(note_names, fundamental_df, max_number_of_observable_metrics,max=20, metric_to_sort_by='difference_ratio'):
    period_df = calculate_period_dataframe(note_names,fundamental_df,max=max)
    bound_df = finding_min_difference_with_lower_upper_bound(period_df)
    bound_df.sort_values(by='ratio', ascending=True, inplace=True)
    each_pair = choosing_bounds_binary_search(period_df,bound_df)
    observable_metrics=[]
    for item in each_pair:
        observable_metrics.append(item['observable_metrics'])
    sorted_observable_metrics = sorted(observable_metrics, key=lambda x: x[metric_to_sort_by])
    return pd.DataFrame(sorted_observable_metrics[:max_number_of_observable_metrics])

# %%
generate_observable_df( ['B2','F#3','B3','F#4','B4','D5'],fundamental_df, max_number_of_observable_metrics=5,max=20)
# Out:
#                                             t_values  mean_t_sub  std_normed  \
# 0  [0.0382225643297143, 0.03783840820463204, 0.03...    0.032278    0.430108
# 1  [0.0764451286594286, 0.07567681640926407, 0.07...    0.064556    0.430108
# 2  [0.05351159006160002, 0.05405486886376005, 0.0...    0.046240    0.420223
# 3  [0.06880061579348574, 0.07027132952288806, 0.0...    0.060203    0.415426
# 4  [0.06115610292754288, 0.06486584263651206, 0.0...    0.053672    0.422259
#
#                        indices  difference  difference_ratio
# 0       [4.0, 6, 8, 8, 8, 8.0]    0.020390          0.631705
# 1  [9.0, 13, 17, 17, 17, 17.0]    0.040780          0.631705
# 2   [6.0, 9, 12, 12, 12, 12.0]    0.029452          0.636940
# 3  [8.0, 12, 16, 16, 16, 16.0]    0.038515          0.639747
# 4  [7.0, 11, 14, 14, 14, 14.0]    0.034494          0.642685

# %%
def obs_metric_to_list_of_dict(observable_df):
    columns = list(observable_df.columns)
    list_of_dicts = []
    for i,row in observable_df.iterrows():
        list_of_dicts.append(row.to_dict())
    
    return list_of_dicts

# %%
take_period_def_extract_winners(period_df,obs_metric_to_list_of_dict(observable_df))
# Out:
# {'t_values': [0.01528902573188572, 0.0128564869306645, 0.015306300658764179, 0.012871013354750365], 'mean_t_sub': 0.014080706669016192, 'std_normed': 0.5736152715746295, 'indices': [1.0, 1, 2, 2.0], 'difference': 0.002449813728099678, 'difference_ratio': 0.17398372011330626, 'order': 1, 't_value_min': 0.0128564869306645, 't_value_max': 0.015306300658764179, 'max_cycle': 2.0}
# indices: [1.0, 1, 2, 2.0]
# values: [0.01528902573188572, 0.0128564869306645, 0.015306300658764179, 0.012871013354750365]
# {'t_values': [0.03057805146377144, 0.03214121732666125, 0.030612601317528357, 0.03003236449441752], 'mean_t_sub': 0.030841058650594638, 'std_normed': 0.42990142473837273, 'indices': [3.0, 4, 5, 6.0], 'difference': 0.0021088528322437336, 'difference_ratio': 0.0683780948032753, 'order': 2, 't_value_min': 0.03003236449441752, 't_value_max': 0.03214121732666125, 'max_cycle': 6.0}
# indices: [3.0, 4, 5, 6.0]
# values: [0.03057805146377144, 0.03214121732666125, 0.030612601317528357, 0.03003236449441752]
# {'t_values': [0.04586707719565716, 0.04499770425732575, 0.04591890197629254, 0.04719371563408468], 'mean_t_sub': 0.04599434976584003, 'std_normed': 0.4118252683853573, 'indices': [5.0, 6, 8, 10.0], 'difference': 0.0021960113767589273, 'difference_ratio': 0.04774524235996273, 'order': 3, 't_value_min': 0.04499770425732575, 't_value_max': 0.04719371563408468, 'max_cycle': 10.0}
# indices: [5.0, 6, 8, 10.0]
# values: [0.04586707719565716, 0.04499770425732575, 0.04591890197629254, 0.04719371563408468]
# {'t_values': [0.05351159006160002, 0.051425947722658, 0.0510210021958806, 0.05148405341900146], 'mean_t_sub': 0.051860648349785016, 'std_normed': 0.4495856218363726, 'indices': [6.0, 7, 9, 11.0], 'difference': 0.002490587865719422, 'difference_ratio': 0.048024618761437966, 'order': 4, 't_value_min': 0.0510210021958806, 't_value_max': 0.05351159006160002, 'max_cycle': 11.0}
# indices: [6.0, 7, 9, 11.0]
# values: [0.05351159006160002, 0.051425947722658, 0.0510210021958806, 0.05148405341900146]
# {'t_values': [0.0764451286594286, 0.077138921583987, 0.0765315032938209, 0.0772260801285022], 'mean_t_sub': 0.07683540841643467, 'std_normed': 0.5171978772513034, 'indices': [9.0, 11, 14, 17.0], 'difference': 0.0007809514690736014, 'difference_ratio': 0.010163952859350718, 'order': 5, 't_value_min': 0.0764451286594286, 't_value_max': 0.0772260801285022, 'max_cycle': 17.0}
# indices: [9.0, 11, 14, 17.0]
# values: [0.0764451286594286, 0.077138921583987, 0.0765315032938209, 0.0772260801285022]
#    note_name  t_values  cycle_or_t  winner_num
# 0         C3  0.015289         1.0           1
# 1        D#3  0.012856         1.0           1
# 2         G3  0.015306         2.0           1
# 3        A#3  0.012871         2.0           1
# 4         C3  0.030578         3.0           2
# 5        D#3  0.032141         4.0           2
# 6         G3  0.030613         5.0           2
# 7        A#3  0.030032         6.0           2
# 8         C3  0.045867         5.0           3
# 9        D#3  0.044998         6.0           3
# 10        G3  0.045919         8.0           3
# 11       A#3  0.047194        10.0           3
# 12        C3  0.053512         6.0           4
# 13       D#3  0.051426         7.0           4
# 14        G3  0.051021         9.0           4
# 15       A#3  0.051484        11.0           4
# 16        C3  0.076445         9.0           5
# 17       D#3  0.077139        11.0           5
# 18        G3  0.076532        14.0           5
# 19       A#3  0.077226        17.0           5

# %%
def create_chart_for_facet(observable_df, x='mean_t_sub',y='difference_ratio'):
    chart = alt.Chart(observable_df).mark_line().encode(
        x=alt.X(x, ),
        y=alt.Y(y, ),
        # color=alt.Color('difference_ratio', title='Difference Ratio'),
        tooltip=['t_values','mean_t_sub','std_normed','difference_ratio']
    ).properties(
        width=200,
        height=200
    )

    chart += alt.Chart(observable_df).mark_point().encode(
        x=alt.X(x, ),
        y=alt.Y(y, ),
        # color=alt.Color('difference_ratio', title='Difference Ratio'),
        tooltip=['t_values','mean_t_sub','std_normed','difference_ratio']
    ).properties(
        width=200,
        height=200
    )

    max_tsub = max(observable_df['mean_t_sub'])
    min_tsub = min(observable_df['mean_t_sub'])

    line_chart = alt.Chart(observable_df).mark_point().encode(
        y=alt.Y('difference_ratio'),
        color=alt.Color('mean_t_sub:Q', title='Mean Period', scale=alt.Scale(domain=[max_tsub, min_tsub])),
    )


    
    return (chart)

# %%
def create_facet_chart(note_name_mega_array,titles , fundamental_df, max_number_of_observable_metrics,max=50,x='mean_t_sub',y='difference_ratio'):
    for i, note_names in enumerate(note_name_mega_array):
        observable_df = generate_observable_df(note_names, fundamental_df, max_number_of_observable_metrics,max=max)
        observable_df['title'] = titles[i]
        observable_df['row']= i//3
        if i == 0:
            all_observable_df = observable_df
        else:
            all_observable_df = pd.concat([all_observable_df, observable_df], ignore_index=True)

    all_observable_df['title'] = all_observable_df['title'].astype('category')
    return create_chart_for_facet(all_observable_df,x=x,y=y).facet(
        'title', align='each', columns=3), all_observable_df

# %%
create_facet_chart(note_name_mega_array,titles , fundamental_df, max_number_of_observable_metrics=15,max=50)
# Out:
# (alt.FacetChart(...),
#                                                t_values  mean_t_sub  \
#  0    [0.03057805146377144, 0.03033726941295533, 0.0...    0.030316
#  1    [0.06115610292754288, 0.06067453882591066, 0.0...    0.060632
#  2    [0.06880061579348574, 0.06674199270850173, 0.0...    0.068063
#  3    [0.0764451286594286, 0.07887690047368386, 0.07...    0.077516
#  4    [0.08408964152537146, 0.08494435435627493, 0.0...    0.083517
#  ..                                                 ...         ...
#  100  [0.04586707719565716, 0.04329275596276908, 0.0...    0.044021
#  101  [0.06880061579348574, 0.06493913394415363, 0.0...    0.066032
#  102  [0.0382225643297143, 0.0360772966356409, 0.038...    0.037638
#  103  [0.05351159006160002, 0.05772367461702544, 0.0...    0.055670
#  104  [0.08408964152537146, 0.07937005259840998, 0.0...    0.080229
#
#       std_normed           indices  difference  difference_ratio  \
#  0      0.501149     [3.0, 4, 6.0]    0.000546          0.018000
#  1      0.501149    [7.0, 9, 13.0]    0.001091          0.018000
#  2      0.556863   [8.0, 10, 15.0]    0.002059          0.030246
#  3      0.510552   [9.0, 12, 17.0]    0.002432          0.031371
#  4      0.520523  [10.0, 13, 18.0]    0.003428          0.041045
#  ..          ...               ...         ...               ...
#  100    0.543409     [5.0, 5, 9.0]    0.002964          0.067325
#  101    0.543409    [8.0, 8, 14.0]    0.004446          0.067325
#  102    0.538431     [4.0, 4, 8.0]    0.002536          0.067373
#  103    0.500461    [6.0, 7, 12.0]    0.004212          0.075662
#  104    0.511600  [10.0, 10, 17.0]    0.006864          0.085550
#
#                              title  row
#  0                     Major Triad    0
#  1                     Major Triad    0
#  2                     Major Triad    0
#  3                     Major Triad    0
#  4                     Major Triad    0
#  ..                            ...  ...
#  100  Maj7th inversion without 3rd    2
#  101  Maj7th inversion without 3rd    2
#  102  Maj7th inversion without 3rd    2
#  103  Maj7th inversion without 3rd    2
#  104  Maj7th inversion without 3rd    2
#
#  [105 rows x 8 columns])

# %%
##testing something on facet
## Using https://nikolasborrel.github.io/about/src/cremo/borrel_jensen_harmonization2009.pdf

chords_to_test = [
    ['C3','E3','G3'],
    ['C3','D#3','G3'],
    ['C3','F3','G3'],
    ['C3','D3','G3'],
    ['C3','D#3','F#3'],
    ['C3','E3','G#3'],
    

]
titles = [
    'C Major Triad',
    'C Minor Triad',
    
    'C Suspended 4th Triad',
    'C Suspended 2nd Triad',
    'C Diminished Triad',
    'C Augmented Triad',
]

fc,obs_df = create_facet_chart(chords_to_test,titles , fundamental_df, max_number_of_observable_metrics=5,max=50,x='mean_t_sub',y='difference_ratio')
fc
# Out:
# alt.FacetChart(...)

# %% [markdown]
# ## Resolve bugs later, now make one by one graphs

# %%
chords_to_test = [
    ['C3','E3','G3'],
    ['C3','D#3','G3'],
    # ['C3','F3','G3'],
    # ['C3','D3','G3'],
    ['C3','D#3','F#3'],
    ['C3','E3','G#3'],
    ['C3','E3','G3','A#3'],
    ['C3','D#3','G3','A#3'],
    ['C3','E3','G3','B3'],
   
    

]
titles = [
    'C Major Triad',
    'C Minor Triad',
    
    # 'C Suspended 4th Triad',
    # 'C Suspended 2nd Triad',
    'C Diminished Triad',
    'C Augmented Triad',
    'C Dominant 7th Chord',
    'C Minor 7th Chord',
    'C Major 7th Chord',
]

# %%
max_number_of_observable_metrics=30
metric_sort_by = 'mean_t_sub'  # 'difference_ratio' or 'mean_t_sub'
for chord_index in range(len(chords_to_test)):
    chord = chords_to_test[chord_index]
    title = titles[chord_index]

    period_df = calculate_period_dataframe(chord, fundamental_df, max=50)
    bound_df = finding_min_difference_with_lower_upper_bound(period_df)
    bound_df.sort_values(by='ratio', ascending=True, inplace=True)
    each_pair = choosing_bounds_binary_search(period_df, bound_df)
    observable_metrics = []
    for item in each_pair:
        observable_metrics.append(item['observable_metrics'])
    sorted_observable_metrics = sorted(observable_metrics, key=lambda x: x[metric_sort_by])
    observable_df = pd.DataFrame(sorted_observable_metrics[:max_number_of_observable_metrics])
    observable_df.sort_values(by='mean_t_sub', inplace=True)

    ## adding 1,2,3, order values to sorted by mean
    observable_df['order'] = range(1, max_number_of_observable_metrics + 1)
    ## adding min t_value to observable_df,
    observable_df['t_value_min'] = [min(r['t_values']) for i, r in observable_df.iterrows()]
    observable_df['t_value_max'] = [max(r['t_values']) for i, r in observable_df.iterrows()]
    add_max_cycle(observable_df)

    # adding row and title

    if chord_index == 0:
        chart = create_chart_for_facet(observable_df, x='mean_t_sub', y='difference_ratio').properties(
            title=title,
            width=300,
            height=250
        )
    else:
        chart = (chart | create_chart_for_facet(observable_df, x='mean_t_sub', y='difference_ratio').properties(
            title=title,
            width=300,
            height=250
        )).resolve_scale(
            y='shared',
            x='shared'
        )
chart
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 28
#      25 # adding row and title
#      27 if chord_index == 0:
# ---> 28     chart = create_chart_for_facet(observable_df, x='mean_t_sub', y='difference_ratio').properties(
#      29         title=title,
#      30         width=300,
#      31         height=250
#      32     )
#      33 else:
#      34     chart = (chart | create_chart_for_facet(observable_df, x='mean_t_sub', y='difference_ratio').properties(
#      35         title=title,
#      36         width=300,
#    (...)     40         x='shared'
#      41     )
#
# NameError: name 'create_chart_for_facet' is not defined

# %% [markdown]
# #

# %% [markdown]
# ## finding properties
# What if under the curve of delta t and t sub have to do with chord tension.
# - sum(Difference) / max tsub: one would expect that a lower sum (i.e. more points with small values) indicates less tension
# - sum(difference_ratio)/max_tsub : this adds a higher layer meaning, that smaller values at shorter time periods have more impact on consonance

# %%
max_number_of_observable_metrics=30
metric_sort_by = 'mean_t_sub'  # 'difference_ratio' or 'mean_t_sub'


chord_df_dif_sum = {
    'chord':[],
    'dif_sum':[],
    'max_tsub':[],
    'area_under_curve_dif_only':[],
    'dif_sum_ratio_max_tsub':[],
    'dif_sum_ratio_sum_mean_sub':[],
    'area_under_curve_dif_ratio_max_tsub':[],
    'area_under_curve_dif_ratio_sum_mean_sub':[],
}
for chord_index in range(len(chords_to_test)):
    chord = chords_to_test[chord_index]
    title = titles[chord_index]

    period_df = calculate_period_dataframe(chord, fundamental_df, max=50)
    bound_df = finding_min_difference_with_lower_upper_bound(period_df)
    bound_df.sort_values(by='ratio', ascending=True, inplace=True)
    each_pair = choosing_bounds_binary_search(period_df, bound_df)
    observable_metrics = []
    for item in each_pair:
        observable_metrics.append(item['observable_metrics'])
    sorted_observable_metrics = sorted(observable_metrics, key=lambda x: x[metric_sort_by])
    print(sorted_observable_metrics[:max_number_of_observable_metrics])
    # break
    observable_df = pd.DataFrame(sorted_observable_metrics[:max_number_of_observable_metrics])
    observable_df.sort_values(by='mean_t_sub', inplace=True)

    ## adding 1,2,3, order values to sorted by mean
    observable_df['order'] = range(1, max_number_of_observable_metrics + 1)
    ## adding min t_value to observable_df,
    observable_df['t_value_min'] = [min(r['t_values']) for i, r in observable_df.iterrows()]
    observable_df['t_value_max'] = [max(r['t_values']) for i, r in observable_df.iterrows()]
    add_max_cycle(observable_df)


    ### summing differences and dividing with max_t_sub (this means summing difference_ratio * t_sub)/t_sub but (dif/tsub * tisub is dif)
    dif_sum = observable_df['difference'].sum()
    chord_df_dif_sum['chord'].append(title)
    chord_df_dif_sum['dif_sum'].append(dif_sum)
    chord_df_dif_sum['dif_sum_ratio_sum_mean_sub'].append(dif_sum / observable_df['mean_t_sub'].sum())
    chord_df_dif_sum['dif_sum_ratio_max_tsub'].append(dif_sum / observable_df['mean_t_sub'].max())
    chord_df_dif_sum['max_tsub'].append(max(observable_df['mean_t_sub']))
    chord_df_dif_sum['area_under_curve_dif_only'].append(observable_df['difference'].sum() * chord_df_dif_sum['max_tsub'][-1])
    chord_df_dif_sum['area_under_curve_dif_ratio_max_tsub'].append(observable_df['difference_ratio'].sum() * chord_df_dif_sum['max_tsub'][-1])
    chord_df_dif_sum['area_under_curve_dif_ratio_sum_mean_sub'].append(observable_df['difference_ratio'].sum() * observable_df['mean_t_sub'].sum())


   
chord_df_dif_sum = pd.DataFrame(chord_df_dif_sum)
chord_df_dif_sum.sort_values(by='area_under_curve_dif_ratio_max_tsub', ascending=False, inplace=True)
chord_df_dif_sum.reset_index(drop=True, inplace=True)
chord_df_dif_sum
# Out:
# [{'t_values': [0.00764451286594286, 0.006067453882591066, 0.00510210021958806], 'mean_t_sub': 0.006271355656040661, 'std_normed': 0.5048009936713209, 'indices': [0.0, 0, 0.0], 'difference': 0.0025424126463548004, 'difference_ratio': 0.4054008073845902}, {'t_values': [0.00764451286594286, 0.006067453882591066, 0.01020420043917612], 'mean_t_sub': 0.007972055729236682, 'std_normed': 0.5046800655119892, 'indices': [0.0, 0, 1.0], 'difference': 0.004136746556585053, 'difference_ratio': 0.518905875358343}, {'t_values': [0.01528902573188572, 0.012134907765182132, 0.01020420043917612], 'mean_t_sub': 0.012542711312081322, 'std_normed': 0.5048009936713209, 'indices': [1.0, 1, 1.0], 'difference': 0.005084825292709601, 'difference_ratio': 0.4054008073845902}, {'t_values': [0.01528902573188572, 0.018202361647773196, 0.015306300658764179], 'mean_t_sub': 0.016265896012807698, 'std_normed': 0.5756461750895879, 'indices': [1.0, 2, 2.0], 'difference': 0.0029133359158874765, 'difference_ratio': 0.1791070048396675}, {'t_values': [0.02293353859782858, 0.018202361647773196, 0.015306300658764179], 'mean_t_sub': 0.018814066968121986, 'std_normed': 0.504800993671321, 'indices': [2.0, 2, 2.0], 'difference': 0.007627237939064403, 'difference_ratio': 0.4054008073845902}, {'t_values': [0.02293353859782858, 0.024269815530364263, 0
, {'t_values': [0.02293353859782858, 0.024269815530364263, 0.02040840087835224, 0.020247698139553162], 'mean_t_sub': 0.021964863286524562, 'std_normed': 0.48936391659224016, 'indices': [2.0, 3, 3, 4.0], 'difference': 0.004022117390811101, 'difference_ratio': 0.18311597656420056}, {'t_values': [0.02293353859782858, 0.024269815530364263, 0.0255105010979403, 0.024297237767463797], 'mean_t_sub': 0.024252773248399237, 'std_normed': 0.40850389532612985, 'indices': [2.0, 3, 4, 5.0], 'difference': 0.002576962500111718, 'difference_ratio': 0.106254343522624}, {'t_values': [0.03057805146377144, 0.03033726941295533, 0.0255105010979403, 0.024297237767463797], 'mean_t_sub': 0.027680764935532717, 'std_normed': 0.5168123324589844, 'indices': [3.0, 4, 4, 5.0], 'difference': 0.006280813696307643, 'difference_ratio': 0.22690173884050466}, {'t_values': [0.03057805146377144, 0.03033726941295533, 0.030612601317528357, 0.02834677739537443], 'mean_t_sub': 0.02996867489740739, 'std_normed': 0.48025711416693984, 'indices': [3.0, 4, 5, 6.0], 'difference': 0.0022658239221539263, 'difference_ratio': 0.0756064100234857}, {'t_values': [0.03057805146377144, 0.03033726941295533, 0.030612601317528357, 0.03239631702328506], 'mean_t_sub': 0.030981059804385046, 'std_normed': 0.4620676877428658, 'indices': [3.0, 4, 5, 7.0], 'difference': 0.0020590476103297325, 'difference_ratio': 0.06646149690587072}, {'t_values': [0.0382225643297143, 0.03640472329554639, 0.035714701537116415, 0.03239631702328506], 'mean_t_sub': 0.03568457654641555, 'std_normed': 0.4177703041976908, 'indices': [4.0, 5, 6, 7.0], 'difference': 0.005826247306429236, 'difference_ratio': 0.16327074244109174}, {'t_values': [0.0382225643297143, 0.03640472329554639, 0.035714701537116415, 0.03644585665119569], 'mean_t_sub': 0.0366969614533932, 'std_normed': 0.4270340478983289, 'indices': [4.0, 5, 6, 8.0], 'difference': 0.0025078627925978828, 'difference_ratio': 0.0683397941756835}, {'t_values': [0.0382225643297143, 0.03640472329554639, 0.04081680175670448, 0.040495396279106324], 'mean_t_sub': 0.03898487141526787, 'std_normed': 0.46955390691419424, 'indices': [4.0, 5, 7, 9.0], 'difference': 0.004412078461158084, 'difference_ratio': 0.11317411860002072}, {'t_values': [0.04586707719565716, 0.04247217717813746, 0.04081680175670448, 0.040495396279106324], 'mean_t_sub': 0.0424 ...
#                   chord   dif_sum  max_tsub  area_under_curve_dif_only  \
# 0     C Major 7th Chord  0.121561  0.082915                   0.010079
# 1         C Major Triad  0.123935  0.096099                   0.011910
# 2         C Minor Triad  0.124710  0.095880                   0.011957
# 3  C Dominant 7th Chord  0.116731  0.085394                   0.009968
# 4     C Minor 7th Chord  0.118302  0.085050                   0.010062
# 5    C Diminished Triad  0.117566  0.097700                   0.011486
# 6     C Augmented Triad  0.110792  0.091415                   0.010128
#
#    dif_sum_ratio_max_tsub  dif_sum_ratio_sum_mean_sub  \
# 0                1.466093                    0.092199
# 1                1.289669                    0.081086
# 2                1.300689                    0.081908
# 3                1.366970                    0.085412
# 4                1.390974                    0.086396
# 5                1.203333                    0.075295
# 6                1.211970                    0.075580
#
#    area_under_curve_dif_ratio_max_tsub  \
# 0                             0.380719
# 1                             0.376823
# 2                             0.372933
# 3                             0.368127
# 4                             0.363792
# 5                             0.363100
# 6                             0.346354
#
#    area_under_curve_dif_ratio_sum_mean_sub
# 0                                 6.053936
# 1                                 5.993353
# 2                                 5.922128
# 3                                 5.891646
# 4                                 5.857020
# 5                                 5.802906
# 6                                 5.553960

# %% [markdown]
# ## Science?

# %% [markdown]
# Lets see what delta t sum gives.

# %%
max_number_of_observable_metrics=3
metric_sort_by = 'difference_ratio'  # 'difference_ratio' or 'mean_t_sub'


chord_df_dif_sum = {
    'chord':[],
    'dif_sum':[],
    'max_tsub':[],
    'delta_t_hat_sum(science)':[],
    'delta_t_hat_max_tsub_mul':[],
    'delta_t_hat_max_tsub_div':[],
    'points_considered':[]


}
for chord_index in range(len(chords_to_test)):
    chord = chords_to_test[chord_index]
    title = titles[chord_index]

    period_df = calculate_period_dataframe(chord, fundamental_df, max=5)
    bound_df = finding_min_difference_with_lower_upper_bound(period_df)
    bound_df.sort_values(by='ratio', ascending=True, inplace=True)
    each_pair = choosing_bounds_binary_search(period_df, bound_df)
    observable_metrics = []
    for item in each_pair:
        observable_metrics.append(item['observable_metrics'])
    sorted_observable_metrics = sorted(observable_metrics, key=lambda x: x[metric_sort_by])
    observable_df = pd.DataFrame(sorted_observable_metrics[:max_number_of_observable_metrics])
    observable_df.sort_values(by='mean_t_sub', inplace=True)
    

    ## adding 1,2,3, order values to sorted by mean
    observable_df['order'] = range(1, max_number_of_observable_metrics + 1)
    ## adding min t_value to observable_df,
    observable_df['t_value_min'] = [min(r['t_values']) for i, r in observable_df.iterrows()]
    observable_df['t_value_max'] = [max(r['t_values']) for i, r in observable_df.iterrows()]
    add_max_cycle(observable_df)


    ### summing differences and dividing with max_t_sub (this means summing difference_ratio * t_sub)/t_sub but (dif/tsub * tisub is dif)
    dif_sum = observable_df['difference_ratio'].sum()
    chord_df_dif_sum['points_considered'] =  observable_df['difference_ratio'].count()
    chord_df_dif_sum['chord'].append(title)
    chord_df_dif_sum['dif_sum'].append(dif_sum)

    chord_df_dif_sum['max_tsub'].append(max(observable_df['mean_t_sub']))
    chord_df_dif_sum['delta_t_hat_sum(science)'].append(max_number_of_observable_metrics/dif_sum)
    chord_df_dif_sum['delta_t_hat_max_tsub_mul'].append((1/dif_sum) * chord_df_dif_sum['max_tsub'][-1])
    chord_df_dif_sum['delta_t_hat_max_tsub_div'].append((1/dif_sum) / chord_df_dif_sum['max_tsub'][-1])
    



   
chord_df_dif_sum = pd.DataFrame(chord_df_dif_sum)
chord_df_dif_sum.sort_values(by='delta_t_hat_max_tsub_div', ascending=False, inplace=True)
chord_df_dif_sum.reset_index(drop=True, inplace=True)
chord_df_dif_sum
# Out:
#                   chord   dif_sum  max_tsub  delta_t_hat_sum(science)  \
# 0  C Dominant 7th Chord  0.698184  0.019676                  4.296863
# 1     C Augmented Triad  0.686971  0.020133                  4.366994
# 2     C Minor 7th Chord  0.701762  0.019947                  4.274953
# 3     C Major 7th Chord  0.756998  0.019436                  3.963023
# 4         C Minor Triad  0.741701  0.020876                  4.044754
# 5    C Diminished Triad  0.743536  0.021280                  4.034774
# 6         C Major Triad  0.755843  0.022537                  3.969080
#
#    delta_t_hat_max_tsub_mul  delta_t_hat_max_tsub_div  points_considered
# 0                  0.028182                 72.792111                  3
# 1                  0.029307                 72.302579                  3
# 2                  0.028424                 71.438515                  3
# 3                  0.025675                 67.968397                  3
# 4                  0.028145                 64.585169                  3
# 5                  0.028620                 63.201128                  3
# 6                  0.029817                 58.704000                  3

# %% [markdown]
# Lets see, what if we calculate auc using metrics.

# %%
max_number_of_observable_metrics=30
metric_sort_by = 'mean_t_sub'  # 'difference_ratio' or 'mean_t_sub'

N_squares =1000

chord_df_dif_sum = {
    'chord':[],
    'weighted_sum_by_distances':[],
    'max_tsub':[],
    'area_under_curve':[],
  
}
for chord_index in range(len(chords_to_test)):
    chord = chords_to_test[chord_index]
    title = titles[chord_index]

    period_df = calculate_period_dataframe(chord, fundamental_df, max=50)
    bound_df = finding_min_difference_with_lower_upper_bound(period_df)
    bound_df.sort_values(by='ratio', ascending=True, inplace=True)
    each_pair = choosing_bounds_binary_search(period_df, bound_df)
    observable_metrics = []
    for item in each_pair:
        observable_metrics.append(item['observable_metrics'])
    sorted_observable_metrics = sorted(observable_metrics, key=lambda x: x[metric_sort_by])
    observable_df = pd.DataFrame(sorted_observable_metrics[:max_number_of_observable_metrics])
    observable_df.sort_values(by='mean_t_sub', inplace=True)

    ## adding 1,2,3, order values to sorted by mean
    observable_df['order'] = range(1, max_number_of_observable_metrics + 1)
    ## adding min t_value to observable_df,
    observable_df['t_value_min'] = [min(r['t_values']) for i, r in observable_df.iterrows()]
    observable_df['t_value_max'] = [max(r['t_values']) for i, r in observable_df.iterrows()]
    add_max_cycle(observable_df)

    ## now we calculate the weighted sum by distances
    sum_by_distance =0 
    prev_distance = 0
    for i, row in observable_df.iterrows():
        delta_t = row['difference']
        middle_point = (prev_distance + row['difference']) / 2
        middle_point_difference = abs(prev_distance - row['difference'])
        sum_by_distance += middle_point * middle_point_difference
        prev_distance = row['difference']
    chord_df_dif_sum['chord'].append(title)
    chord_df_dif_sum['weighted_sum_by_distances'].append(sum_by_distance/observable_df['mean_t_sub'].sum())
    chord_df_dif_sum['max_tsub'].append(max(observable_df['mean_t_sub']))
    chord_df_dif_sum['area_under_curve'].append(sum_by_distance * chord_df_dif_sum['max_tsub'][-1])

chord_df_dif_sum = pd.DataFrame(chord_df_dif_sum)
chord_df_dif_sum.sort_values(by='weighted_sum_by_distances', ascending=False, inplace=True)

chord_df_dif_sum
# Out:
#                   chord  weighted_sum_by_distances  max_tsub  area_under_curve
# 1         C Minor Triad                   0.000276  0.095880          0.000040
# 0         C Major Triad                   0.000271  0.096099          0.000040
# 6     C Major 7th Chord                   0.000233  0.082915          0.000025
# 3     C Augmented Triad                   0.000204  0.091415          0.000027
# 2    C Diminished Triad                   0.000201  0.097700          0.000031
# 5     C Minor 7th Chord                   0.000191  0.085050          0.000022
# 4  C Dominant 7th Chord                   0.000191  0.085394          0.000022

# %% [markdown]
# # transitional overlay, de un ii V I

# %%
chords_to_test = [
    ['C3','E3','G3'],
    ['C3','D#3','G3'],
    # ['C3','F3','G3'],
    # ['C3','D3','G3'],
    ['C3','D#3','F#3'],
    ['C3','E3','G#3'],
    ['C3','E3','G3','A#3'],
    ['C3','D#3','G3','A#3'],
    ['C3','E3','G3','B3'],
   
    

]
titles = [
    'C Major Triad',
    'C Minor Triad',
    
    # 'C Suspended 4th Triad',
    # 'C Suspended 2nd Triad',
    'C Diminished Triad',
    'C Augmented Triad',
    'C Dominant 7th Chord',
    'C Minor 7th Chord',
    'C Major 7th Chord',
]

# %%
max_number_of_observable_metrics=20
metric_sort_by = 'mean_t_sub'  # 'difference_ratio' or 'mean_t_sub'
max_considered_periods = 100
for chord_index in range(len(chords_to_test)):
    chord = chords_to_test[chord_index]
    title = titles[chord_index]

    period_df = calculate_period_dataframe(chord, fundamental_df, max_considered_periods)
    bound_df = finding_min_difference_with_lower_upper_bound(period_df)
    bound_df.sort_values(by='ratio', ascending=True, inplace=True)
    each_pair = choosing_bounds_binary_search(period_df, bound_df)
    observable_metrics = []
    for item in each_pair:
        observable_metrics.append(item['observable_metrics'])
    sorted_observable_metrics = sorted(observable_metrics, key=lambda x: x[metric_sort_by])
    observable_df = pd.DataFrame(sorted_observable_metrics[:max_number_of_observable_metrics])
    observable_df.sort_values(by='mean_t_sub', inplace=True)

    ## adding 1,2,3, order values to sorted by mean
    observable_df['order'] = range(1, max_number_of_observable_metrics + 1)
    ## adding min t_value to observable_df,
    observable_df['t_value_min'] = [min(r['t_values']) for i, r in observable_df.iterrows()]
    observable_df['t_value_max'] = [max(r['t_values']) for i, r in observable_df.iterrows()]
    add_max_cycle(observable_df)

    # adding row and title

    if chord_index == 0:
        chart = create_chart_for_facet(observable_df, x='mean_t_sub', y='difference_ratio').properties(
            title=title,
            width=300,
            height=250
        )
    else:
        chart_overlay1 = (chart + create_chart_for_facet(observable_df, x='mean_t_sub', y='difference_ratio').properties(
            title=title,
            width=300,
            height=250,
            color='red'
        )).resolve_scale(
            y='shared',
            x='shared'
        )
        
chart
# Out:
# alt.LayerChart(...)

# %%
chords_to_test = [
    ['C3','E3','G3'],
    ['C3','D#3','G3'],
    # ['C3','F3','G3'],
    # ['C3','D3','G3'],
    ['C3','D#3','F#3'],
    ['C3','E3','G#3'],
    ['C3','E3','G3','A#3'],
    ['C3','D#3','G3','A#3'],
    ['C3','E3','G3','B3'],
   
    

]
titles = [
    'C Major Triad',
    'C Minor Triad',
    
    # 'C Suspended 4th Triad',
    # 'C Suspended 2nd Triad',
    'C Diminished Triad',
    'C Augmented Triad',
    'C Dominant 7th Chord',
    'C Minor 7th Chord',
    'C Major 7th Chord',
]

# %%
chords_to_test = [
    ['C3','E3','G3'],
    ['C3','D#3','G3'],
    ['C3','F3','G3'],
    ['C3','D3','G3'],
    ['C3','D#3','F#3'],
    ['C3','E3','G#3'],
    

]
titles = [
    'C Major Triad',
    'C Minor Triad',
    
    'C Suspended 4th Triad',
    'C Suspended 2nd Triad',
    'C Diminished Triad',
    'C Augmented Triad',
]

# %%
max_tsub = max(observable_df['mean_t_sub'])
min_tsub = min(observable_df['mean_t_sub'])

alt.Chart(observable_df).mark_point().encode(
    y=alt.Y('difference_ratio'),
    color=alt.Color('mean_t_sub:Q', title='Mean Period', scale=alt.Scale(domain=[max_tsub, min_tsub])),
)

# %% [markdown]
# Proof that statioary is replicable

# %%
mega_chord_array = [
    ['D3', 'A3','D4','A4','D5','F#5'],
    ['A2','E3','A3','A4','C#5','E5'],
    ['B2','F#3','B3','F#4','B4','D5'],
    ['F#2','C#3','F#3','F#4','A4','C#5'],
    ['G2','D3','G3','D4','G4','B4'],
    ['D3','A3','D4','F#4','A4'],
    ['E3','B3','E4','G4','B4'],
    ['A2','E3','A3','E4','A4','C#5']
]

chord_labels = [
    'D major',
    'A major',
    'B minor',
    'F# minor',
    'G major',
    'D major',
    'E minor',
    'A major'

]

# %%
def create_facet_chart_for_stationary(note_name_mega_array,titles , fundamental_df, max_number_of_observable_metrics,max=20):
    for i, note_names in enumerate(note_name_mega_array):
        # print(note_names)
        observable_df = generate_observable_df(note_names, fundamental_df, max_number_of_observable_metrics,max)
        observable_df.sort_values(by='difference_ratio', ascending=True, inplace=True)    
        # print(observable_df)
        observable_df['chord'] = titles[i]
        # observable_df['row']= i//3
        if i == 0:
            all_observable_df = observable_df
        else:
            all_observable_df = pd.concat([all_observable_df, observable_df], ignore_index=True)

    all_observable_df['chord'] = all_observable_df['chord'].astype('category')
    return all_observable_df# return create_chart_for_facet(all_observable_df).facet(
    #     'title', align='each', columns=3)

# %%
obs = generate_observable_df(mega_chord_array[2],fundamental_df,max_number_of_observable_metrics=19,max=50)

obs.sort_values(by='difference_ratio', ascending=True, inplace=True)
# take_period_def_extract_winners(period_df,obs[:10])
obs
# Out:
#                                              t_values  mean_t_sub  std_normed  \
# 0   [0.03239631702328506, 0.03243292131825603, 0.0...    0.032401    0.369830
# 1   [0.06479263404657012, 0.06486584263651206, 0.0...    0.064802    0.369830
# 2   [0.08099079255821265, 0.08108230329564008, 0.0...    0.081144    0.392683
# 3   [0.08099079255821265, 0.08108230329564008, 0.0...    0.080860    0.389391
# 4   [0.04859447553492759, 0.04864938197738404, 0.0...    0.048743    0.398266
# 5   [0.04859447553492759, 0.04864938197738404, 0.0...    0.048459    0.395430
# 6   [0.06479263404657012, 0.06486584263651206, 0.0...    0.065085    0.401440
# 7   [0.06479263404657012, 0.06486584263651206, 0.0...    0.064518    0.399114
# 8   [0.08099079255821265, 0.08108230329564008, 0.0...    0.079788    0.495985
# 9   [0.07289171330239139, 0.07027132952288806, 0.0...    0.072238    0.412720
# 10  [0.07289171330239139, 0.07567681640926407, 0.0...    0.073423    0.398928
# 11  [0.07289171330239139, 0.07027132952288806, 0.0...    0.071167    0.446733
# 12  [0.05669355479074886, 0.05405486886376005, 0.0...    0.056180    0.392999
# 13  [0.05669355479074886, 0.05946035575013606, 0.0...    0.057365    0.408483
# 14  [0.05669355479074886, 0.05405486886376005, 0.0...    0.055559    0.474455
# 15  [0.01619815851164253, 0.016216460659128015, 0....    0.016342    0.404784
# 16  [0.03239631702328506, 0.03243292131825603, 0.0...    0.032685    0.404784
# 17  [0.01619815851164253, 0.016216460659128015, 0....    0.016058    0.403352
# 18  [0.03239631702328506, 0.03243292131825603, 0.0...    0.032117    0.403352
#
#                         indices  difference  difference_ratio
# 0     [3.0, 5, 7, 11, 15, 18.0]    0.000083          0.002565
# 1   [7.0, 11, 15, 23, 31, 37.0]    0.000166          0.002565
# 2   [9.0, 14, 19, 29, 39, 47.0]    0.000735          0.009059
# 3   [9.0, 14, 19, 29, 39, 46.0]    0.001059          0.013098
# 4    [5.0, 8, 11, 17, 23, 28.0]    0.000782          0.016034
# 5    [5.0, 8, 11, 17, 23, 27.0]    0.000976          0.020140
# 6   [7.0, 11, 15, 23, 31, 38.0]    0.001610          0.024731
# 7   [7.0, 11, 15, 23, 31, 36.0]    0.001869          0.028966
# 8   [9.0, 14, 19, 28, 38, 45.0]    0.002762          0.034613
# 9   [8.0, 12, 17, 26, 35, 41.0]    0.002703          0.037414
# 10  [8.0, 13, 17, 26, 35, 42.0]    0.002785          0.037932
# 11  [8.0, 12, 17, 25, 34, 40.0]    0.003084          0.043338
# 12   [6.0, 9, 13, 20, 27, 32.0]    0.002703          0.048109
# 13  [6.0, 10, 13, 20, 27, 33.0]    0.002767          0.048232
# 14   [6.0, 9, 13, 20, 26, 31.0]    0.002703          0.048647
# 15       [1.0, 2, 3, 5, 7, 9.0]    0.000828          0.050670
# 16    [3.0, 5, 7, 11, 15, 19.0]    0.001656          0.050670
# 17       [1.0, 2, 3, 5, 7, 8.0]    0.000893          0.055601
# 18    [3.0, 5, 7, 11, 15, 17.0]    0.001786          0.055601

# %%
a_obs_df = create_facet_chart_for_stationary(mega_chord_array,chord_labels,fundamental_df,max_number_of_observable_metrics=5,max=50)
a_obs_df
# Out:
#                                              t_values  mean_t_sub  std_normed  \
# 0   [0.040495396279106324, 0.04090909090909091, 0....    0.040817    0.384815
# 1   [0.08099079255821265, 0.08181818181818182, 0.0...    0.081634    0.384815
# 2   [0.06479263404657012, 0.06363636363636363, 0.0...    0.064361    0.486243
# 3   [0.07289171330239139, 0.07272727272727272, 0.0...    0.072146    0.506131
# 4   [0.07289171330239139, 0.07272727272727272, 0.0...    0.072714    0.369481
# 5   [0.07289171330239139, 0.07280944659109279, 0.0...    0.072754    0.325514
# 6   [0.07289171330239139, 0.07280944659109279, 0.0...    0.072470    0.389281
# 7   [0.04859447553492759, 0.048539631060728526, 0....    0.049202    0.470381
# 8   [0.08099079255821265, 0.07887690047368386, 0.0...    0.081067    0.383942
# 9   [0.08099079255821265, 0.07887690047368386, 0.0...    0.080405    0.377100
# 10  [0.03239631702328506, 0.03243292131825603, 0.0...    0.032401    0.369830
# 11  [0.06479263404657012, 0.06486584263651206, 0.0...    0.064802    0.369830
# 9   [9.0, 12, 17, 34, 44, 46.0]    0.002941          0.036581   A major
# 10    [3.0, 5, 7, 11, 15, 18.0]    0.000083          0.002565   B minor
# 11  [7.0, 11, 15, 23, 31, 37.0]    0.000166          0.002565   B minor
# 12  [9.0, 14, 19, 29, 39, 47.0]    0.000735          0.009059   B minor
# 13  [9.0, 14, 19, 29, 39, 46.0]    0.001059          0.013098   B minor
# 14   [5.0, 8, 11, 17, 23, 28.0]    0.000782          0.016034   B minor
# 15   [7.0, 8, 11, 23, 27, 37.0]    0.001303          0.020156  F# minor
# 16  [9.0, 10, 14, 29, 34, 46.0]    0.001712          0.021310  F# minor
# 17   [7.0, 8, 11, 23, 28, 38.0]    0.001610          0.024651  F# minor
# 18   [7.0, 8, 11, 23, 27, 36.0]    0.001942          0.030181  F# minor
# 19  [9.0, 10, 14, 29, 35, 47.0]    0.002448          0.030219  F# minor
# 20    [4.0, 5, 7, 11, 15, 23.0]    0.000368          0.009011   G major
# 21  [9.0, 11, 15, 23, 31, 47.0]    0.000735          0.009011   G major
# 22  [9.0, 11, 15, 23, 31, 46.0]    0.001703          0.020945   G major
# 23   [6.0, 7, 10, 15, 21, 31.0]    0.002210          0.039887   G major
# 24    [4.0, 5, 7, 11, 15, 22.0]    0.001703          0.042037   G major
# 25       [4.0, 8, 11, 14, 23.0]    0.000414          0.010156   D major
# 26      [9.0, 17, 23, 29, 47.0]    0.000827          0.010156   D major
# 27      [7.0, 13, 18, 23, 37.0]    0.001229          0.019050   D major
# 28      [8.0, 15, 20, 26, 41.0]    0.001464          0.020242   D major
# 29      [9.0, 17, 23, 29, 46.0]    0.001795          0.022125   D major
# 30      [9.0, 19, 26, 31, 47.0]    0.000920          0.011293   E minor
# 31      [8.0, 17, 23, 28, 42.0]    0.001171          0.016007   E minor
# 32      [7.0, 15, 20, 24, 37.0]    0.001084          0.016850   E minor
# 33      [5.0, 11, 15, 18, 28.0]    0.000906          0.018600   E minor
# 34      [5.0, 11, 15, 18, 27.0]    0.000921          0.019040   E minor
# 35  [8.0, 11, 15, 23, 31, 42.0]    0.000485          0.006663   A major
# 36  [8.0, 11, 15, 23, 31, 41.0]    0.001382          0.019036   A major
# 37   [5.0, 7, 10, 15, 21, 28.0]    0.001460          0.029697   A major
# 38  [9.0, 12, 17, 26, 35, 47.0]    0.003034          0.037366   A major
# 39  [9.0, 12, 17, 26, 34, 46.0]    0.003034          0.037673   A major

# %%
note_names = mega_chord_array[2]
period_df = calculate_period_dataframe(note_names,fundamental_df,max=50)
bound_df = finding_min_difference_with_lower_upper_bound(period_df)
bound_df.sort_values(by='ratio', ascending=True, inplace=True)
bound_df
# Out:
#     bass  last_note  difference      mean     ratio  bass_value  \
# 0      3         18   -0.000047  0.032373  0.001437    0.032396
# 1      7         37   -0.000093  0.064746  0.001437    0.064793
# 2      8         42    0.000321  0.073052  0.004394    0.072892
# 3      6         32   -0.000507  0.056440  0.008984    0.056694
# 4      4         23    0.000368  0.040679  0.009035    0.040495
# 5      9         47    0.000735  0.081358  0.009035    0.080991
# 58     0          0   -0.006396  0.004901  1.305173    0.008099
#
#     last_note_value
# 0          0.032350
# 1          0.064700
# 2          0.073213
# 3          0.056187
# 4          0.040863
# 5          0.081726
# 6          0.080023
# 7          0.049376
# 8          0.071510
# 9          0.023837
# 10         0.047673
# 11         0.057889
# 12         0.066402
# 13         0.062997
# 15         0.078321
# 14         0.039160
# 16         0.054484
# 17         0.069807
# 18         0.008513
# 19         0.017026
# 20         0.025539
# 21         0.034052
# 22         0.076618
# 23         0.045971
# 24         0.015324
# 25         0.030647
# 26         0.061294
# 27         0.083428
# 28         0.068105
# 29         0.052781
# 30         0.037458
# 31         0.074915
# 32         0.059592
# 33         0.081726
# 34         0.066402
# 35         0.022134
# 36         0.044268
# 37         0.073213
# 38         0.051079
# 39         0.028945
# 40         0.057889
# 41         0.035755
# 42         0.042566
# 43         0.049376
# 44         0.034052
# 45         0.006810
# 46         0.013621
# 47         0.020431
# 48         0.027242
# 49         0.040863
# 50         0.025539
# 51         0.018729
# 52         0.011918
# 53         0.017026
# 54         0.005108
# 55         0.010216
# 56         0.008513
# 57         0.003405
# 58         0.001703

# %%
each_pair = choosing_bounds_binary_search(period_df,bound_df)
observable_metrics=[]
for item in each_pair:
    observable_metrics.append(item['observable_metrics'])
sorted_observable_metrics = sorted(observable_metrics, key=lambda x: x['difference_ratio'])
pd.DataFrame(sorted_observable_metrics[:30])
# Out:
#                                              t_values  mean_t_sub  std_normed  \
# 0   [0.03239631702328506, 0.03243292131825603, 0.0...    0.032401    0.369830
# 1   [0.06479263404657012, 0.06486584263651206, 0.0...    0.064802    0.369830
# 2   [0.08099079255821265, 0.08108230329564008, 0.0...    0.081144    0.392683
# 3   [0.08099079255821265, 0.08108230329564008, 0.0...    0.080860    0.389391
# 4   [0.04859447553492759, 0.04864938197738404, 0.0...    0.048743    0.398266
# 5   [0.04859447553492759, 0.04864938197738404, 0.0...    0.048459    0.395430
# 6   [0.06479263404657012, 0.06486584263651206, 0.0...    0.065085    0.401440
# 7   [0.06479263404657012, 0.06486584263651206, 0.0...    0.064518    0.399114
# 8   [0.08099079255821265, 0.08108230329564008, 0.0...    0.079788    0.495985
# 9   [0.07289171330239139, 0.07027132952288806, 0.0...    0.072238    0.412720
# 10  [0.07289171330239139, 0.07567681640926407, 0.0...    0.073423    0.398928
# 11  [0.07289171330239139, 0.07027132952288806, 0.0...    0.071167    0.446733
# 12  [0.05669355479074886, 0.05405486886376005, 0.0...    0.056180    0.392999
# 13  [0.05669355479074886, 0.05946035575013606, 0.0...    0.057365    0.408483
# 14  [0.05669355479074886, 0.05405486886376005, 0.0...    0.055559    0.474455
# 15  [0.01619815851164253, 0.016216460659128015, 0....    0.016342    0.404784
# 16  [0.03239631702328506, 0.03243292131825603, 0.0...    0.032685    0.404784
# 17  [0.01619815851164253, 0.016216460659128015, 0....    0.016058    0.403352
# 18  [0.03239631702328506, 0.03243292131825603, 0.0...    0.032117    0.403352
# 19  [0.06479263404657012, 0.06486584263651206, 0.0...    0.063446    0.440548
# 20  [0.08099079255821265, 0.08108230329564008, 0.0...    0.078830    0.429979
# 21  [0.04859447553492759, 0.04864938197738404, 0.0...    0.047388    0.503461
# 22  [0.08908987181403392, 0.08648779018201608, 0.0...    0.086267    0.337599
# 23  [0.040495396279106324, 0.04324389509100804, 0....    0.041022    0.399400
# 24  [0.040495396279106324, 0.03783840820463204, 0....    0.039838    0.413619
# 25  [0.07289171330239139, 0.07027132952288806, 0.0...    0.070208    0.348731
# 26  [0.05669355479074886, 0.05405486886376005, 0.0...    0.054824    0.402047
# 27  [0.040495396279106324, 0.03783840820463204, 0....    0.038766    0.453797
# 28  [0.08099079255821265, 0.07567681640926407, 0.0...    0.077308    0.355817
# 29  [0.06479263404657012, 0.06486584263651206, 0.0...    0.062487    0.402951
#
#                          indices  difference  difference_ratio
# 0      [3.0, 5, 7, 11, 15, 18.0]    0.000083          0.002565
# 1    [7.0, 11, 15, 23, 31, 37.0]    0.000166          0.002565
# 2    [9.0, 14, 19, 29, 39, 47.0]    0.000735          0.009059
# 3    [9.0, 14, 19, 29, 39, 46.0]    0.001059          0.013098
# 4     [5.0, 8, 11, 17, 23, 28.0]    0.000782          0.016034
# 5     [5.0, 8, 11, 17, 23, 27.0]    0.000976          0.020140
# 6    [7.0, 11, 15, 23, 31, 38.0]    0.001610          0.024731
# 7    [7.0, 11, 15, 23, 31, 36.0]    0.001869          0.028966
# 8    [9.0, 14, 19, 28, 38, 45.0]    0.002762          0.034613
# 9    [8.0, 12, 17, 26, 35, 41.0]    0.002703          0.037414
# 10   [8.0, 13, 17, 26, 35, 42.0]    0.002785          0.037932
# 11   [8.0, 12, 17, 25, 34, 40.0]    0.003084          0.043338
# 12    [6.0, 9, 13, 20, 27, 32.0]    0.002703          0.048109
# 13   [6.0, 10, 13, 20, 27, 33.0]    0.002767          0.048232
# 14    [6.0, 9, 13, 20, 26, 31.0]    0.002703          0.048647
# 15        [1.0, 2, 3, 5, 7, 9.0]    0.000828          0.050670
# 16     [3.0, 5, 7, 11, 15, 19.0]    0.001656          0.050670
# 17        [1.0, 2, 3, 5, 7, 8.0]    0.000893          0.055601
# 18     [3.0, 5, 7, 11, 15, 17.0]    0.001786          0.055601
# 19   [7.0, 11, 15, 22, 30, 35.0]    0.003571          0.056291
# 20   [9.0, 14, 18, 28, 38, 44.0]    0.004464          0.056633
# 21    [5.0, 8, 11, 16, 22, 26.0]    0.002703          0.057035
# 22  [10.0, 15, 20, 31, 42, 48.0]    0.005661          0.065627
# 23     [4.0, 7, 9, 14, 19, 23.0]    0.002748          0.067000
# 24     [4.0, 6, 9, 14, 19, 22.0]    0.002703          0.067844
# 25   [8.0, 12, 16, 25, 34, 39.0]    0.004787          0.068181
# 26    [6.0, 9, 13, 19, 26, 30.0]    0.003912          0.071360
# 27     [4.0, 6, 9, 13, 18, 21.0]    0.003038          0.078360
# 28   [9.0, 13, 18, 28, 37, 43.0]    0.006075          0.078588
# 29   [7.0, 11, 14, 22, 30, 34.0]    0.005274          0.084402
