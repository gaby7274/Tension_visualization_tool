# %%
import pandas as pd
from math import log2
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statistics
import altair as alt



max_number_of_observable_metrics=5

#hz is the number
def equation_for_midi_number(hz):
    return 12*log2(hz/440) +69
    


# N is themidi number

def equation_for_hertz(n):
    return 440* 2**((n-69)/12)

def equation_for_harmonics(number_of_harmonics, midi_number):
    all_harmonics = []
    hertz = equation_for_hertz(midi_number)
    for i in range(number_of_harmonics):
        
        all_harmonics.append((i+1)*hertz)
    
    return all_harmonics
        

note_df = pd.DataFrame()


piano_range = range(21, 109)
piano_notes = ['A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#']
piano_octave = [str(i) for i in range(0, 9)]

##populating dataframe columns
piano_note_index = 0
piano_octave_index = 0
for midi_number in piano_range:
    if piano_note_index %12 == 3:
        piano_octave_index += 1

    note_name = piano_notes[piano_note_index % 12] + piano_octave[piano_octave_index]
    note_df[note_name]= equation_for_harmonics(10,midi_number)
    
    piano_note_index += 1


note_df
# Out:
#       A0         A#0          B0          C1         C#1          D1  \
# 0   27.5   29.135235   30.867706   32.703196   34.647829   36.708096
# 1   55.0   58.270470   61.735413   65.406391   69.295658   73.416192
# 2   82.5   87.405705   92.603119   98.109587  103.943487  110.124288
# 3  110.0  116.540940  123.470825  130.812783  138.591315  146.832384
# 4  137.5  145.676175  154.338532  163.515978  173.239144  183.540480
# 5  165.0  174.811411  185.206238  196.219174  207.886973  220.248576
# 6  192.5  203.946646  216.073944  228.922370  242.534802  256.956672
# 7  220.0  233.081881  246.941651  261.625565  277.182631  293.664768
# 8  247.5  262.217116  277.809357  294.328761  311.830460  330.372864
# 9  275.0  291.352351  308.677063  327.031957  346.478289  367.080960
#
#           D#1          E1          F1         F#1  ...           D#7  \
# 0   38.890873   41.203445   43.653529   46.249303  ...   2489.015870
# 1   77.781746   82.406889   87.307058   92.498606  ...   4978.031740
# 2  116.672619  123.610334  130.960587  138.747909  ...   7467.047609
# 3  155.563492  164.813778  174.614116  184.997211  ...   9956.063479
# 4  194.454365  206.017223  218.267645  231.246514  ...  12445.079349
# 5  233.345238  247.220668  261.921174  277.495817  ...  14934.095219
# 6  272.236111  288.424112  305.574703  323.745120  ...  17423.111088
# 7  311.126984  329.627557  349.228231  369.994423  ...  19912.126958
# 8  350.017857  370.831002  392.881760  416.243726  ...  22401.142828
# 9  388.908730  412.034446  436.535289  462.493028  ...  24890.158698
#
#              E7            F7           F#7            G7           G#7  \
# 0   2637.020455   2793.825851   2959.955382   3135.963488   3322.437581
# 1   5274.040911   5587.651703   5919.910763   6271.926976   6644.875161
# 2   7911.061366   8381.477554   8879.866145   9407.890464   9967.312742
# 3  10548.081821  11175.303406  11839.821527  12543.853951  13289.750323
# 4  13185.102277  13969.129257  14799.776908  15679.817439  16612.187903
# 5  15822.122732  16762.955109  17759.732290  18815.780927  19934.625484
# 6  18459.143187  19556.780960  20719.687672  21951.744415  23257.063064
# 7  21096.163642  22350.606812  23679.643054  25087.707903  26579.500645
# 8  23733.184098  25144.432663  26639.598435  28223.671391  29901.938226
# 9  26370.204553  27938.258515  29599.553817  31359.634879  33224.375806
#
#         A7           A#7           B7            C8
# 0   3520.0   3729.310092   3951.06641   4186.009045
# 1   7040.0   7458.620184   7902.13282   8372.018090
# 2  10560.0  11187.930276  11853.19923  12558.027134
# 3  14080.0  14917.240369  15804.26564  16744.036179
# 4  17600.0  18646.550461  19755.33205  20930.045224
# 5  21120.0  22375.860553  23706.39846  25116.054269
# 6  24640.0  26105.170645  27657.46487  29302.063314
# 7  28160.0  29834.480737  31608.53128  33488.072358
# 8  31680.0  33563.790829  35559.59769  37674.081403
# 9  35200.0  37293.100921  39510.66410  41860.090448
#
# [10 rows x 88 columns]

# %%
# Assuming df is your dataframe
fundamental_df = note_df.drop(note_df.index[1:10])
fundamental_df.reset_index(drop=True, inplace=True)
fundamental_df
# Out:
#      A0        A#0         B0         C1        C#1         D1        D#1  \
# 0  27.5  29.135235  30.867706  32.703196  34.647829  36.708096  38.890873
#
#           E1         F1        F#1  ...         D#7           E7           F7  \
# 0  41.203445  43.653529  46.249303  ...  2489.01587  2637.020455  2793.825851
#
#            F#7           G7          G#7      A7          A#7          B7  \
# 0  2959.955382  3135.963488  3322.437581  3520.0  3729.310092  3951.06641
#
#             C8
# 0  4186.009045
#
# [1 rows x 88 columns]

# %%
def calculate_period_dataframe(note_names:list,note_df ,max=13):
    df = pd.DataFrame()
    for note_name in note_names:
        df[note_name]= 1/note_df[note_name][0]

    ## calculating period
    for i in range(1,max):
        list_of_periods = []
        for note_name in note_names:
            list_of_periods.append((1/(note_df[note_name][0]))*i)

        df.loc[i] = list_of_periods
    # note_period_c3 = (1/note_c3[0]) * (i)
    # note_period_e3 = (1/note_e3[0]) * (i)
    # note_period_g3 = (1/note_g3[0]) * (i)
    # note_period_c4 = (1/note_c4[0]) * (i)
    # dataframe_demos.loc[i] = [note_period_c3, note_period_e3, note_period_g3, note_period_c4]


    
    return df

note_names = ['C3', 'D#3', 'G3', 'A#3']
period_df = calculate_period_dataframe(note_names, fundamental_df)  
period_df
# Out:
#           C3       D#3        G3       A#3
# 1   0.007645  0.006428  0.005102  0.004290
# 2   0.015289  0.012856  0.010204  0.008581
# 3   0.022934  0.019285  0.015306  0.012871
# 4   0.030578  0.025713  0.020408  0.017161
# 5   0.038223  0.032141  0.025511  0.021452
# 6   0.045867  0.038569  0.030613  0.025742
# 7   0.053512  0.044998  0.035715  0.030032
# 8   0.061156  0.051426  0.040817  0.034323
# 9   0.068801  0.057854  0.045919  0.038613
# 10  0.076445  0.064282  0.051021  0.042903
# 11  0.084090  0.070711  0.056123  0.047194
# 12  0.091734  0.077139  0.061225  0.051484

# %% [markdown]
# ### Ahora, intentaremos hacer algo loco, encontrar las cotas menores y mayores
# Algoritmo es T(n)=2n

# %%
def finding_min_difference_with_lower_upper_bound(period_df):
    '''
    This function will assume that the first and last note are the lower and upper bounds
    Since bass is the first note, and it oscillates less, than the last note

    Algorithm goes as follows:
    loop until last note max index is reached

    then, for each note, we will take the difference between the last note and the bass note
    and divide by the mean of the two notes. We will store, the keys, the division and 
    then sort by division results. 

    each time the difference of last-bass is positive we will increment the bass,
    then when the difference is negative, we will increment the last note
    '''
    notes = period_df.columns
    range_to_consider = len(period_df[notes[0]].values)

    ## bass
    bass =  period_df[notes[0]].values

    last_note = period_df[notes[-1]].values

    ## algorithm
    i, j = 0,0

    ## array to store all dicts info
    ratio_dicts = []

    while i < range_to_consider and j < range_to_consider:
        bass_note = bass[i]
        last_note_value = last_note[j]

        difference = last_note_value - bass_note
        mean = (last_note_value + bass_note) / 2
        ratio = abs(difference/mean)
        ratio_dicts.append({
            'bass': i,
            'last_note': j,
            'difference': difference,
            'mean': mean,
            'ratio': ratio,
            'bass_value':bass_note,
            'last_note_value':last_note_value
        })

        if difference > 0:
            i += 1
        else:
            j += 1
        
    return pd.DataFrame(sorted(ratio_dicts, key=lambda x: x['ratio'] ))

# %%
notes =['C3','A#3']
period_df = calculate_period_dataframe(notes, fundamental_df, max=16)
bound_df = finding_min_difference_with_lower_upper_bound(period_df)
bound_df
# Out:
#     bass  last_note  difference      mean     ratio  bass_value  \
# 0      4          8    0.000390  0.038418  0.010164    0.038223
# 1      3          6   -0.000546  0.030305  0.018006    0.030578
# 2      7         13   -0.001091  0.060610  0.018006    0.061156
# 3      5         10    0.001327  0.046530  0.028511    0.045867
# 4      6         11   -0.002028  0.052498  0.038621    0.053512
# 5      6         12    0.002263  0.054643  0.041411    0.053512
# 6      7         14    0.003199  0.062756  0.050975    0.061156
# 7      2          4   -0.001482  0.022193  0.066772    0.022934
# 8      5          9   -0.002964  0.044385  0.066772    0.045867
# 9      8         14   -0.004446  0.066578  0.066772    0.068801
# 10     7         12   -0.005382  0.058465  0.092050    0.061156
# 11     4          7   -0.003900  0.036273  0.107515    0.038223
# 12     2          5    0.002808  0.024338  0.115396    0.022934
# 13     0          1    0.000936  0.008113  0.115396    0.007645
# 14     1          3    0.001872  0.016225  0.115396    0.015289
# 15     3          7    0.003745  0.032450  0.115396    0.030578
# 16     6         10   -0.006318  0.050353  0.125473    0.053512
# 17     1          2   -0.002418  0.014080  0.171734    0.015289
# 18     3          5   -0.004836  0.028160  0.171734    0.030578
# 19     5          8   -0.007254  0.042240  0.171734    0.045867
# 20     2          3   -0.005772  0.020047  0.287926    0.022934
# 21     0          0   -0.003354  0.005967  0.562081    0.007645
# 22     1          1   -0.006708  0.011935  0.562081    0.015289
#
#     last_note_value
# 0          0.038613
# 1          0.030032
# 2          0.060065
# 3          0.047194
# 4          0.051484
# 5          0.055774
# 6          0.064355
# 7          0.021452
# 8          0.042903
# 9          0.064355
# 10         0.055774
# 11         0.034323
# 12         0.025742
# 13         0.008581
# 14         0.017161
# 15         0.034323
# 16         0.047194
# 17         0.012871
# 18         0.025742
# 19         0.038613
# 20         0.017161
# 21         0.004290
# 22         0.008581

# %% [markdown]
# ### ahora, si cojo cada uno de esos elementos de upper y lower, se reducirá la búsqueda a n^2logn?
#  mira, por cada uno de estos pares
# 1. go through every array, and perform binary search...

# %%
def binary_search_with_bounds(period_df,lower_bound,upper_bound,mean_bound):
    

    """
    this binary search goes as follows:
    1. We first take a pivot, which is between lower and upper bound,
    2. we then substract period against mean. 
    3. we compare if that is the lowest, if it is, take pivot as candidate
    4. if positive, we go to right leaf, if negative we go to left
    5. at the end return candidate for each 
    """

    notes = period_df.columns
    ## only take medium ones
    notes = notes[ 1 : -1]

    chosen_winners = []
    all_found = []
    for note in notes:

        ### here we begin binary loop

        low = lower_bound
        upper = upper_bound
        
        candidate_index = 0
        candidate_difference = 1000
        candidate_value = 10000
        # updated= True
        note_values = period_df[note].values
        # print(note_values)


        complete_note_differences = []

        while low<=upper:
            # updated = False

            middle = (low + upper) // 2

            difference = mean_bound - note_values[middle]


            if(candidate_difference>abs(difference)):
                candidate_difference =  abs(difference)
                candidate_index = middle
                candidate_value = note_values[middle]
            complete_note_differences.append({
                'index':middle,
                'value': note_values[middle],
                'abs_difference': abs(difference),
                'difference':difference
            })
            ## update middle
            if difference >0:
                low=middle+1
            else:
                upper = middle-1

        #### now we store the necessary information, the chosen one and everything
        all_found.append(
            {'note': note,
             'values':complete_note_differences}
        )
        chosen_winners.append(
            {'note': note,
             'candidate_index': candidate_index,
             'candidate_difference':candidate_difference,
             'candidate_value': candidate_value}
        )
    return all_found,chosen_winners

            
            
        

def choosing_bounds_binary_search(period_df, bounds_df):
    
    # notes in period_df to get bass and last
    notes = period_df.columns
    # bass =  bounds_df[notes[0]].values
    # last_note =  bounds_df[notes[-1]].values
    each_pair_values = []
    for i,row in bound_df.iterrows():
        bass_value = int(row['bass'])
        last_note_value = int(row['last_note'])
        mean_bound = row['mean']
        all_found, chosen_winners = binary_search_with_bounds(period_df,bass_value,last_note_value, mean_bound)
        

        ### interestingly enough, could i then here, normalize, and standard deviation?
        values=[row['bass_value']]
         ## indeces
        indices_to_observe=[row['bass']]
        for d in chosen_winners:
            values.append(d['candidate_value'])
            indices_to_observe.append(d['candidate_index'])
        indices_to_observe.append(row['last_note'])
        values.append(row['last_note_value'])


       


        ## normalizing, and calculating standard deviation and mean
        

        minimum = min(values)
        maximum = max(values)
        mean_vals = sum(values)/len(values)

        ##normalizing
        norm_vals = []
        # for v in values:
        #     normed = (v-minimum)/(maximum-minimum)
        #     norm_vals.append(normed)
        # std_= statistics.stdev(norm_vals)

        observable_metrics = {
            't_values':values,
            'mean_t_sub': mean_vals,
            # 'std_normed':std_,
            'indices':indices_to_observe,
            'difference':maximum-minimum,
            'difference_ratio': (maximum-minimum)/mean_vals,
        }

        




        each_pair_values.append({
            "all_found":all_found,
            'chosen_winners':chosen_winners,
            'observable_metrics':observable_metrics
            
        }
        )
        
    return each_pair_values

# %%
each_pair = choosing_bounds_binary_search(period_df,bound_df)
for bp_i, bp_v in bound_df.iterrows():
    print(f'bound_pair #{bp_i} with vals bass={bp_v["bass"]} and last_note{bp_v["last_note"]}')
    print('all_found',each_pair[bp_i]['all_found'])
    print('winner',each_pair[bp_i]['chosen_winners'])
# Out:
# bound_pair #0 with vals bass=4.0 and last_note8.0
# all_found []
# winner []
# bound_pair #1 with vals bass=3.0 and last_note6.0
# all_found []
# winner []
# bound_pair #2 with vals bass=7.0 and last_note13.0
# all_found []
# winner []
# bound_pair #3 with vals bass=5.0 and last_note10.0
# all_found []
# winner []
# bound_pair #4 with vals bass=6.0 and last_note11.0
# all_found []
# winner []
# bound_pair #5 with vals bass=6.0 and last_note12.0
# all_found []
# winner []
# bound_pair #6 with vals bass=7.0 and last_note14.0
# all_found []
# winner []
# bound_pair #7 with vals bass=2.0 and last_note4.0
# all_found []
# winner []
# bound_pair #8 with vals bass=5.0 and last_note9.0
# all_found []
# winner []
# bound_pair #9 with vals bass=8.0 and last_note14.0
# all_found []
# winner []
# bound_pair #10 with vals bass=7.0 and last_note12.0
# all_found []
# winner []
# bound_pair #11 with vals bass=4.0 and last_note7.0
# all_found []
# winner []
# bound_pair #12 with vals bass=2.0 and last_note5.0
# all_found []
# winner []
# bound_pair #13 with vals bass=0.0 and last_note1.0
# all_found []
# winner []
# bound_pair #14 with vals bass=1.0 and last_note3.0
# all_found []
# winner []
# bound_pair #15 with vals bass=3.0 and last_note7.0
# all_found []
# winner []
# bound_pair #16 with vals bass=6.0 and last_note10.0
# all_found []
# winner []
# bound_pair #17 with vals bass=1.0 and last_note2.0
# all_found []
# winner []
# bound_pair #18 with vals bass=3.0 and last_note5.0
# all_found []
# winner []
# bound_pair #19 with vals bass=5.0 and last_note8.0
# all_found []
# winner []
# bound_pair #20 with vals bass=2.0 and last_note3.0
# all_found []
# winner []
# bound_pair #21 with vals bass=0.0 and last_note0.0
# all_found []
# winner []
# bound_pair #22 with vals bass=1.0 and last_note1.0
# all_found []
# winner []

# %% [markdown]
# ## recap.
# - Un algoritmo que comienza por definir upper, lowerbounds, es t(n)=2n
# - se sortean estos pares usando delta_t/meanT
# - luego por cada par que encontró (n pares) ve por cada nota (n) y haz binary_search(logn) donde la diferencia de ese indice y la media de upper y lower sea la más pequeña
# - Cuando finalice y encuentre todos los candidatos de cada par, entonces, min difference de min max
#
#
# voy a ver que da

# %%
# note_names = ['D3','A3','D4','A4','D5','F#5']
##minor C 7
# note_names = ['C3','D#3','G3','A#3']


##major triad
note_names = ['C3','E3','G3', 'C4']
# # minor triad
# note_names = ['C3','D#3','G3']
## major 7
# note_names = ['C#3','D3', 'F#3', 'A3']
# D major scale
# note_names = ['D3','E3', 'F#3','G3' ,'A3', 'B3','C#4','D4']	
# note_names =['D3','F3','A3']
# note_names = ['A2','E3', 'A3', 'A4', 'C#5', 'E5']
# note_names = ['B2', 'F#3', 'B3', 'F#4','B4','D5']

period_df = calculate_period_dataframe(note_names,fundamental_df,max=20)
period_df
# Out:
#           C3        E3        G3        C4
# 1   0.007645  0.006067  0.005102  0.003822
# 2   0.015289  0.012135  0.010204  0.007645
# 3   0.022934  0.018202  0.015306  0.011467
# 4   0.030578  0.024270  0.020408  0.015289
# 5   0.038223  0.030337  0.025511  0.019111
# 6   0.045867  0.036405  0.030613  0.022934
# 7   0.053512  0.042472  0.035715  0.026756
# 8   0.061156  0.048540  0.040817  0.030578
# 9   0.068801  0.054607  0.045919  0.034400
# 10  0.076445  0.060675  0.051021  0.038223
# 11  0.084090  0.066742  0.056123  0.042045
# 12  0.091734  0.072809  0.061225  0.045867
# 13  0.099379  0.078877  0.066327  0.049689
# 14  0.107023  0.084944  0.071429  0.053512
# 15  0.114668  0.091012  0.076532  0.057334
# 16  0.122312  0.097079  0.081634  0.061156
# 17  0.129957  0.103147  0.086736  0.064978
# 18  0.137601  0.109214  0.091838  0.068801
# 19  0.145246  0.115282  0.096940  0.072623

# %%
bound_df = finding_min_difference_with_lower_upper_bound(period_df)
bound_df.sort_values(by='ratio', ascending=True, inplace=True)  
bound_df
# Out:
#     bass  last_note  difference      mean     ratio  bass_value  \
# 0      0          1    0.000000  0.007645  0.000000    0.007645
# 1      1          3    0.000000  0.015289  0.000000    0.015289
# 2      2          5    0.000000  0.022934  0.000000    0.022934
# 3      3          7    0.000000  0.030578  0.000000    0.030578
# 4      4          9    0.000000  0.038223  0.000000    0.038223
# 5      5         11    0.000000  0.045867  0.000000    0.045867
# 6      6         13    0.000000  0.053512  0.000000    0.053512
# 7      7         15    0.000000  0.061156  0.000000    0.061156
# 8      8         17    0.000000  0.068801  0.000000    0.068801
# 9      9         18   -0.003822  0.074534  0.051282    0.076445
# 10     8         18    0.003822  0.070712  0.054054    0.068801
# 11     8         16   -0.003822  0.066889  0.057143    0.068801
# 12     7         16    0.003822  0.063067  0.060606    0.061156
# 13     7         14   -0.003822  0.059245  0.064516    0.061156
# 14     6         14    0.003822  0.055423  0.068966    0.053512
# 15     6         12   -0.003822  0.051600  0.074074    0.053512
# 16     5         12    0.003822  0.047778  0.080000    0.045867
# 17     5         10   -0.003822  0.043956  0.086957    0.045867
# 18     4         10    0.003822  0.040134  0.095238    0.038223
# 19     4          8   -0.003822  0.036311  0.105263    0.038223
# 20     3          8    0.003822  0.032489  0.117647    0.030578
# 21     3          6   -0.003822  0.028667  0.133333    0.030578
# 22     2          6    0.003822  0.024845  0.153846    0.022934
# 23     2          4   -0.003822  0.021022  0.181818    0.022934
# 24     1          4    0.003822  0.017200  0.222222    0.015289
# 25     1          2   -0.003822  0.013378  0.285714    0.015289
# 26     0          2    0.003822  0.009556  0.400000    0.007645
# 27     0          0   -0.003822  0.005733  0.666667    0.007645
#
#     last_note_value
# 0          0.007645
# 1          0.015289
# 2          0.022934
# 3          0.030578
# 4          0.038223
# 5          0.045867
# 6          0.053512
# 7          0.061156
# 8          0.068801
# 9          0.072623
# 10         0.072623
# 11         0.064978
# 12         0.064978
# 13         0.057334
# 14         0.057334
# 15         0.049689
# 16         0.049689
# 17         0.042045
# 18         0.042045
# 19         0.034400
# 20         0.034400
# 21         0.026756
# 22         0.026756
# 23         0.019111
# 24         0.019111
# 25         0.011467
# 26         0.011467
# 27         0.003822

# %%
each_pair = choosing_bounds_binary_search(period_df,bound_df)
## we will see if our method seems ok????
observable_metrics=[]
for item in each_pair:
    observable_metrics.append(item['observable_metrics'])
sorted(observable_metrics, key=lambda x: x['difference'])
# Out:
# [{'t_values': [0.03057805146377144,
#    0.03033726941295533,
#    0.030612601317528357,
#    0.03057805146377144],
#   'mean_t_sub': 0.03052649341450664,
#   'indices': [3.0, 4, 5, 7.0],
#   'difference': 0.0002753319045730278,
#   'difference_ratio': 0.009019440943786422},
#  {'t_values': [0.06115610292754288,
#    0.06067453882591066,
#    0.061225202635056715,
#    0.06115610292754288],
#   'mean_t_sub': 0.06105298682901328,
#   'indices': [7.0, 9, 11, 15.0],
#   'difference': 0.0005506638091460556,
#   'difference_ratio': 0.009019440943786422},
#  {'t_values': [0.06880061579348574,
#    0.06674199270850173,
#    0.06632730285464478,
#    0.06880061579348574],
#   'mean_t_sub': 0.06766763178752949,
#   'indices': [8.0, 10, 12, 17.0],
#   'difference': 0.0024733129388409686,
#   'difference_ratio': 0.036550901420740675},
#  {'t_values': [0.0382225643297143,
#    0.03640472329554639,
#    0.035714701537116415,
#    0.0382225643297143],
#   'mean_t_sub': 0.03714113837302285,
#   'indices': [4.0, 5, 6, 9.0],
#   'difference': 0.0025078627925978828,
#   'difference_ratio': 0.06752250745279922},
#  {'t_values': [0.00764451286594286,
#    0.006067453882591066,
#    0.00510210021958806,
#    0.00764451286594286],
#   'mean_t_sub': 0.00661464495851621,
#   'indices': [0.0, 0, 0, 1.0],
#   'difference': 0.0025424126463548004,
#   'difference_ratio': 0.3843611656104837},
#  {'t_values': [0.04586707719565716,
#    0.048539631060728526,
#    0.04591890197629254,
#    0.04586707719565716],
#   'mean_t_sub': 0.04654817185708385,
#   'indices': [5.0, 7, 8, 11.0],
#   'difference': 0.002672553865071363,
#   'difference_ratio': 0.05741479758382058},
#  {'t_values': [0.01528902573188572,
#    0.018202361647773196,
#    0.015306300658764179,
#    0.01528902573188572],
#   'mean_t_sub': 0.0160216784425772,
#   'indices': [1.0, 2, 2, 3.0],
#   'difference': 0.0029133359158874765,
#   'difference_ratio': 0.1818371231409414},
#  {'t_values': [0.05351159006160002,
#    0.05460708494331959,
#    0.0510210021958806,
#    0.05351159006160002],
#   'mean_t_sub': 0.05316281681560006,
#   'indices': [6.0, 8, 9, 13.0],
#   'difference': 0.00358608274743899,
#   'difference_ratio': 0.06745471670317311},
#  {'t_values': [0.05351159006160002,
#    0.05460708494331959,
#    0.056123102415468654,
#    0.05733384649457145],
#   'mean_t_sub': 0.05539390597873993,
#   'indices': [6.0, 8, 10, 14.0],
#   'difference': 0.0038222564329714256,
#   'difference_ratio': 0.0690013886083137},
#  {'t_values': [0.04586707719565716,
#    0.048539631060728526,
#    0.04591890197629254,
#    0.04968933362862859],
#   'mean_t_sub': 0.047503735965326706,
#   'indices': [5.0, 7, 8, 12.0],
#   'difference': 0.0038222564329714256,
#   'difference_ratio': 0.08046222797637045},
#  {'t_values': [0.0382225643297143,
#    0.03640472329554639,
#    0.035714701537116415,
#    0.03440030789674287],
#   'mean_t_sub': 0.036185574264779995,
#   'indices': [4.0, 5, 6, 8.0],
#   'difference': 0.0038222564329714256,
#   'difference_ratio': 0.1056292876548788},
#  {'t_values': [0.02293353859782858,
#    0.024269815530364263,
#    0.0255105010979403,
#    0.02675579503080001],
#   'mean_t_sub': 0.02486741256423329,
#   'indices': [2.0, 3, 4, 6.0],
#   'difference': 0.003822256432971429,
#   'difference_ratio': 0.1537054336915199},
#  {'t_values': [0.01528902573188572,
#    0.018202361647773196,
#    0.015306300658764179,
#    0.01911128216485715],
#   'mean_t_sub': 0.01697724255082006,
#   'indices': [1.0, 2, 2, 4.0],
#   'difference': 0.003822256432971429,
#   'difference_ratio': 0.2251400026553076},
#  {'t_values': [0.00764451286594286,
#    0.006067453882591066,
#    0.00510210021958806,
#    0.00382225643297143],
#   'mean_t_sub': 0.005659080850273353,
#   'indices': [0.0, 0, 0, 0.0],
#   'difference': 0.00382225643297143,
#   'difference_ratio': 0.6754200079659229},
#  {'t_values': [0.06880061579348574,
#    0.06674199270850173,
#    0.06632730285464478,
#    0.06497835936051431],
#   'mean_t_sub': 0.06671206767928664,
#   'indices': [8.0, 10, 12, 16.0],
#   'difference': 0.0038222564329714326,
#   'difference_ratio': 0.05729482784653969},
#  {'t_values': [0.01528902573188572,
#    0.012134907765182132,
#    0.015306300658764179,
#    0.01146676929891429],
#   'mean_t_sub': 0.01354925086368658,
#   'indices': [1.0, 1, 2, 2.0],
#   'difference': 0.003839531359849888,
#   'difference_ratio': 0.28337591491056063},
#  {'t_values': [0.03057805146377144,
#    0.03033726941295533,
#    0.030612601317528357,
#    0.02675579503080001],
#   'mean_t_sub': 0.029570929306263784,
#   'indices': [3.0, 4, 5, 6.0],
#   'difference': 0.0038568062867283467,
#   'difference_ratio': 0.1304256030232837},
#  {'t_values': [0.02293353859782858,
#    0.024269815530364263,
#    0.02040840087835224,
#    0.02293353859782858],
#   'mean_t_sub': 0.02263632340109342,
#   'indices': [2.0, 3, 3, 5.0],
#   'difference': 0.0038614146520120247,
#   'difference_ratio': 0.17058488622871965},
#  {'t_values': [0.04586707719565716,
#    0.04247217717813746,
#    0.04591890197629254,
#    0.04204482076268573],
#   'mean_t_sub': 0.044075744278193225,
#   'indices': [5.0, 6, 8, 10.0],
#   'difference': 0.0038740812136068073,
#   'difference_ratio': 0.08789599080062581},
#  {'t_values': [0.06115610292754288,
#    0.06067453882591066,
#    0.061225202635056715,
#    0.05733384649457145],
#   'mean_t_sub': 0.06009742272077043,
#   'indices': [7.0, 9, 11, 14.0],
#   'difference': 0.003891356140485268,
#   'difference_ratio': 0.0647507990245373},
#  {'t_values': [0.0764451286594286,
#    0.07280944659109279,
#    0.0765315032938209,
#    0.07262287222645716],
#   'mean_t_sub': 0.07460223769269986,
#   'indices': [9.0, 11, 14, 18.0],
#   'difference': 0.003908631067363735,
#   'difference_ratio': 0.05239294675669241},
#  {'t_values': [0.06880061579348574,
#    0.07280944659109279,
#    0.07142940307423283,
#    0.07262287222645716],
#   'mean_t_sub': 0.07141558442131712,
#   'indices': [8.0, 11, 13, 18.0],
#   'difference': 0.004008830797607041,
#   'difference_ratio': 0.05613383731423234},
#  {'t_values': [0.03057805146377144,
#    0.03033726941295533,
#    0.030612601317528357,
#    0.03440030789674287],
#   'mean_t_sub': 0.0314820575227495,
#   'indices': [3.0, 4, 5, 8.0],
#   'difference': 0.004063038483787543,
#   'difference_ratio': 0.12905886093536037},
#  {'t_values': [0.0382225643297143,
#    0.04247217717813746,
#    0.04081680175670448,
#    0.04204482076268573],
#   'mean_t_sub': 0.04088909100681049,
#   'indices': [4.0, 6, 7, 10.0],
#   'difference': 0.004249612848423165,
#   'difference_ratio': 0.10393023527266353},
#  {'t_values': [0.06115610292754288,
#    0.06067453882591066,
#    0.061225202635056715,
#    0.06497835936051431],
#   'mean_t_sub': 0.06200855093725614,
#   'indices': [7.0, 9, 11, 16.0],
#   'difference': 0.004303820534603653,
#   'difference_ratio': 0.0694068877526022},
#  {'t_values': [0.00764451286594286,
#    0.012134907765182132,
#    0.01020420043917612,
#    0.01146676929891429],
#   'mean_t_sub': 0.01036259759230385,
#   'indices': [0.0, 1, 1, 2.0],
#   'difference': 0.004490394899239272,
#   'difference_ratio': 0.4333271517340616},
#  {'t_values': [0.02293353859782858,
#    0.018202361647773196,
#    0.02040840087835224,
#    0.01911128216485715],
#   'mean_t_sub': 0.020163895822202793,
#   'indices': [2.0, 2, 3, 4.0],
#   'difference': 0.004731176950055385,
#   'difference_ratio': 0.2346360540528983},
#  {'t_values': [0.05351159006160002,
#    0.05460708494331959,
#    0.0510210021958806,
#    0.04968933362862859],
#   'mean_t_sub': 0.0522072527073572,
#   'indices': [6.0, 8, 9, 12.0],
#   'difference': 0.004917751314691,
#   'difference_ratio': 0.09419670753902697}]

# %% [markdown]
# ### Graficaré el mean_t_sub, y notas

# %%
period_df = calculate_period_dataframe(note_names,fundamental_df,max=20)
period_df
# Out:
#           C3        E3        G3        C4
# 1   0.007645  0.006067  0.005102  0.003822
# 2   0.015289  0.012135  0.010204  0.007645
# 3   0.022934  0.018202  0.015306  0.011467
# 4   0.030578  0.024270  0.020408  0.015289
# 5   0.038223  0.030337  0.025511  0.019111
# 6   0.045867  0.036405  0.030613  0.022934
# 7   0.053512  0.042472  0.035715  0.026756
# 8   0.061156  0.048540  0.040817  0.030578
# 9   0.068801  0.054607  0.045919  0.034400
# 10  0.076445  0.060675  0.051021  0.038223
# 11  0.084090  0.066742  0.056123  0.042045
# 12  0.091734  0.072809  0.061225  0.045867
# 13  0.099379  0.078877  0.066327  0.049689
# 14  0.107023  0.084944  0.071429  0.053512
# 15  0.114668  0.091012  0.076532  0.057334
# 16  0.122312  0.097079  0.081634  0.061156
# 17  0.129957  0.103147  0.086736  0.064978
# 18  0.137601  0.109214  0.091838  0.068801
# 19  0.145246  0.115282  0.096940  0.072623

# %%
def take_period_def_extract_winners(period_df,observable_metrics):
    note_names = period_df.columns
    new_df = {
        'note_name':[],
        't_values':[],
        # 't_value_in_met':[],
        'cycle_or_t':[],
        'winner_num':[],
    }
    count=0
    for item in observable_metrics:
        print(item)
        indices = item['indices']
        print('indices:', indices)
        count+=1
        
        values = item['t_values']
        print('values:', values)
        for i in range(len(indices)):
            note_name = note_names[i]
            new_df['note_name'].append(note_name)
            new_df['t_values'].append(values[i])
            new_df['cycle_or_t'].append(indices[i])
            new_df['winner_num'].append(count)
            # new_df['t_value_in_met'].append(values[i])
    return pd.DataFrame(new_df)

# %%
top_3_observable_metrics = sorted(observable_metrics, key=lambda x: x['difference'])
top_3_observable_metrics
# Out:
# [{'t_values': [0.03057805146377144,
#    0.03033726941295533,
#    0.030612601317528357,
#    0.03057805146377144],
#   'mean_t_sub': 0.03052649341450664,
#   'indices': [3.0, 4, 5, 7.0],
#   'difference': 0.0002753319045730278,
#   'difference_ratio': 0.009019440943786422},
#  {'t_values': [0.06115610292754288,
#    0.06067453882591066,
#    0.061225202635056715,
#    0.06115610292754288],
#   'mean_t_sub': 0.06105298682901328,
#   'indices': [7.0, 9, 11, 15.0],
#   'difference': 0.0005506638091460556,
#   'difference_ratio': 0.009019440943786422},
#  {'t_values': [0.06880061579348574,
#    0.06674199270850173,
#    0.06632730285464478,
#    0.06880061579348574],
#   'mean_t_sub': 0.06766763178752949,
#   'indices': [8.0, 10, 12, 17.0],
#   'difference': 0.0024733129388409686,
#   'difference_ratio': 0.036550901420740675},
#  {'t_values': [0.0382225643297143,
#    0.03640472329554639,
#    0.035714701537116415,
#    0.0382225643297143],
#   'mean_t_sub': 0.03714113837302285,
#   'indices': [4.0, 5, 6, 9.0],
#   'difference': 0.0025078627925978828,
#   'difference_ratio': 0.06752250745279922},
#  {'t_values': [0.00764451286594286,
#    0.006067453882591066,
#    0.00510210021958806,
#    0.00764451286594286],
#   'mean_t_sub': 0.00661464495851621,
#   'indices': [0.0, 0, 0, 1.0],
#   'difference': 0.0025424126463548004,
#   'difference_ratio': 0.3843611656104837},
#  {'t_values': [0.04586707719565716,
#    0.048539631060728526,
#    0.04591890197629254,
#    0.04586707719565716],
#   'mean_t_sub': 0.04654817185708385,
#   'indices': [5.0, 7, 8, 11.0],
#   'difference': 0.002672553865071363,
#   'difference_ratio': 0.05741479758382058},
#  {'t_values': [0.01528902573188572,
#    0.018202361647773196,
#    0.015306300658764179,
#    0.01528902573188572],
#   'mean_t_sub': 0.0160216784425772,
#   'indices': [1.0, 2, 2, 3.0],
#   'difference': 0.0029133359158874765,
#   'difference_ratio': 0.1818371231409414},
#  {'t_values': [0.05351159006160002,
#    0.05460708494331959,
#    0.0510210021958806,
#    0.05351159006160002],
#   'mean_t_sub': 0.05316281681560006,
#   'indices': [6.0, 8, 9, 13.0],
#   'difference': 0.00358608274743899,
#   'difference_ratio': 0.06745471670317311},
#  {'t_values': [0.05351159006160002,
#    0.05460708494331959,
#    0.056123102415468654,
#    0.05733384649457145],
#   'mean_t_sub': 0.05539390597873993,
#   'indices': [6.0, 8, 10, 14.0],
#   'difference': 0.0038222564329714256,
#   'difference_ratio': 0.0690013886083137},
#  {'t_values': [0.04586707719565716,
#    0.048539631060728526,
#    0.04591890197629254,
#    0.04968933362862859],
#   'mean_t_sub': 0.047503735965326706,
#   'indices': [5.0, 7, 8, 12.0],
#   'difference': 0.0038222564329714256,
#   'difference_ratio': 0.08046222797637045},
#  {'t_values': [0.0382225643297143,
#    0.03640472329554639,
#    0.035714701537116415,
#    0.03440030789674287],
#   'mean_t_sub': 0.036185574264779995,
#   'indices': [4.0, 5, 6, 8.0],
#   'difference': 0.0038222564329714256,
#   'difference_ratio': 0.1056292876548788},
#  {'t_values': [0.02293353859782858,
#    0.024269815530364263,
#    0.0255105010979403,
#    0.02675579503080001],
#   'mean_t_sub': 0.02486741256423329,
#   'indices': [2.0, 3, 4, 6.0],
#   'difference': 0.003822256432971429,
#   'difference_ratio': 0.1537054336915199},
#  {'t_values': [0.01528902573188572,
#    0.018202361647773196,
#    0.015306300658764179,
#    0.01911128216485715],
#   'mean_t_sub': 0.01697724255082006,
#   'indices': [1.0, 2, 2, 4.0],
#   'difference': 0.003822256432971429,
#   'difference_ratio': 0.2251400026553076},
#  {'t_values': [0.00764451286594286,
#    0.006067453882591066,
#    0.00510210021958806,
#    0.00382225643297143],
#   'mean_t_sub': 0.005659080850273353,
#   'indices': [0.0, 0, 0, 0.0],
#   'difference': 0.00382225643297143,
#   'difference_ratio': 0.6754200079659229},
#  {'t_values': [0.06880061579348574,
#    0.06674199270850173,
#    0.06632730285464478,
#    0.06497835936051431],
#   'mean_t_sub': 0.06671206767928664,
#   'indices': [8.0, 10, 12, 16.0],
#   'difference': 0.0038222564329714326,
#   'difference_ratio': 0.05729482784653969},
#  {'t_values': [0.01528902573188572,
#    0.012134907765182132,
#    0.015306300658764179,
#    0.01146676929891429],
#   'mean_t_sub': 0.01354925086368658,
#   'indices': [1.0, 1, 2, 2.0],
#   'difference': 0.003839531359849888,
#   'difference_ratio': 0.28337591491056063},
#  {'t_values': [0.03057805146377144,
#    0.03033726941295533,
#    0.030612601317528357,
#    0.02675579503080001],
#   'mean_t_sub': 0.029570929306263784,
#   'indices': [3.0, 4, 5, 6.0],
#   'difference': 0.0038568062867283467,
#   'difference_ratio': 0.1304256030232837},
#  {'t_values': [0.02293353859782858,
#    0.024269815530364263,
#    0.02040840087835224,
#    0.02293353859782858],
#   'mean_t_sub': 0.02263632340109342,
#   'indices': [2.0, 3, 3, 5.0],
#   'difference': 0.0038614146520120247,
#   'difference_ratio': 0.17058488622871965},
#  {'t_values': [0.04586707719565716,
#    0.04247217717813746,
#    0.04591890197629254,
#    0.04204482076268573],
#   'mean_t_sub': 0.044075744278193225,
#   'indices': [5.0, 6, 8, 10.0],
#   'difference': 0.0038740812136068073,
#   'difference_ratio': 0.08789599080062581},
#  {'t_values': [0.06115610292754288,
#    0.06067453882591066,
#    0.061225202635056715,
#    0.05733384649457145],
#   'mean_t_sub': 0.06009742272077043,
#   'indices': [7.0, 9, 11, 14.0],
#   'difference': 0.003891356140485268,
#   'difference_ratio': 0.0647507990245373},
#  {'t_values': [0.0764451286594286,
#    0.07280944659109279,
#    0.0765315032938209,
#    0.07262287222645716],
#   'mean_t_sub': 0.07460223769269986,
#   'indices': [9.0, 11, 14, 18.0],
#   'difference': 0.003908631067363735,
#   'difference_ratio': 0.05239294675669241},
#  {'t_values': [0.06880061579348574,
#    0.07280944659109279,
#    0.07142940307423283,
#    0.07262287222645716],
#   'mean_t_sub': 0.07141558442131712,
#   'indices': [8.0, 11, 13, 18.0],
#   'difference': 0.004008830797607041,
#   'difference_ratio': 0.05613383731423234},
#  {'t_values': [0.03057805146377144,
#    0.03033726941295533,
#    0.030612601317528357,
#    0.03440030789674287],
#   'mean_t_sub': 0.0314820575227495,
#   'indices': [3.0, 4, 5, 8.0],
#   'difference': 0.004063038483787543,
#   'difference_ratio': 0.12905886093536037},
#  {'t_values': [0.0382225643297143,
#    0.04247217717813746,
#    0.04081680175670448,
#    0.04204482076268573],
#   'mean_t_sub': 0.04088909100681049,
#   'indices': [4.0, 6, 7, 10.0],
#   'difference': 0.004249612848423165,
#   'difference_ratio': 0.10393023527266353},
#  {'t_values': [0.06115610292754288,
#    0.06067453882591066,
#    0.061225202635056715,
#    0.06497835936051431],
#   'mean_t_sub': 0.06200855093725614,
#   'indices': [7.0, 9, 11, 16.0],
#   'difference': 0.004303820534603653,
#   'difference_ratio': 0.0694068877526022},
#  {'t_values': [0.00764451286594286,
#    0.012134907765182132,
#    0.01020420043917612,
#    0.01146676929891429],
#   'mean_t_sub': 0.01036259759230385,
#   'indices': [0.0, 1, 1, 2.0],
#   'difference': 0.004490394899239272,
#   'difference_ratio': 0.4333271517340616},
#  {'t_values': [0.02293353859782858,
#    0.018202361647773196,
#    0.02040840087835224,
#    0.01911128216485715],
#   'mean_t_sub': 0.020163895822202793,
#   'indices': [2.0, 2, 3, 4.0],
#   'difference': 0.004731176950055385,
#   'difference_ratio': 0.2346360540528983},
#  {'t_values': [0.05351159006160002,
#    0.05460708494331959,
#    0.0510210021958806,
#    0.04968933362862859],
#   'mean_t_sub': 0.0522072527073572,
#   'indices': [6.0, 8, 9, 12.0],
#   'difference': 0.004917751314691,
#   'difference_ratio': 0.09419670753902697}]

# %%
extracted_winners = take_period_def_extract_winners(period_df,top_3_observable_metrics[:max_number_of_observable_metrics])
extracted_winners
# Out:
# {'t_values': [0.03057805146377144, 0.03033726941295533, 0.030612601317528357, 0.03057805146377144], 'mean_t_sub': 0.03052649341450664, 'indices': [3.0, 4, 5, 7.0], 'difference': 0.0002753319045730278, 'difference_ratio': 0.009019440943786422}
# indices: [3.0, 4, 5, 7.0]
# values: [0.03057805146377144, 0.03033726941295533, 0.030612601317528357, 0.03057805146377144]
# {'t_values': [0.06115610292754288, 0.06067453882591066, 0.061225202635056715, 0.06115610292754288], 'mean_t_sub': 0.06105298682901328, 'indices': [7.0, 9, 11, 15.0], 'difference': 0.0005506638091460556, 'difference_ratio': 0.009019440943786422}
# indices: [7.0, 9, 11, 15.0]
# values: [0.06115610292754288, 0.06067453882591066, 0.061225202635056715, 0.06115610292754288]
# {'t_values': [0.06880061579348574, 0.06674199270850173, 0.06632730285464478, 0.06880061579348574], 'mean_t_sub': 0.06766763178752949, 'indices': [8.0, 10, 12, 17.0], 'difference': 0.0024733129388409686, 'difference_ratio': 0.036550901420740675}
# indices: [8.0, 10, 12, 17.0]
# values: [0.06880061579348574, 0.06674199270850173, 0.06632730285464478, 0.06880061579348574]
# {'t_values': [0.0382225643297143, 0.03640472329554639, 0.035714701537116415, 0.0382225643297143], 'mean_t_sub': 0.03714113837302285, 'indices': [4.0, 5, 6, 9.0], 'difference': 0.0025078627925978828, 'difference_ratio': 0.06752250745279922}
# indices: [4.0, 5, 6, 9.0]
# values: [0.0382225643297143, 0.03640472329554639, 0.035714701537116415, 0.0382225643297143]
# {'t_values': [0.00764451286594286, 0.006067453882591066, 0.00510210021958806, 0.00764451286594286], 'mean_t_sub': 0.00661464495851621, 'indices': [0.0, 0, 0, 1.0], 'difference': 0.0025424126463548004, 'difference_ratio': 0.3843611656104837}
# indices: [0.0, 0, 0, 1.0]
# values: [0.00764451286594286, 0.006067453882591066, 0.00510210021958806, 0.00764451286594286]
#    note_name  t_values  cycle_or_t  winner_num
# 0         C3  0.030578         3.0           1
# 1         E3  0.030337         4.0           1
# 2         G3  0.030613         5.0           1
# 3         C4  0.030578         7.0           1
# 4         C3  0.061156         7.0           2
# 5         E3  0.060675         9.0           2
# 6         G3  0.061225        11.0           2
# 7         C4  0.061156        15.0           2
# 8         C3  0.068801         8.0           3
# 9         E3  0.066742        10.0           3
# 10        G3  0.066327        12.0           3
# 11        C4  0.068801        17.0           3
# 12        C3  0.038223         4.0           4
# 13        E3  0.036405         5.0           4
# 14        G3  0.035715         6.0           4
# 15        C4  0.038223         9.0           4
# 16        C3  0.007645         0.0           5
# 17        E3  0.006067         0.0           5
# 18        G3  0.005102         0.0           5
# 19        C4  0.007645         1.0           5

# %%
### what interests me, create chart of the period df, with all cycle numbers, t values and notes. 
period_df, period_df.shape
long_period_df = period_df.reset_index().melt(id_vars='index')
long_period_df.columns = ['cycle_or_t', 'note_name', 't_values']
long_period_df['cycle_or_t'] = long_period_df['cycle_or_t'] -1
# long_period_df['cycle_or_t'] = long_period_df['cycle_or_t'].astype(str)
long_period_df
long_period_df[long_period_df['cycle_or_t']>=20]
# Out:
# Empty DataFrame
# Columns: [cycle_or_t, note_name, t_values]
# Index: []

# %%
chart3 = alt.Chart(long_period_df).mark_bar(
    opacity=0.1,
    clip=True
    # xOffset=0.5
).encode(
    x=alt.X('t_values', title='Period',scale=alt.Scale(domain=[0, 0.08])),
    y=alt.Y('cycle_or_t:Q', title='Cycle' ),
    color=alt.Color('note_name', title='Note'),
).properties(
    width=600,
    height=300
)
chart3
# Out:
# alt.Chart(...)

# %%
chart1= alt.Chart(extracted_winners).mark_bar(
    opacity=0.6,
).encode(
    x=alt.X('t_values', scale=alt.Scale(domain=[0, 0.08])),
    y=alt.Y('cycle_or_t'),
    color='note_name',
    # tooltip=['note_name','t_values','cycle_or_t'],
).properties(
    width=600,
    height=300
)
chart1
# Out:
# alt.Chart(...)

# %%
top_3_observable_metrics = sorted(observable_metrics, key=lambda x: x['difference'])[:max_number_of_observable_metrics]
observable_df = pd.DataFrame(top_3_observable_metrics)
observable_df.sort_values(by='mean_t_sub',inplace=True)
## adding 1,2,3, order values to sorted by mean
observable_df['order'] = range(1,max_number_of_observable_metrics+1)
observable_df
# Out:
#                                             t_values  mean_t_sub  \
# 4  [0.00764451286594286, 0.006067453882591066, 0....    0.006615
# 0  [0.03057805146377144, 0.03033726941295533, 0.0...    0.030526
# 3  [0.0382225643297143, 0.03640472329554639, 0.03...    0.037141
# 1  [0.06115610292754288, 0.06067453882591066, 0.0...    0.061053
# 2  [0.06880061579348574, 0.06674199270850173, 0.0...    0.067668
#
#                indices  difference  difference_ratio  order
# 4     [0.0, 0, 0, 1.0]    0.002542          0.384361      1
# 0     [3.0, 4, 5, 7.0]    0.000275          0.009019      2
# 3     [4.0, 5, 6, 9.0]    0.002508          0.067523      3
# 1   [7.0, 9, 11, 15.0]    0.000551          0.009019      4
# 2  [8.0, 10, 12, 17.0]    0.002473          0.036551      5

# %% [markdown]
# En este momento probaré lo de harmonious

# %%
(0.000275/0.030509)
# Out:
# 0.009013733652364877

# %%
## adding min t_value to observable_df, 
observable_df['t_value_min'] = [min(r['t_values']) for i,r in observable_df.iterrows()]
observable_df['t_value_max'] = [max(r['t_values']) for i,r in observable_df.iterrows()]


observable_df
# Out:
#                                             t_values  mean_t_sub  \
# 4  [0.00764451286594286, 0.006067453882591066, 0....    0.006615
# 0  [0.03057805146377144, 0.03033726941295533, 0.0...    0.030526
# 3  [0.0382225643297143, 0.03640472329554639, 0.03...    0.037141
# 1  [0.06115610292754288, 0.06067453882591066, 0.0...    0.061053
# 2  [0.06880061579348574, 0.06674199270850173, 0.0...    0.067668
#
#                indices  difference  difference_ratio  order  t_value_min  \
# 4     [0.0, 0, 0, 1.0]    0.002542          0.384361      1     0.005102
# 0     [3.0, 4, 5, 7.0]    0.000275          0.009019      2     0.030337
# 3     [4.0, 5, 6, 9.0]    0.002508          0.067523      3     0.035715
# 1   [7.0, 9, 11, 15.0]    0.000551          0.009019      4     0.060675
# 2  [8.0, 10, 12, 17.0]    0.002473          0.036551      5     0.066327
#
#    t_value_max
# 4     0.007645
# 0     0.030613
# 3     0.038223
# 1     0.061225
# 2     0.068801

# %%
def add_max_cycle(observable_df):
    for i, row in observable_df.iterrows():
        indices = row['indices']
        max_cycle = max(indices)
        observable_df.at[i, 'max_cycle'] = max_cycle

    

add_max_cycle(observable_df)

# %%
chart2 = alt.Chart(observable_df).mark_bar(
    color='black'
).encode(
    x=alt.X('mean_t_sub').scale(domain=[0, 0.08]),
    y=alt.Y('order'),
    
)

chart4 = alt.Chart(observable_df).mark_text(
    color='black',
    align='center',
    dy=-10,
    fontSize=12,
).encode(
    x=alt.X('mean_t_sub').scale(domain=[0, 0.08]),
    y=alt.Y('max_cycle:Q'),
    text=alt.Text('difference:Q', format='.3s', ),
    
)
(chart1+chart2+chart3+chart4).properties(
    width=300,
    height=250,
    title='Mean note period in Cmin7 (C3,D#3,G3,A#3) Chord'
    # title='Mean note period in C Major (C3,E3,G3,C4) Triad',
).configure_title(
    fontSize=16,
)
# Out:
# alt.LayerChart(...)

# %%
# Sample frequency array (in Hertz)
frequencies =fundamental_df[note_names].to_numpy().flatten()  # C4, E4, G4 notes
note_names
# Out:
# ['C3', 'E3', 'G3', 'C4']

# %%
# Function to generate sine wave data
def generate_sine_waves(frequencies, note_names, duration=1.0, sample_rate=1000):
    t = np.linspace(0, duration, int(sample_rate * duration))
    data = []
    
    for f_ind in range(len(frequencies)):
        freq = frequencies[f_ind]
        note_name = note_names[f_ind]
        # Calculate sine wave values: sin(2π * frequency * time)
        y_values = np.sin(2 * np.pi * freq * t)  
        
        # Create DataFrame entries for this frequency
        for i in range(len(t)):
            data.append({
                'time': t[i],
                'amplitude': y_values[i],
                'frequency': f"{freq} Hz",
                'note_name':note_name
            })
            
    return pd.DataFrame(data)

# Generate the data
sine_df = generate_sine_waves(frequencies, note_names,duration=((1/frequencies[-1])*18), sample_rate=10000)
sine_df
# Out:
#           time     amplitude             frequency note_name
# 0     0.000000  0.000000e+00  130.8127826502993 Hz        C3
# 1     0.000100  8.221955e-02  130.8127826502993 Hz        C3
# 2     0.000200  1.638824e-01  130.8127826502993 Hz        C3
# 3     0.000300  2.444354e-01  130.8127826502993 Hz        C3
# 4     0.000401  3.233333e-01  130.8127826502993 Hz        C3
# ...        ...           ...                   ...       ...
# 2747  0.068400 -6.119310e-01  261.6255653005986 Hz        C4
# 2748  0.068500 -4.740412e-01  261.6255653005986 Hz        C4
# 2749  0.068600 -3.233333e-01  261.6255653005986 Hz        C4
# 2750  0.068700 -1.638824e-01  261.6255653005986 Hz        C4
# 2751  0.068801  9.802126e-15  261.6255653005986 Hz        C4
#
# [2752 rows x 4 columns]

# %%
# Create Altair visualization
chart = alt.Chart(sine_df).mark_line(
    opacity=0.5,
    clip=True
).encode(
    x=alt.X('time:Q', title='Time (seconds)', scale=alt.Scale(domain=[0.02, 0.040])),
    y=alt.Y('amplitude:Q', title='Amplitude'),
    color=alt.Color('note_name:N', title='Note Name')
).properties(
    width=500,
    height=250,
    title='Sine Waves at Different Frequencies'
)

chart
# Out:
# alt.Chart(...)

# %%
min_difference =min(observable_df['difference'])
max_difference =max(observable_df['difference'])

# %%
rect_chart = alt.Chart(observable_df).mark_rect(
    opacity=0.8,
    clip=True
).encode(
    x=alt.X('t_value_min', scale=alt.Scale(domain=[0.02, 0.04])),
    x2='t_value_max',
    color=alt.Color('difference', scale=alt.Scale(domain=[0,0.0025], range=['green','red']))
)
(chart+rect_chart).configure_title(
    fontSize=16,
    anchor='end',
    color='black'
).properties(
    title='Sine Waves Approximate alignment of C major (C3, E3, G3, C4) Triad',
    width=500,
    height=255,
).configure_view(fill='white').configure_axis(grid=False)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Making grid of period_df

# %%
grid_p_df = period_df.melt(ignore_index=False).reset_index()
grid_p_df.columns = ['cycle_or_t', 'note_name', 't_values']
grid_p_df['t_values'] = round(grid_p_df['t_values'] * 10**3,2)

# %%
chart_grid = alt.Chart(grid_p_df).mark_rect(
    color='white',
    stroke='black',
    
).encode(
    x=alt.X('note_name',
            axis=alt.Axis(orient='top',title='Note Name', labelAngle=0),
            sort=note_names),
    y=alt.Y('cycle_or_t:Q',
             scale=alt.Scale(domain=[0,19],reverse=True),
             axis=alt.Axis(title='Cycle', tickCount=20,)),
    
)
text = alt.Chart(grid_p_df).mark_text(baseline='bottom').encode(
        x=alt.X('note_name',
                sort=note_names),
    y=alt.Y('cycle_or_t:Q',
             scale=alt.Scale(domain=[0,19],reverse=True),
             axis=alt.Axis(title='Cycle', tickCount=20)),
    text='t_values',
    
)
chart_grid = chart_grid + text
chart_grid.properties(width=250)
# Out:
# alt.LayerChart(...)

# %%
## changing extracted_winners to match period_df
ext_win = extracted_winners.copy()
ext_win['cycle_or_t_end'] = ext_win['cycle_or_t'] +1
ext_win
# Out:
#    note_name  t_values  cycle_or_t  winner_num  cycle_or_t_end
# 0         C3  0.030578         3.0           1             4.0
# 1         E3  0.030337         4.0           1             5.0
# 2         G3  0.030613         5.0           1             6.0
# 3         C4  0.030578         7.0           1             8.0
# 4         C3  0.061156         7.0           2             8.0
# 5         E3  0.060675         9.0           2            10.0
# 6         G3  0.061225        11.0           2            12.0
# 7         C4  0.061156        15.0           2            16.0
# 8         C3  0.068801         8.0           3             9.0
# 9         E3  0.066742        10.0           3            11.0
# 10        G3  0.066327        12.0           3            13.0
# 11        C4  0.068801        17.0           3            18.0
# 12        C3  0.038223         4.0           4             5.0
# 13        E3  0.036405         5.0           4             6.0
# 14        G3  0.035715         6.0           4             7.0
# 15        C4  0.038223         9.0           4            10.0
# 16        C3  0.007645         0.0           5             1.0
# 17        E3  0.006067         0.0           5             1.0
# 18        G3  0.005102         0.0           5             1.0
# 19        C4  0.007645         1.0           5             2.0

# %%
note_names
# Out:
# ['C3', 'E3', 'G3', 'C4']

# %%
chart_rect_win = alt.Chart(ext_win).mark_rect().encode(
    x=alt.X('note_name',
            axis=alt.Axis(orient='top',title='Note Name', labelAngle=0),
            sort=note_names),
    y=alt.Y('cycle_or_t',
             scale=alt.Scale(domain=[0,19],reverse=True),
             axis=alt.Axis(title='Cycle', tickCount=20,)),
    y2='cycle_or_t_end',
    color=alt.Color('winner_num:O',title='Winner Order Preference', scale=alt.Scale(scheme='goldgreen'))
)
chart_rect_win
# Out:
# alt.Chart(...)

# %%
(chart_grid+chart_rect_win+text).properties(width=250, title='Winning Cycles of the Cmin7').configure_title(
fontSize=16,
anchor='middle',	
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Making bound df visualization with rectangles

# %%
## mixing bound_df with note_names

bdf = bound_df[['bass','last_note','ratio','bass_value','last_note_value']].copy()
bdf.sort_values(by='ratio', ascending=True, inplace=True)
bdf['winners']= range(1,len(bdf)+1)


bass_bdf = bdf[['bass','bass_value','winners']].copy()
bass_bdf['note_name'] = note_names[0]
bass_bdf.rename(columns={'bass':'cycle_or_t'}, inplace=True)
# bass_bdf['cycle_or_t'] = bass_bdf['cycle_or_t'] +1

bass_bdf
# Out:
#     cycle_or_t  bass_value  winners note_name
# 0            0    0.007645        1        C3
# 1            1    0.015289        2        C3
# 2            2    0.022934        3        C3
# 3            3    0.030578        4        C3
# 4            4    0.038223        5        C3
# 5            5    0.045867        6        C3
# 6            6    0.053512        7        C3
# 7            7    0.061156        8        C3
# 8            8    0.068801        9        C3
# 9            9    0.076445       10        C3
# 10           8    0.068801       11        C3
# 11           8    0.068801       12        C3
# 12           7    0.061156       13        C3
# 13           7    0.061156       14        C3
# 14           6    0.053512       15        C3
# 15           6    0.053512       16        C3
# 16           5    0.045867       17        C3
# 17           5    0.045867       18        C3
# 18           4    0.038223       19        C3
# 19           4    0.038223       20        C3
# 20           3    0.030578       21        C3
# 21           3    0.030578       22        C3
# 22           2    0.022934       23        C3
# 23           2    0.022934       24        C3
# 24           1    0.015289       25        C3
# 25           1    0.015289       26        C3
# 26           0    0.007645       27        C3
# 27           0    0.007645       28        C3

# %%
last_note = bdf[['last_note','last_note_value','winners']].copy()
last_note['note_name'] = note_names[-1]
last_note.rename(columns={'last_note':'cycle_or_t'}, inplace=True)
# last_note['cycle_or_t'] = last_note['cycle_or_t'] +1

last_note
# Out:
#     cycle_or_t  last_note_value  winners note_name
# 0            1         0.007645        1        C4
# 1            3         0.015289        2        C4
# 2            5         0.022934        3        C4
# 3            7         0.030578        4        C4
# 4            9         0.038223        5        C4
# 5           11         0.045867        6        C4
# 6           13         0.053512        7        C4
# 7           15         0.061156        8        C4
# 8           17         0.068801        9        C4
# 9           18         0.072623       10        C4
# 10          18         0.072623       11        C4
# 11          16         0.064978       12        C4
# 12          16         0.064978       13        C4
# 13          14         0.057334       14        C4
# 14          14         0.057334       15        C4
# 15          12         0.049689       16        C4
# 16          12         0.049689       17        C4
# 17          10         0.042045       18        C4
# 18          10         0.042045       19        C4
# 19           8         0.034400       20        C4
# 20           8         0.034400       21        C4
# 21           6         0.026756       22        C4
# 22           6         0.026756       23        C4
# 23           4         0.019111       24        C4
# 24           4         0.019111       25        C4
# 25           2         0.011467       26        C4
# 26           2         0.011467       27        C4
# 27           0         0.003822       28        C4

# %%
bass_bdf['cycle_or_t_end'] = bass_bdf['cycle_or_t']+1
last_note['cycle_or_t_end'] = last_note['cycle_or_t']+1

### only retrieing top 10  winners
bass_bdf = bass_bdf[bass_bdf['winners']<=10]
last_note = last_note[last_note['winners']<=10]

# %%
bound_chart_bass = alt.Chart(bass_bdf).mark_rect().encode(
    x=alt.X('note_name',
            axis=alt.Axis(orient='top',title='Note Name', labelAngle=0),
            sort=note_names),
    y=alt.Y('cycle_or_t',
             scale=alt.Scale(domain=[0,19],reverse=True),
             axis=alt.Axis(title='Cycle', tickCount=20,)),
    y2='cycle_or_t_end',
    color=alt.Color('winners:O',title='Winner Order Preference', scale=alt.Scale(scheme='yellowgreen'))
)



bound_chart_sop  = alt.Chart(last_note).mark_rect().encode(
    x=alt.X('note_name',
            axis=alt.Axis(orient='top',title='Note Name', labelAngle=0),
            sort=note_names),
    y=alt.Y('cycle_or_t',
             scale=alt.Scale(domain=[0,19],reverse=True),
             axis=alt.Axis(title='Cycle', tickCount=20,)),
    y2='cycle_or_t_end',
    color=alt.Color('winners:O',title='Winner Order Preference', scale=alt.Scale())
)

(chart_grid+bound_chart_bass+bound_chart_sop+text).properties(width=250, title='Bound Candidates C Major Triad').configure_title(
fontSize=16,
anchor='middle',	
)
# Out:
# alt.LayerChart(...)

# %%
#### now make border with grid rectangles

#####
## The table must be note_name[1], note_name [-2] and y=cycle_or_t y2 =last_note_cycle_t_end
###
new_df = pd.DataFrame(
    {
        "note_name":[],
        'before_last':[],
        'cycle_or_t':[],
        'cycle_or_t_end':[],
        'winners':[]
    }
)

after_bass = note_names[1]
before_last = note_names[-2]
for i,r in bass_bdf.iterrows():
    winner_num = r['winners']
    ##searching in bass_df winner
    cycle_to_begin = r['cycle_or_t']
    cycle_to_end = last_note[last_note['winners'] == winner_num]['cycle_or_t'].values[0]+1
    new_df.loc[i] = {
        'note_name':after_bass,
        'before_last':before_last,
        'cycle_or_t':cycle_to_begin,
        'cycle_or_t_end':cycle_to_end,
        'winners':winner_num
    }
new_df
# Out:
#   note_name before_last  cycle_or_t  cycle_or_t_end  winners
# 0        E3          G3           0               2        1
# 1        E3          G3           1               4        2
# 2        E3          G3           2               6        3
# 3        E3          G3           3               8        4
# 4        E3          G3           4              10        5
# 5        E3          G3           5              12        6
# 6        E3          G3           6              14        7
# 7        E3          G3           7              16        8
# 8        E3          G3           8              18        9
# 9        E3          G3           9              19       10

# %%
## chart

inside_rect = alt.Chart(new_df).mark_rect(
    filled=False,
    strokeWidth=2,
    strokeOpacity=0.5,
    baseline='middle',
    # width=30
    
    
).encode(
    x=alt.X('note_name', sort=note_names,bandPosition=0),
    x2=alt.X2('before_last',bandPosition=1),
    y=alt.Y('cycle_or_t',
             scale=alt.Scale(domain=[0,19],reverse=True),
             axis=alt.Axis(title='Cycle', tickCount=20,)),
    y2='cycle_or_t_end',
    color=alt.Color('winners:O',title='Winner Order Preference', scale=alt.Scale(scheme='rainbow'))

)

# (chart_grid+inside_rect).properties(width=250).to_json()

# %%
(chart_grid+bound_chart_bass+bound_chart_sop+inside_rect+text).properties(width=250, title='Search Candidates C major').configure_title(
fontSize=16,
anchor='middle',	
).configure_view(
    strokeOpacity=0.7
)
# Out:
# alt.LayerChart(...)

# %%
import json
from pprint import pprint
pprint(json.loads((chart_grid+bound_chart_bass+bound_chart_sop+inside_rect+text).properties(width=250).to_json()))
# Out:
# {'$schema': 'https://vega.github.io/schema/vega-lite/v5.20.1.json',
#  'config': {'view': {'continuousHeight': 300, 'continuousWidth': 300}},
#  'data': {'name': 'data-6546ca5d5c25fb9a8da0af03b1968f16'},
#  'datasets': {'data-30216b18e76b1fa6b301b20685a6e0cc': [{'cycle_or_t': 1,
#                                                          'cycle_or_t_end': 2,
#                                                          'last_note_value': 0.00764451286594286,
#                                                          'note_name': 'C4',
#                                                          'winners': 1},
#                                                         {'cycle_or_t': 3,
#                                                          'cycle_or_t_end': 4,
#                                                          'last_note_value': 0.01528902573188572,
#                                                          'note_name': 'C4',
#                                                          'winners': 2},
#                                                         {'cycle_or_t': 5,
#                                                          'cycle_or_t_end': 6,
#                                                          'last_note_value': 0.02293353859782858,
#                                                          'note_name': 'C4',
#                                                          'winners': 3},
#                                                         {'cycle_or_t': 7,
#                                                          'cycle_or_t_end': 8,
#                                                          'last_note_value': 0.03057805146377144,
#                                                          'note_name': 'C4',
#                                                          'winners': 4},
#                                                         {'cycle_or_t': 9,
#                                                          'cycle_or_t_end': 10,
#                                                          'last_note_value': 0.0382225643297143,
#                                                          'note_name': 'C4',
#                                                          'winners': 5},
#                                                         {'cycle_or_t': 11,
#                                                          'cycle_or_t_end': 12,
#                                                          'last_note_value': 0.04586707719565716,
#                                                          'note_name': 'C4',
#                                                          'winners': 6},
#                                                         {'cycle_or_t': 13,
#                                                          'cycle_or_t_end': 14,
#                                                          'last_note_value': 0.05351159006160002,
#                                                          'note_name': 'C4',
#                                                          'winners': 7},
#                                                         {'cycle_or_t': 15,
#                                                          'cycle_or_t_end': 16,
#                                                          'last_note_value': 0.06115610292754288,
#                                                          'note_name': 'C4',
#                                                          'winners': 8},
#                                                         {'cycle_or_t': 17,
#                                                          'cycle_or_t_end': 18,
#                                                          'last_note_value': 0.06880061579348574,
#                                                          'note_name': 'C4',
#                                                          'winners': 9},
#                                                         {'cycle_or_t': 18,
#                                                          'cycle_or_t_end': 19,
#                                                          'last_note_value': 0.07262287222645716,
#                                                          'note_name': 'C4',
#                                                          'winners': 10}],
#               'data-3684c1dc87115f53f8977458e1d5b291': [{'before_last': 'G3',
#                                                          'cycle_or_t': 0,
#                                                          'cycle_or_t_end': 2,
#                                                          'note_name': 'E3',
#                                                          'winners': 1},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 1,
#                                                          'cycle_or_t_end': 4,
#                                                          'note_name': 'E3',
#                                                          'winners': 2},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 2,
#                                                          'cycle_or_t_end': 6,
#                                                          'note_name': 'E3',
#                                                          'winners': 3},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 3,
#                                                          'cycle_or_t_end': 8,
#                                                          'note_name': 'E3',
#                                                          'winners': 4},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 4,
#                                                          'cycle_or_t_end': 10,
#                                                          'note_name': 'E3',
#                                                          'winners': 5},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 5,
#                                                          'cycle_or_t_end': 12,
#                                                          'note_name': 'E3',
#                                                          'winners': 6},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 6,
#                                                          'cycle_or_t_end': 14,
#                                                          'note_name': 'E3',
#                                                          'winners': 7},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 7,
#                                                          'cycle_or_t_end': 16,
#                                                          'note_name': 'E3',
#                                                          'winners': 8},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 8,
#                                                          'cycle_or_t_end': 18,
#                                                          'note_name': 'E3',
#                                                          'winners': 9},
#                                                         {'before_last': 'G3',
#                                                          'cycle_or_t': 9,
#                                                          'cycle_or_t_end': 19,
#                                                          'note_name': 'E3',
#                                                          'winners': 10}],
#               'data-6546ca5d5c25fb9a8da0af03b1968f16': [{'cycle_or_t': 1,
#                                                          'note_name': 'C3',
#                                                          't_values': 7.64},
#                                                         {'cycle_or_t': 2,
#                                                          'note_name': 'C3',
#                                                          't_values': 15.29},
#                                                         {'cycle_or_t': 3,
#                                                          'note_name': 'C3',
#                                                          't_values': 22.93},
#                                                         {'cycle_or_t': 4,
#                                                          'note_name': 'C3',
#                                                          't_values': 30.58},
#                                                         {'cycle_or_t': 5,
#                                                          'note_name': 'C3',
#                                                          't_values': 38.22},
#                                                         {'cycle_or_t': 6,
#                                                          'note_name': 'C3',
#                                                          't_values': 45.87},
#                                                         {'cycle_or_t': 7,
#                                                          'note_name': 'C3',
#                                                          't_values': 53.51},
#                                                         {'cycle_or_t': 8,
#                                                          'note_name': 'C3',
#                                                          't_values': 61.16},
#                                                         {'cycle_or_t': 9,
#                                                          'note_name': 'C3',
#                                                          't_values': 68.8},
#                                                         {'cycle_or_t': 10,
#                                                          'note_name': 'C3',
#                                                          't_values': 76.45},
#                                                         {'cycle_or_t': 11,
#                                                          'note_name': 'C3',
#                                                          't_values': 84.09},
#                                                         {'cycle_or_t': 12,
#                                                          'note_name': 'C3',
#                                                          't_values': 91.73},
#                                                         {'cycle_or_t': 13,
#                                                          'note_name': 'C3',
#                                                          't_values': 99.38},
#                                                         {'cycle_or_t': 14,
#                                                          'note_name': 'C3',
#                                                          't_values': 107.02},
#                                                         {'cycle_or_t': 15,
#                                                          'note_name': 'C3',
#                                                          't_values': 114.67},
#                                                         {'cycle_or_t': 16,
#                                                          'note_name': 'C3',
#                                                          't_values': 122.31},
#                                                         {'cycle_or_t': 17,
#                                                          'note_name': 'C3',
#                                                          't_values': 129.96},
#                                                         {'cycle_or_t': 18,
#                                                          'note_name': 'C3',
#                                                          't_values': 137.6},
#                                                         {'cycle_or_t': 19,
#                                                          'note_name': 'C3',
#                                                          't_values': 145.25},
#                                                         {'cycle_or_t': 1,
#                                                          'note_name': 'E3',
#                                                          't_values': 6.07},
#                                                         {'cycle_or_t': 2,
#                                                          'note_name': 'E3',
#                                                          't_values': 12.13},
#                                                         {'cycle_or_t': 3,
#                                                          'note_name': 'E3',
#                                                          't_values': 18.2},
#                                                         {'cycle_or_t': 4,
#                                                          'note_name': 'E3',
#                                                          't_values': 24.27},
#                                                         {'cycle_or_t': 5,
#                                                          'note_name': 'E3',
#                                                          't_values': 30.34},
#                                                         {'cycle_or_t': 6,
#                                                          'note_name': 'E3',
#                                                          't_values': 36.4},
#                                                         {'cycle_or_t': 7,
#                                                          'note_name': 'E3',
#                                                          't_values': 42.47},
#                                                         {'cycle_or_t': 8,
#                                                          'note_name': 'E3',
#                                                          't_values': 48.54},
#                                                         {'cycle_or_t': 9,
#                                                          'note_name': 'E3',
#                                                          't_values': 54.61},
#                                                         {'cycle_or_t': 10,
#                                                          'note_name': 'E3',
#                                                          't_values': 60.67},
#                                                         {'cycle_or_t': 11,
#                                                          'note_name': 'E3',
#                                                          't_values': 66.74},
#                                                         {'cycle_or_t': 12,
#                                                          'note_name': 'E3',
#                                                          't_values': 72.81},
#                                                         {'cycle_or_t': 13,
#                                                          'note_name': 'E3',
#                                                          't_values': 78.88},
#                                                         {'cycle_or_t': 14,
#                                                          'note_name': 'E3',
#                                                          't_values': 84.94},
#                                                         {'cycle_or_t': 15,
#                                                          'note_name': 'E3',
#                                                          't_values': 91.01},
#                                                         {'cycle_or_t': 16,
#                                                          'note_name': 'E3',
#                                                          't_values': 97.08},
#                                                         {'cycle_or_t': 17,
#                                                          'note_name': 'E3',
#                                                          't_values': 103.15},
#                                                         {'cycle_or_t': 18,
#                                                          'note_name': 'E3',
#                                                          't_values': 109.21},
#                                                         {'cycle_or_t': 19,
#                                                          'note_name': 'E3',
#                                                          't_values': 115.28},
#                                                         {'cycle_or_t': 1,
#                                                          'note_name': 'G3',
#                                                          't_values': 5.1},
#                                                         {'cycle_or_t': 2,
#                                                          'note_name': 'G3',
#                                                          't_values': 10.2},
#                                                         {'cycle_or_t': 3,
#                                                          'note_name': 'G3',
#                                                          't_values': 15.31},
#                                                         {'cycle_or_t': 4,
#                                                          'note_name': 'G3',
#                                                          't_values': 20.41},
#                                                         {'cycle_or_t': 5,
#                                                          'note_name': 'G3',
#                                                          't_values': 25.51},
#                                                         {'cycle_or_t': 6,
#                                                          'note_name': 'G3',
#                                                          't_values': 30.61},
#                                                         {'cycle_or_t': 7,
#                                                          'note_name': 'G3',
#                                                          't_values': 35.71},
#                                                         {'cycle_or_t': 8,
#                                                          'note_name': 'G3',
#                                                          't_values': 40.82},
#                                                         {'cycle_or_t': 9,
#                                                          'note_name': 'G3',
#                                                          't_values': 45.92},
#                                                         {'cycle_or_t': 10,
#                                                          'note_name': 'G3',
#                                                          't_values': 51.02},
#                                                         {'cycle_or_t': 11,
#                                                          'note_name': 'G3',
#                                                          't_values': 56.12},
#                                                         {'cycle_or_t': 12,
#                                                          'note_name': 'G3',
#                                                          't_values': 61.23},
#                                                         {'cycle_or_t': 13,
#                                                          'note_name': 'G3',
#                                                          't_values': 66.33},
#                                                         {'cycle_or_t': 14,
#                                                          'note_name': 'G3',
#                                                          't_values': 71.43},
#                                                         {'cycle_or_t': 15,
#                                                          'note_name': 'G3',
#                                                          't_values': 76.53},
#                                                         {'cycle_or_t': 16,
#                                                          'note_name': 'G3',
#                                                          't_values': 81.63},
#                                                         {'cycle_or_t': 17,
#                                                          'note_name': 'G3',
#                                                          't_values': 86.74},
#                                                         {'cycle_or_t': 18,
#                                                          'note_name': 'G3',
#                                                          't_values': 91.84},
#                                                         {'cycle_or_t': 19,
#                                                          'note_name': 'G3',
#                                                          't_values': 96.94},
#                                                         {'cycle_or_t': 1,
#                                                          'note_name': 'C4',
#                                                          't_values': 3.82},
#                                                         {'cycle_or_t': 2,
#                                                          'note_name': 'C4',
#                                                          't_values': 7.64},
#                                                         {'cycle_or_t': 3,
#                                                          'note_name': 'C4',
#                                                          't_values': 11.47},
#                                                         {'cycle_or_t': 4,
#                                                          'note_name': 'C4',
#                                                          't_values': 15.29},
#                                                         {'cycle_or_t': 5,
#                                                          'note_name': 'C4',
#                                                          't_values': 19.11},
#                                                         {'cycle_or_t': 6,
#                                                          'note_name': 'C4',
#                                                          't_values': 22.93},
#                                                         {'cycle_or_t': 7,
#                                                          'note_name': 'C4',
#                                                          't_values': 26.76},
#                                                         {'cycle_or_t': 8,
#                                                          'note_name': 'C4',
#                                                          't_values': 30.58},
#                                                         {'cycle_or_t': 9,
#                                                          'note_name': 'C4',
#                                                          't_values': 34.4},
#                                                         {'cycle_or_t': 10,
#                                                          'note_name': 'C4',
#                                                          't_values': 38.22},
#                                                         {'cycle_or_t': 11,
#                                                          'note_name': 'C4',
#                                                          't_values': 42.04},
#                                                         {'cycle_or_t': 12,
#                                                          'note_name': 'C4',
#                                                          't_values': 45.87},
#                                                         {'cycle_or_t': 13,
#                                                          'note_name': 'C4',
#                                                          't_values': 49.69},
#                                                         {'cycle_or_t': 14,
#                                                          'note_name': 'C4',
#                                                          't_values': 53.51},
#                                                         {'cycle_or_t': 15,
#                                                          'note_name': 'C4',
#                                                          't_values': 57.33},
#                                                         {'cycle_or_t': 16,
#                                                          'note_name': 'C4',
#                                                          't_values': 61.16},
#                                                         {'cycle_or_t': 17,
#                                                          'note_name': 'C4',
#                                                          't_values': 64.98},
#                                                         {'cycle_or_t': 18,
#                                                          'note_name': 'C4',
#                                                          't_values': 68.8},
#                                                         {'cycle_or_t': 19,
#                                                          'note_name': 'C4',
#                                                          't_values': 72.62}],
#               'data-e9b5ba39a1fdd224ef625a82bd772fad': [{'bass_value': 0.00764451286594286,
#                                                          'cycle_or_t': 0,
#                                                          'cycle_or_t_end': 1,
#                                                          'note_name': 'C3',
#                                                          'winners': 1},
#                                                         {'bass_value': 0.01528902573188572,
#                                                          'cycle_or_t': 1,
#                                                          'cycle_or_t_end': 2,
#                                                          'note_name': 'C3',
#                                                          'winners': 2},
#                                                         {'bass_value': 0.02293353859782858,
#                                                          'cycle_or_t': 2,
#                                                          'cycle_or_t_end': 3,
#                                                          'note_name': 'C3',
#                                                          'winners': 3},
#                                                         {'bass_value': 0.03057805146377144,
#                                                          'cycle_or_t': 3,
#                                                          'cycle_or_t_end': 4,
#                                                          'note_name': 'C3',
#                                                          'winners': 4},
#                                                         {'bass_value': 0.0382225643297143,
#                                                          'cycle_or_t': 4,
#                                                          'cycle_or_t_end': 5,
#                                                          'note_name': 'C3',
#                                                          'winners': 5},
#                                                         {'bass_value': 0.04586707719565716,
#                                                          'cycle_or_t': 5,
#                                                          'cycle_or_t_end': 6,
#                                                          'note_name': 'C3',
#                                                          'winners': 6},
#                                                         {'bass_value': 0.05351159006160002,
#                                                          'cycle_or_t': 6,
#                                                          'cycle_or_t_end': 7,
#                                                          'note_name': 'C3',
#                                                          'winners': 7},
#                                                         {'bass_value': 0.06115610292754288,
#                                                          'cycle_or_t': 7,
#                                                          'cycle_or_t_end': 8,
#                                                          'note_name': 'C3',
#                                                          'winners': 8},
#                                                         {'bass_value': 0.06880061579348574,
#                                                          'cycle_or_t': 8,
#                                                          'cycle_or_t_end': 9,
#                                                          'note_name': 'C3',
#                                                          'winners': 9},
#                                                         {'bass_value': 0.0764451286594286,
#                                                          'cycle_or_t': 9,
#                                                          'cycle_or_t_end': 10,
#                                                          'note_name': 'C3',
#                                                          'winners': 10}]},
#  'layer': [{'encoding': {'x': {'axis': {'labelAngle': 0,
#                                         'orient': 'top',
#                                         'title': 'Note Name'},
#                                'field': 'note_name',
#                                'sort': ['C3', 'E3', 'G3', 'C4'],
#                                'type': 'nominal'},
#                          'y': {'axis': {'tickCount': 20, 'title': 'Cycle'},
#                                'field': 'cycle_or_t',
#                                'scale': {'domain': [0, 19], 'reverse': True},
#                                'type': 'quantitative'}},
#             'mark': {'color': 'white', 'stroke': 'black', 'type': 'rect'}},
#            {'encoding': {'text': {'field': 't_values', 'type': 'quantitative'},
#                          'x': {'field': 'note_name',
#                                'sort': ['C3', 'E3', 'G3', 'C4'],
#                                'type': 'nominal'},
#                          'y': {'axis': {'tickCount': 20, 'title': 'Cycle'},
#                                'field': 'cycle_or_t',
#                                'scale': {'domain': [0, 19], 'reverse': True},
#                                'type': 'quantitative'}},
#             'mark': {'baseline': 'bottom', 'type': 'text'}},
#            {'data': {'name': 'data-e9b5ba39a1fdd224ef625a82bd772fad'},
#             'encoding': {'color': {'field': 'winners',
#                                    'scale': {'scheme': 'yellowgreen'},
#                                    'title': 'Winner Order Preference',
#                                    'type': 'ordinal'},
#                          'x': {'axis': {'labelAngle': 0,
#                                         'orient': 'top',
#                                         'title': 'Note Name'},
#                                'field': 'note_name',
#                                'sort': ['C3', 'E3', 'G3', 'C4'],
#                                'type': 'nominal'},
#                          'y': {'axis': {'tickCount': 20, 'title': 'Cycle'},
#                                'field': 'cycle_or_t',
#                                'scale': {'domain': [0, 19], 'reverse': True},
#                                'type': 'quantitative'},
#                          'y2': {'field': 'cycle_or_t_end'}},
#             'mark': {'type': 'rect'}},
#            {'data': {'name': 'data-30216b18e76b1fa6b301b20685a6e0cc'},
#             'encoding': {'color': {'field': 'winners',
#                                    'scale': {},
#                                    'title': 'Winner Order Preference',
#                                    'type': 'ordinal'},
#                          'x': {'axis': {'labelAngle': 0,
#                                         'orient': 'top',
#                                         'title': 'Note Name'},
#                                'field': 'note_name',
#                                'sort': ['C3', 'E3', 'G3', 'C4'],
#                                'type': 'nominal'},
#                          'y': {'axis': {'tickCount': 20, 'title': 'Cycle'},
#                                'field': 'cycle_or_t',
#                                'scale': {'domain': [0, 19], 'reverse': True},
#                                'type': 'quantitative'},
#                          'y2': {'field': 'cycle_or_t_end'}},
#             'mark': {'type': 'rect'}},
#            {'data': {'name': 'data-3684c1dc87115f53f8977458e1d5b291'},
#             'encoding': {'color': {'field': 'winners',
#                                    'scale': {'scheme': 'rainbow'},
#                                    'title': 'Winner Order Preference',
#                                    'type': 'ordinal'},
#                          'x': {'bandPosition': 0,
#                                'field': 'note_name',
#                                'sort': ['C3', 'E3', 'G3', 'C4'],
#                                'type': 'nominal'},
#                          'x2': {'bandPosition': 1, 'field': 'before_last'},
#                          'y': {'axis': {'tickCount': 20, 'title': 'Cycle'},
#                                'field': 'cycle_or_t',
#                                'scale': {'domain': [0, 19], 'reverse': True},
#                                'type': 'quantitative'},
#                          'y2': {'field': 'cycle_or_t_end'}},
#             'mark': {'baseline': 'middle',
#                      'filled': False,
#                      'strokeOpacity': 0.5,
#                      'strokeWidth': 2,
#                      'type': 'rect'}},
#            {'data': {'name': 'data-6546ca5d5c25fb9a8da0af03b1968f16'},
#             'encoding': {'text': {'field': 't_values', 'type': 'quantitative'},
#                          'x': {'field': 'note_name',
#                                'sort': ['C3', 'E3', 'G3', 'C4'],
#                                'type': 'nominal'},
#                          'y': {'axis': {'tickCount': 20, 'title': 'Cycle'},
#                                'field': 'cycle_or_t',
#                                'scale': {'domain': [0, 19], 'reverse': True},
#                                'type': 'quantitative'}},
#             'mark': {'baseline': 'bottom', 'type': 'text'}}],
#  'width': 250}

# %%
t_value_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 t_value_df
#
# NameError: name 't_value_df' is not defined

# %%
type_of_note_and_cycle.join(t_value_df, on=['winners','index'])
type_of_note_and_cycle
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[132], line 1
# ----> 1 type_of_note_and_cycle.join(t_value_df, on=['winners','index'])
#       2 type_of_note_and_cycle
#
# NameError: name 'type_of_note_and_cycle' is not defined

# %% [markdown]
# Faceted delta t and t sub

# %%
#notes 
note_name_mega_array = [
    # ['C3','C4'],
    # ['C3','G3'],
    # ['C3','E3'],
    ['C3', 'E3','G3'],
    ['C3', 'D#3','G3'],
    ['C3','E3','G#3'],
    ['C3','D#3','F#3'],
    ['C3','E3','F#3'],
    ['C3','D3','G3'],
     ['C3','C#3','G#3'],
    # ['C3','D#3'],

    # ['C3','G#3'],
    
    # ['C3','F#3'],
  
    # ['C3','D3'],
    # ['C3','C#3'],
   
    

]

titles=[
        # 'Octave',
        # 'Fifth',
        # 'Major Third',
        'Major Triad',
       
        
        'Minor Triad',
        'Augmented Fifth Triad',
        'Diminished Fifth Triad',
        'Flat Fifth Triad',
        'Suspended 2nd Triad',
        'Maj7th inversion without 3rd',
        
        # 'Minor Third',
        # 'Minor Sixth',
        
        # 'Diminished Fifth',
        
        # 'Major 2nd',
        # 'Minor 2nd',
        

        ]

# %% [markdown]
# Now loop through each and create a graph

# %%
def generate_observable_df(note_names, fundamental_df, max_number_of_observable_metrics,max=20, metric_to_sort_by='difference_ratio'):
    period_df = calculate_period_dataframe(note_names,fundamental_df,max=max)
    bound_df = finding_min_difference_with_lower_upper_bound(period_df)
    bound_df.sort_values(by='ratio', ascending=True, inplace=True)
    each_pair = choosing_bounds_binary_search(period_df,bound_df)
    observable_metrics=[]
    for item in each_pair:
        observable_metrics.append(item['observable_metrics'])
    sorted_observable_metrics = sorted(observable_metrics, key=lambda x: x[metric_to_sort_by])
    return pd.DataFrame(sorted_observable_metrics[:max_number_of_observable_metrics])

# %%
generate_observable_df( ['B2','F#3','B3','F#4','B4','D5'],fundamental_df, max_number_of_observable_metrics=5,max=20)
# Out:
#                                             t_values  mean_t_sub  \
# 0  [0.0382225643297143, 0.03783840820463204, 0.03...    0.032278
# 1  [0.0764451286594286, 0.07567681640926407, 0.07...    0.064556
# 2  [0.05351159006160002, 0.05405486886376005, 0.0...    0.046240
# 3  [0.06880061579348574, 0.07027132952288806, 0.0...    0.060203
# 4  [0.06115610292754288, 0.06486584263651206, 0.0...    0.053672
#
#                        indices  difference  difference_ratio
# 0       [4.0, 6, 8, 8, 8, 8.0]    0.020390          0.631705
# 1  [9.0, 13, 17, 17, 17, 17.0]    0.040780          0.631705
# 2   [6.0, 9, 12, 12, 12, 12.0]    0.029452          0.636940
# 3  [8.0, 12, 16, 16, 16, 16.0]    0.038515          0.639747
# 4  [7.0, 11, 14, 14, 14, 14.0]    0.034494          0.642685

# %%
def obs_metric_to_list_of_dict(observable_df):
    columns = list(observable_df.columns)
    list_of_dicts = []
    for i,row in observable_df.iterrows():
        list_of_dicts.append(row.to_dict())
    
    return list_of_dicts

# %%
take_period_def_extract_winners(period_df,obs_metric_to_list_of_dict(observable_df))
# Out:
# {'t_values': [0.01528902573188572, 0.0128564869306645, 0.015306300658764179, 0.012871013354750365], 'mean_t_sub': 0.014080706669016192, 'indices': [1.0, 1, 2, 2.0], 'difference': 0.002449813728099678, 'difference_ratio': 0.17398372011330626, 'order': 1, 't_value_min': 0.0128564869306645, 't_value_max': 0.015306300658764179, 'max_cycle': 2.0}
# indices: [1.0, 1, 2, 2.0]
# values: [0.01528902573188572, 0.0128564869306645, 0.015306300658764179, 0.012871013354750365]
# {'t_values': [0.03057805146377144, 0.03214121732666125, 0.030612601317528357, 0.03003236449441752], 'mean_t_sub': 0.030841058650594638, 'indices': [3.0, 4, 5, 6.0], 'difference': 0.0021088528322437336, 'difference_ratio': 0.0683780948032753, 'order': 2, 't_value_min': 0.03003236449441752, 't_value_max': 0.03214121732666125, 'max_cycle': 6.0}
# indices: [3.0, 4, 5, 6.0]
# values: [0.03057805146377144, 0.03214121732666125, 0.030612601317528357, 0.03003236449441752]
# {'t_values': [0.04586707719565716, 0.04499770425732575, 0.04591890197629254, 0.04719371563408468], 'mean_t_sub': 0.04599434976584003, 'indices': [5.0, 6, 8, 10.0], 'difference': 0.0021960113767589273, 'difference_ratio': 0.04774524235996273, 'order': 3, 't_value_min': 0.04499770425732575, 't_value_max': 0.04719371563408468, 'max_cycle': 10.0}
# indices: [5.0, 6, 8, 10.0]
# values: [0.04586707719565716, 0.04499770425732575, 0.04591890197629254, 0.04719371563408468]
# {'t_values': [0.05351159006160002, 0.051425947722658, 0.0510210021958806, 0.05148405341900146], 'mean_t_sub': 0.051860648349785016, 'indices': [6.0, 7, 9, 11.0], 'difference': 0.002490587865719422, 'difference_ratio': 0.048024618761437966, 'order': 4, 't_value_min': 0.0510210021958806, 't_value_max': 0.05351159006160002, 'max_cycle': 11.0}
# indices: [6.0, 7, 9, 11.0]
# values: [0.05351159006160002, 0.051425947722658, 0.0510210021958806, 0.05148405341900146]
# {'t_values': [0.0764451286594286, 0.077138921583987, 0.0765315032938209, 0.0772260801285022], 'mean_t_sub': 0.07683540841643467, 'indices': [9.0, 11, 14, 17.0], 'difference': 0.0007809514690736014, 'difference_ratio': 0.010163952859350718, 'order': 5, 't_value_min': 0.0764451286594286, 't_value_max': 0.0772260801285022, 'max_cycle': 17.0}
# indices: [9.0, 11, 14, 17.0]
# values: [0.0764451286594286, 0.077138921583987, 0.0765315032938209, 0.0772260801285022]
#    note_name  t_values  cycle_or_t  winner_num
# 0         C3  0.015289         1.0           1
# 1        D#3  0.012856         1.0           1
# 2         G3  0.015306         2.0           1
# 3        A#3  0.012871         2.0           1
# 4         C3  0.030578         3.0           2
# 5        D#3  0.032141         4.0           2
# 6         G3  0.030613         5.0           2
# 7        A#3  0.030032         6.0           2
# 8         C3  0.045867         5.0           3
# 9        D#3  0.044998         6.0           3
# 10        G3  0.045919         8.0           3
# 11       A#3  0.047194        10.0           3
# 12        C3  0.053512         6.0           4
# 13       D#3  0.051426         7.0           4
# 14        G3  0.051021         9.0           4
# 15       A#3  0.051484        11.0           4
# 16        C3  0.076445         9.0           5
# 17       D#3  0.077139        11.0           5
# 18        G3  0.076532        14.0           5
# 19       A#3  0.077226        17.0           5

# %%
def create_chart_for_facet(observable_df, x='mean_t_sub',y='difference_ratio'):
    chart = alt.Chart(observable_df).mark_line().encode(
        x=alt.X(x, ),
        y=alt.Y(y, ),
        # color=alt.Color('difference_ratio', title='Difference Ratio'),
        tooltip=['t_values','mean_t_sub','std_normed','difference_ratio']
    ).properties(
        width=200,
        height=200
    )

    chart += alt.Chart(observable_df).mark_point().encode(
        x=alt.X(x, ),
        y=alt.Y(y, ),
        # color=alt.Color('difference_ratio', title='Difference Ratio'),
        tooltip=['t_values','mean_t_sub','std_normed','difference_ratio']
    ).properties(
        width=200,
        height=200
    )

    max_tsub = max(observable_df['mean_t_sub'])
    min_tsub = min(observable_df['mean_t_sub'])

    line_chart = alt.Chart(observable_df).mark_point().encode(
        y=alt.Y('difference_ratio'),
        color=alt.Color('mean_t_sub:Q', title='Mean Period', scale=alt.Scale(domain=[max_tsub, min_tsub])),
    )


    
    return (chart)

# %%
def create_facet_chart(note_name_mega_array,titles , fundamental_df, max_number_of_observable_metrics,max=50,x='mean_t_sub',y='difference_ratio'):
    for i, note_names in enumerate(note_name_mega_array):
        observable_df = generate_observable_df(note_names, fundamental_df, max_number_of_observable_metrics,max=max)
        observable_df['title'] = titles[i]
        observable_df['row']= i//3
        if i == 0:
            all_observable_df = observable_df
        else:
            all_observable_df = pd.concat([all_observable_df, observable_df], ignore_index=True)

    all_observable_df['title'] = all_observable_df['title'].astype('category')
    return create_chart_for_facet(all_observable_df,x=x,y=y).facet(
        'title', align='each', columns=3), all_observable_df

# %%
create_facet_chart(note_name_mega_array,titles , fundamental_df, max_number_of_observable_metrics=15,max=50)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 create_facet_chart(note_name_mega_array,titles , fundamental_df, max_number_of_observable_metrics=15,max=50)
#
# NameError: name 'note_name_mega_array' is not defined

# %%
##testing something on facet
## Using https://nikolasborrel.github.io/about/src/cremo/borrel_jensen_harmonization2009.pdf

chords_to_test = [
    ['C3','E3','G3'],
    ['C3','D#3','G3'],
    ['C3','F3','G3'],
    ['C3','D3','G3'],
    ['C3','D#3','F#3'],
    ['C3','E3','G#3'],
    

]
titles = [
    'C Major Triad',
    'C Minor Triad',
    
    'C Suspended 4th Triad',
    'C Suspended 2nd Triad',
    'C Diminished Triad',
    'C Augmented Triad',
]

fc,obs_df = create_facet_chart(chords_to_test,titles , fundamental_df, max_number_of_observable_metrics=5,max=50,x='mean_t_sub',y='difference_ratio')
fc
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\api.py:2004, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#    2001 # remaining to_dict calls are not at top level
#    2002 context["top_level"] = False
# -> 2004 vegalite_spec: Any = _top_schema_base(super(TopLevelMixin, copy)).to_dict(
#    2005     validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#    2006 )
#    2008 # TODO: following entries are added after validation. Should they be validated?
#    2009 if is_top_level:
#    2010     # since this is top-level we add $schema if it's missing
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:553, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
# --> 553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:554, in <dictcomp>(.0)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\api.py:2004, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#    2001 # remaining to_dict calls are not at top level
#    2002 context["top_level"] = False
# -> 2004 vegalite_spec: Any = _top_schema_base(super(TopLevelMixin, copy)).to_dict(
#    2005     validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#    2006 )
#    2008 # TODO: following entries are added after validation. Should they be validated?
#    2009 if is_top_level:
#    2010     # since this is top-level we add $schema if it's missing
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:553, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
# --> 553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:554, in <dictcomp>(.0)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:551, in _todict(obj, context, np_opt, pd_opt)
#     549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
# --> 551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:551, in <listcomp>(.0)
#     549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
# --> 551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\api.py:4033, in Chart.to_dict(self, validate, format, ignore, context)
#    4031     copy.data = core.InlineData(values=[{}])
#    4032     return super(Chart, copy).to_dict(**kwds)
# -> 4033 return super().to_dict(**kwds)
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\api.py:2004, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#    2001 # remaining to_dict calls are not at top level
#    2002 context["top_level"] = False
# -> 2004 vegalite_spec: Any = _top_schema_base(super(TopLevelMixin, copy)).to_dict(
#    2005     validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#    2006 )
#    2008 # TODO: following entries are added after validation. Should they be validated?
#    2009 if is_top_level:
#    2010     # since this is top-level we add $schema if it's missing
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:553, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
# --> 553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:554, in <dictcomp>(.0)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:553, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
# --> 553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:554, in <dictcomp>(.0)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:551, in _todict(obj, context, np_opt, pd_opt)
#     549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
# --> 551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:551, in <listcomp>(.0)
#     549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
# --> 551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\schema\channels.py:209, in FieldChannelMixin.to_dict(self, validate, ignore, context)
#     202 if isinstance(data, nw.DataFrame):
#     203     msg = (
#     204         f'Unable to determine data type for the field "{shorthand}";'
#     205         " verify that the field name is not misspelled."
#     206         " If you are referencing a field from a transform,"
#     207         " also confirm that the data type is specified correctly."
#     208     )
# --> 209     raise ValueError(msg)
#     210 else:
#     211     msg = (
#     212         f"{shorthand} encoding field is specified without a type; "
#     213         "the type cannot be automatically inferred because "
#     214         "the data is not specified as a pandas.DataFrame."
#     215     )
#
# ValueError: Unable to determine data type for the field "std_normed"; verify that the field name is not misspelled. If you are referencing a field from a transform, also confirm that the data type is specified correctly.
# alt.FacetChart(...)

# %% [markdown]
# ## Resolve bugs later, now make one by one graphs

# %%
chords_to_test = [
    ['C3','E3','G3'],
    ['C3','D#3','G3'],
    # ['C3','F3','G3'],
    # ['C3','D3','G3'],
    ['C3','D#3','F#3'],
    ['C3','E3','G#3'],
    ['C3','E3','G3','A#3'],
    ['C3','D#3','G3','A#3'],
    ['C3','E3','G3','B3'],
   
    

]
titles = [
    'C Major Triad',
    'C Minor Triad',
    
    # 'C Suspended 4th Triad',
    # 'C Suspended 2nd Triad',
    'C Diminished Triad',
    'C Augmented Triad',
    'C Dominant 7th Chord',
    'C Minor 7th Chord',
    'C Major 7th Chord',
]

# %%
max_number_of_observable_metrics=30
metric_sort_by = 'mean_t_sub'  # 'difference_ratio' or 'mean_t_sub'
for chord_index in range(len(chords_to_test)):
    chord = chords_to_test[chord_index]
    title = titles[chord_index]

    period_df = calculate_period_dataframe(chord, fundamental_df, max=50)
    bound_df = finding_min_difference_with_lower_upper_bound(period_df)
    bound_df.sort_values(by='ratio', ascending=True, inplace=True)
    each_pair = choosing_bounds_binary_search(period_df, bound_df)
    observable_metrics = []
    for item in each_pair:
        observable_metrics.append(item['observable_metrics'])
    sorted_observable_metrics = sorted(observable_metrics, key=lambda x: x[metric_sort_by])
    observable_df = pd.DataFrame(sorted_observable_metrics[:max_number_of_observable_metrics])
    observable_df.sort_values(by='mean_t_sub', inplace=True)

    ## adding 1,2,3, order values to sorted by mean
    observable_df['order'] = range(1, max_number_of_observable_metrics + 1)
    ## adding min t_value to observable_df,
    observable_df['t_value_min'] = [min(r['t_values']) for i, r in observable_df.iterrows()]
    observable_df['t_value_max'] = [max(r['t_values']) for i, r in observable_df.iterrows()]
    add_max_cycle(observable_df)

    # adding row and title

    if chord_index == 0:
        chart = create_chart_for_facet(observable_df, x='mean_t_sub', y='difference_ratio').properties(
            title=title,
            width=300,
            height=250
        )
    else:
        chart = (chart | create_chart_for_facet(observable_df, x='mean_t_sub', y='difference_ratio').properties(
            title=title,
            width=300,
            height=250
        )).resolve_scale(
            y='shared',
            x='shared'
        )
chart
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\api.py:2004, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#    2001 # remaining to_dict calls are not at top level
#    2002 context["top_level"] = False
# -> 2004 vegalite_spec: Any = _top_schema_base(super(TopLevelMixin, copy)).to_dict(
#    2005     validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#    2006 )
#    2008 # TODO: following entries are added after validation. Should they be validated?
#    2009 if is_top_level:
#    2010     # since this is top-level we add $schema if it's missing
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:553, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
# --> 553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:554, in <dictcomp>(.0)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:551, in _todict(obj, context, np_opt, pd_opt)
#     549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
# --> 551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:551, in <listcomp>(.0)
#     549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
# --> 551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\api.py:2004, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#    2001 # remaining to_dict calls are not at top level
#    2002 context["top_level"] = False
# -> 2004 vegalite_spec: Any = _top_schema_base(super(TopLevelMixin, copy)).to_dict(
#    2005     validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#    2006 )
#    2008 # TODO: following entries are added after validation. Should they be validated?
#    2009 if is_top_level:
#    2010     # since this is top-level we add $schema if it's missing
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:553, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
# --> 553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:554, in <dictcomp>(.0)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:551, in _todict(obj, context, np_opt, pd_opt)
#     549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
# --> 551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:551, in <listcomp>(.0)
#     549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
# --> 551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\api.py:4033, in Chart.to_dict(self, validate, format, ignore, context)
#    4031     copy.data = core.InlineData(values=[{}])
#    4032     return super(Chart, copy).to_dict(**kwds)
# -> 4033 return super().to_dict(**kwds)
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\api.py:2004, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#    2001 # remaining to_dict calls are not at top level
#    2002 context["top_level"] = False
# -> 2004 vegalite_spec: Any = _top_schema_base(super(TopLevelMixin, copy)).to_dict(
#    2005     validate=validate, ignore=ignore, context=dict(context, pre_transform=False)
#    2006 )
#    2008 # TODO: following entries are added after validation. Should they be validated?
#    2009 if is_top_level:
#    2010     # since this is top-level we add $schema if it's missing
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:553, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
# --> 553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:554, in <dictcomp>(.0)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:1163, in SchemaBase.to_dict(self, validate, ignore, context)
#    1161     msg = f"{type(self)} instance has both a value and properties : cannot serialize to dict"
#    1162     raise ValueError(msg)
# -> 1163 result = _todict(kwds, context=context, **opts)
#    1164 if validate:
#    1165     # NOTE: Don't raise `from err`, see `SchemaValidationError` doc
#    1166     try:
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:553, in _todict(obj, context, np_opt, pd_opt)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
# --> 553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:554, in <dictcomp>(.0)
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
# --> 554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#     558 elif isinstance(obj, SchemaLike):
#     559     return obj.to_dict()
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:551, in _todict(obj, context, np_opt, pd_opt)
#     549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
# --> 551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:551, in <listcomp>(.0)
#     549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
# --> 551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#     552 elif isinstance(obj, dict):
#     553     return {
#     554         k: _todict(v, context, np_opt, pd_opt)
#     555         for k, v in obj.items()
#     556         if v is not Undefined
#     557     }
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\utils\schemapi.py:549, in _todict(obj, context, np_opt, pd_opt)
#     547         return result
#     548 if isinstance(obj, SchemaBase):
# --> 549     return obj.to_dict(validate=False, context=context)
#     550 elif isinstance(obj, (list, tuple)):
#     551     return [_todict(v, context, np_opt, pd_opt) for v in obj]
#
# File c:\Users\gabri\AppData\Local\Programs\Python\Python311\Lib\site-packages\altair\vegalite\v5\schema\channels.py:209, in FieldChannelMixin.to_dict(self, validate, ignore, context)
#     202 if isinstance(data, nw.DataFrame):
#     203     msg = (
#     204         f'Unable to determine data type for the field "{shorthand}";'
#     205         " verify that the field name is not misspelled."
#     206         " If you are referencing a field from a transform,"
#     207         " also confirm that the data type is specified correctly."
#     208     )
# --> 209     raise ValueError(msg)
#     210 else:
#     211     msg = (
#     212         f"{shorthand} encoding field is specified without a type; "
#     213         "the type cannot be automatically inferred because "
#     214         "the data is not specified as a pandas.DataFrame."
#     215     )
#
# ValueError: Unable to determine data type for the field "std_normed"; verify that the field name is not misspelled. If you are referencing a field from a transform, also confirm that the data type is specified correctly.
# alt.HConcatChart(...)

# %% [markdown]
# #

# %% [markdown]
# # transitional overlay, de un ii V I

# %%
chords_to_test = [
    ['C3','E3','G3'],
    ['C3','D#3','G3'],
    # ['C3','F3','G3'],
    # ['C3','D3','G3'],
    ['C3','D#3','F#3'],
    ['C3','E3','G#3'],
    ['C3','E3','G3','A#3'],
    ['C3','D#3','G3','A#3'],
    ['C3','E3','G3','B3'],
   
    

]
titles = [
    'C Major Triad',
    'C Minor Triad',
    
    # 'C Suspended 4th Triad',
    # 'C Suspended 2nd Triad',
    'C Diminished Triad',
    'C Augmented Triad',
    'C Dominant 7th Chord',
    'C Minor 7th Chord',
    'C Major 7th Chord',
]

# %%
max_number_of_observable_metrics=20
metric_sort_by = 'mean_t_sub'  # 'difference_ratio' or 'mean_t_sub'
max_considered_periods = 100
for chord_index in range(len(chords_to_test)):
    chord = chords_to_test[chord_index]
    title = titles[chord_index]

    period_df = calculate_period_dataframe(chord, fundamental_df, max_considered_periods)
    bound_df = finding_min_difference_with_lower_upper_bound(period_df)
    bound_df.sort_values(by='ratio', ascending=True, inplace=True)
    each_pair = choosing_bounds_binary_search(period_df, bound_df)
    observable_metrics = []
    for item in each_pair:
        observable_metrics.append(item['observable_metrics'])
    sorted_observable_metrics = sorted(observable_metrics, key=lambda x: x[metric_sort_by])
    observable_df = pd.DataFrame(sorted_observable_metrics[:max_number_of_observable_metrics])
    observable_df.sort_values(by='mean_t_sub', inplace=True)

    ## adding 1,2,3, order values to sorted by mean
    observable_df['order'] = range(1, max_number_of_observable_metrics + 1)
    ## adding min t_value to observable_df,
    observable_df['t_value_min'] = [min(r['t_values']) for i, r in observable_df.iterrows()]
    observable_df['t_value_max'] = [max(r['t_values']) for i, r in observable_df.iterrows()]
    add_max_cycle(observable_df)

    # adding row and title

    if chord_index == 0:
        chart = create_chart_for_facet(observable_df, x='mean_t_sub', y='difference_ratio').properties(
            title=title,
            width=300,
            height=250
        )
    else:
        chart_overlay1 = (chart + create_chart_for_facet(observable_df, x='mean_t_sub', y='difference_ratio').properties(
            title=title,
            width=300,
            height=250,
            color='red'
        )).resolve_scale(
            y='shared',
            x='shared'
        )
        
chart
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 29
#      26 # adding row and title
#      28 if chord_index == 0:
# ---> 29     chart = create_chart_for_facet(observable_df, x='mean_t_sub', y='difference_ratio').properties(
#      30         title=title,
#      31         width=300,
#      32         height=250
#      33     )
#      34 else:
#      35     chart_overlay1 = (chart + create_chart_for_facet(observable_df, x='mean_t_sub', y='difference_ratio').properties(
#      36         title=title,
#      37         width=300,
#    (...)     42         x='shared'
#      43     )
#
# NameError: name 'create_chart_for_facet' is not defined

# %%
chords_to_test = [
    ['C3','E3','G3'],
    ['C3','D#3','G3'],
    # ['C3','F3','G3'],
    # ['C3','D3','G3'],
    ['C3','D#3','F#3'],
    ['C3','E3','G#3'],
    ['C3','E3','G3','A#3'],
    ['C3','D#3','G3','A#3'],
    ['C3','E3','G3','B3'],
   
    

]
titles = [
    'C Major Triad',
    'C Minor Triad',
    
    # 'C Suspended 4th Triad',
    # 'C Suspended 2nd Triad',
    'C Diminished Triad',
    'C Augmented Triad',
    'C Dominant 7th Chord',
    'C Minor 7th Chord',
    'C Major 7th Chord',
]

# %%
chords_to_test = [
    ['C3','E3','G3'],
    ['C3','D#3','G3'],
    ['C3','F3','G3'],
    ['C3','D3','G3'],
    ['C3','D#3','F#3'],
    ['C3','E3','G#3'],
    

]
titles = [
    'C Major Triad',
    'C Minor Triad',
    
    'C Suspended 4th Triad',
    'C Suspended 2nd Triad',
    'C Diminished Triad',
    'C Augmented Triad',
]

# %%
max_tsub = max(observable_df['mean_t_sub'])
min_tsub = min(observable_df['mean_t_sub'])

alt.Chart(observable_df).mark_point().encode(
    y=alt.Y('difference_ratio'),
    color=alt.Color('mean_t_sub:Q', title='Mean Period', scale=alt.Scale(domain=[max_tsub, min_tsub])),
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Proof that statioary is replicable

# %%
mega_chord_array = [
    ['D3', 'A3','D4','A4','D5','F#5'],
    ['A2','E3','A3','A4','C#5','E5'],
    ['B2','F#3','B3','F#4','B4','D5'],
    ['F#2','C#3','F#3','F#4','A4','C#5'],
    ['G2','D3','G3','D4','G4','B4'],
    ['D3','A3','D4','F#4','A4'],
    ['E3','B3','E4','G4','B4'],
    ['A2','E3','A3','E4','A4','C#5']
]

chord_labels = [
    'D major',
    'A major',
    'B minor',
    'F# minor',
    'G major',
    'D major',
    'E minor',
    'A major'

]

# %%
metric_to_sort_by_up_to='mean_t_sub'  # 'difference_ratio' or 'mean_t_sub'
# max_number_of_observable_metrics = 
max_considered_periods = 20


def get_min_max_t_values_for_each_row(df):

    df['min_t_value'] = df['t_values'].apply(lambda x: min(x)) - 0.0005
    df['max_t_value'] = df['t_values'].apply(lambda x: max(x)) + 0.0005
    return df 


new_new_pdf = pd.DataFrame()
new_df = pd.DataFrame()

for i in range(len(mega_chord_array)):
    note_names = mega_chord_array[i]
    chord_label = chord_labels[i]
    period_df = calculate_period_dataframe(note_names,fundamental_df,max=max_considered_periods)
    bound_df = finding_min_difference_with_lower_upper_bound(period_df)
    bound_df.sort_values(by='ratio', ascending=True, inplace=True)
    each_pair = choosing_bounds_binary_search(period_df,bound_df)
    observable_metrics=[]
    for item in each_pair:
        observable_metrics.append(item['observable_metrics'])

    ## first sort the top n alignments, then choose the most aligned
    sorted_observable_metrics = sorted(observable_metrics, key=lambda x: x[metric_to_sort_by_up_to])


    # df = sorted_observable_metrics[:max_number_of_observable_metrics]
    df = sorted_observable_metrics
    df= pd.DataFrame(sorted(df, key=lambda x: x['difference_ratio']))
    period_df.columns = [f'{i}_note' for i in range(1,len(period_df.columns)+1)]

    new_pdf = pd.melt(period_df, ignore_index=False).reset_index().rename(columns={'index': 'cycle_or_t', 'variable': 'note_name', 'value': 't_values'})
    new_pdf['chord_start'] = chord_label
    new_pdf['chord_number'] = i + 1
    
    new_pdf['chord_num_end'] = i+2
    new_pdf['chord_end']= chord_label +str(2)

    # new_pdf['chord_label'] = chord_label
    new_new_pdf= pd.concat([new_new_pdf, new_pdf], ignore_index=True)

    
    main_chart = (alt.Chart(new_pdf).mark_point(
                clip=True,
                opacity=0.6,
                filled=True,
                strokeWidth=2,
                # background='black',
            ).encode(
                y=alt.Y('t_values', title='T_sub', scale=alt.Scale(domain=[0.05, 0], nice=True)),
                x=alt.X('chord_start:N',),
                color=alt.Color('note_name', title='Note Name', scale=alt.Scale(domain=note_names, range=['purple','blue','green','yellow','orange','red'])),
            ) + alt.Chart(new_pdf).mark_line(
                opacity=0.5,
                strokeWidth=2,
                clip=True).encode(
                    y=alt.Y('t_values'),
                    # ='t_values',
                    x=alt.X('chord_start:N', ),
                    x2=alt.X2('chord_end:N', ),
                    color=alt.Color('note_name', title='Note Name', scale=alt.Scale(domain=note_names, range=['purple','blue','green','yellow','orange','red'])),
                ))
    
    df = get_min_max_t_values_for_each_row(df)
    df['chord_start'] = chord_label
    df['chord_number']= i+1
    df['chord_num_end'] = i+2
    df['chord_end'] = chord_label + str(2)
    
    df= df[:2]
    new_df = pd.concat([new_df, df], ignore_index=True)

    chart = alt.Chart(df).mark_rect(
        clip=True,
        fill='null',
        stroke='white',
        strokeWidth=2).encode(
            x=alt.X('chord_start:N', ),
            x2=alt.X2('chord_end:N', ),
            y=alt.Y('min_t_value:Q', scale=alt.Scale(domain=[0.05,0], nice=True)),
            y2=alt.Y2('max_t_value:Q', ),
        )
    chart = chart + alt.Chart(df).mark_text(
        color='white',
        align='right',
        baseline='top',
        fontSize=12,
    ).encode(
        x=alt.X('chord_start:N', title= chord_label),
        y=alt.Y('min_t_value:Q', scale=alt.Scale(domain=[0.05, 0], nice=True)),
        text=alt.Text('difference:Q', format='.3s'),
        # color=alt.Color('note_name:N', title='Note Name', scale=alt.Scale(domain=note_names, range=['purple','blue','green','yellow','orange','red'])),
    )
    concat = (chart + main_chart).properties(
        width=130,height=300)
    if i == 0:
        final_chart = concat
    else:
        final_chart = final_chart | concat
final_chart.configure_view(fill='black').configure_axisX(title='D', labels=False, ticks=False).configure_axisY().resolve_scale(
    y='shared',)
# Out:
# alt.HConcatChart(...)

# %%
new_new_pdf
# Out:
#      cycle_or_t note_name  t_values chord_start  chord_number  chord_num_end  \
# 0             1    1_note  0.006810     D major             1              2
# 1             2    1_note  0.013621     D major             1              2
# 2             3    1_note  0.020431     D major             1              2
# 3             4    1_note  0.027242     D major             1              2
# 4             5    1_note  0.034052     D major             1              2
# ..          ...       ...       ...         ...           ...            ...
# 869          15    6_note  0.027058     A major             8              9
# 870          16    6_note  0.028862     A major             8              9
# 871          17    6_note  0.030666     A major             8              9
# 872          18    6_note  0.032470     A major             8              9
# 873          19    6_note  0.034273     A major             8              9
#
#     chord_end
# 0    D major2
# 1    D major2
# 2    D major2
# 3    D major2
# 4    D major2
# ..        ...
# 869  A major2
# 870  A major2
# 871  A major2
# 872  A major2
# 873  A major2
#
# [874 rows x 7 columns]

# %%
new_new_pdf = new_new_pdf[new_new_pdf['chord_number']!=1]
main_chart = (alt.Chart(new_new_pdf).mark_point(
                clip=True,
                opacity=0.6,
                filled=True,
                strokeWidth=2,
                # background='black',
            ).encode(
                y=alt.Y('t_values', title='T_sub', scale=alt.Scale(domain=[0.05, 0], nice=True)),
                x=alt.X('chord_number:N',),
                color=alt.Color('note_name', title='Note Name', scale=alt.Scale( range=['purple','blue','green','yellow','orange','red'])),
            ) + alt.Chart(new_new_pdf).mark_line(
                opacity=0.5,
                strokeWidth=2,
                clip=True).encode(
                    y=alt.Y('t_values'),
                    # ='t_values',
                    x=alt.X('chord_number:N', ),
                    x2=alt.X2('chord_num_end:N',  ),
                    color=alt.Color('note_name', title='Note Name', scale=alt.Scale( range=['purple','blue','green','yellow','orange','red'])),
                ))
    
main_chart
# Out:
# alt.LayerChart(...)

# %%
# df = get_min_max_t_values_for_each_row(df)
# df['chord_start'] = chord_label
# df['chord_end'] = chord_label + str(2)
    
# df= df[:2]
new_df = new_df[new_df['chord_number']!=1]
chart = alt.Chart(new_df).mark_rect(
        clip=True,
        fill='transparent',
        stroke='white',
        strokeWidth=2).encode(
            x=alt.X('chord_number:N', ),
            x2=alt.X2('chord_num_end:N', ),
            y=alt.Y('min_t_value:Q', scale=alt.Scale(domain=[0.05,0], nice=True)),
            y2=alt.Y2('max_t_value:Q', ),
        )
chart = chart + alt.Chart(new_df).mark_text(
        color='white',
        align='right',
        baseline='top',
        fontSize=12,
        # fill='null'
    ).encode(
        x=alt.X('chord_number:N',  ),
        y=alt.Y('min_t_value:Q', scale=alt.Scale(domain=[0.05, 0], nice=True)),
        # column=alt.Column('chord_start:N'),
        text=alt.Text('difference:Q', format='.3s'),
        # color=alt.Color('note_name:N', title='Note Name', scale=alt.Scale(domain=note_names, range=['purple','blue','green','yellow','orange','red'])),
    )



concat = (  main_chart+ chart).properties(
        width=700,height=500).configure_view(fill='black')
#         final_chart = concat
#     else:
#         final_chart = final_chart | concat
# final_chart.configure_view(fill='black').configure_axisX(title='D', labels=False, ticks=False).configure_axisY().resolve_scale(
#     y='shared',)
concat
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Ok plan, to repliicate, for each note, we are going to plot the vertical axis using the note period, and with this observable metric we are going to overlay the bar

# %%
period_df.columns = [f'{i}_note' for i in range(1,len(period_df.columns)+1)]
period_df
# Out:
#       1_note    2_note    3_note    4_note    5_note    6_note
# 1   0.009091  0.006067  0.004545  0.003034  0.002273  0.001804
# 2   0.018182  0.012135  0.009091  0.006067  0.004545  0.003608
# 3   0.027273  0.018202  0.013636  0.009101  0.006818  0.005412
# 4   0.036364  0.024270  0.018182  0.012135  0.009091  0.007215
# 5   0.045455  0.030337  0.022727  0.015169  0.011364  0.009019
# 6   0.054545  0.036405  0.027273  0.018202  0.013636  0.010823
# 7   0.063636  0.042472  0.031818  0.021236  0.015909  0.012627
# 8   0.072727  0.048540  0.036364  0.024270  0.018182  0.014431
# 9   0.081818  0.054607  0.040909  0.027304  0.020455  0.016235
# 10  0.090909  0.060675  0.045455  0.030337  0.022727  0.018039
# 11  0.100000  0.066742  0.050000  0.033371  0.025000  0.019843
# 12  0.109091  0.072809  0.054545  0.036405  0.027273  0.021646
# 13  0.118182  0.078877  0.059091  0.039438  0.029545  0.023450
# 14  0.127273  0.084944  0.063636  0.042472  0.031818  0.025254
# 15  0.136364  0.091012  0.068182  0.045506  0.034091  0.027058
# 16  0.145455  0.097079  0.072727  0.048540  0.036364  0.028862
# 17  0.154545  0.103147  0.077273  0.051573  0.038636  0.030666
# 18  0.163636  0.109214  0.081818  0.054607  0.040909  0.032470
# 19  0.172727  0.115282  0.086364  0.057641  0.043182  0.034273

# %%
new_pdf = pd.melt(period_df, ignore_index=False).reset_index().rename(columns={'index': 'cycle_or_t', 'variable': 'note_name', 'value': 't_values'})
new_pdf
# new_pdf=new_pdf[new_pdf['note_name']=='D3']
# Out:
#      cycle_or_t note_name  t_values
# 0             1    1_note  0.009091
# 1             2    1_note  0.018182
# 2             3    1_note  0.027273
# 3             4    1_note  0.036364
# 4             5    1_note  0.045455
# ..          ...       ...       ...
# 109          15    6_note  0.027058
# 110          16    6_note  0.028862
# 111          17    6_note  0.030666
# 112          18    6_note  0.032470
# 113          19    6_note  0.034273
#
# [114 rows x 3 columns]

# %%
new_pdf['chord_start'] = chord_label
new_pdf['chord_end']= chord_label +str(2)
main_chart = (alt.Chart(new_pdf).mark_point(
            clip=True,
            opacity=0.6,
            filled=True,
            strokeWidth=2,
            # background='black',
        ).encode(
            y=alt.Y('t_values', title='T_sub', scale=alt.Scale(domain=[0, 0.05], nice=True)),
            x=alt.X('chord_start:N',),
            color=alt.Color('note_name', title='Note Name', scale=alt.Scale(domain=note_names, range=['purple','blue','green','yellow','orange','red'])),
        ) + alt.Chart(new_pdf).mark_line(
            opacity=0.5,
            strokeWidth=2,
            clip=True).encode(
                y=alt.Y('t_values'),
                # ='t_values',
                x=alt.X('chord_start:N', ),
                x2=alt.X2('chord_end:N', ),
                color=alt.Color('note_name', title='Note Name', scale=alt.Scale(domain=note_names, range=['purple','blue','green','yellow','orange','red'])),
            ))
main_chart
# Out:
# alt.LayerChart(...)

# %%
def get_min_max_t_values_for_each_row(df):

    df['min_t_value'] = df['t_values'].apply(lambda x: min(x)) - 0.0005
    df['max_t_value'] = df['t_values'].apply(lambda x: max(x)) + 0.0005
    return df
df = get_min_max_t_values_for_each_row(df)
df['chord_start'] = chord_label
df['chord_end'] = chord_label + str(2)

# %%
df
# Out:
#                                             t_values  mean_t_sub  \
# 0  [0.01818181818181818, 0.018202361647773196, 0....    0.018165
# 1  [0.03636363636363636, 0.03640472329554639, 0.0...    0.036029
#
#                      indices  difference  difference_ratio  min_t_value  \
# 0     [1.0, 2, 3, 5, 7, 9.0]    0.000164          0.009013     0.017539
# 1  [3.0, 5, 7, 11, 15, 18.0]    0.002131          0.059155     0.033773
#
#    max_t_value chord_start  chord_number  chord_num_end chord_end
# 0     0.018702     A major             8              9  A major2
# 1     0.036905     A major             8              9  A major2

# %%
df= df[:2]

chart = alt.Chart(df).mark_rect(
    clip=True,
    fill='null',
    stroke='white',
    strokeWidth=2).encode(
        x=alt.X('chord_start:N', ),
        x2=alt.X2('chord_end:N', ),
        y=alt.Y('min_t_value:Q', scale=alt.Scale(domain=[0, 0.05], nice=True)),
        y2=alt.Y2('max_t_value:Q', ),
    )
chart = chart + alt.Chart(df).mark_text(
    color='white',
    align='right',
    baseline='top',
    fontSize=12,
).encode(
    x=alt.X('chord_start:N', title= 'D Major'),
    y=alt.Y('min_t_value:Q', scale=alt.Scale(domain=[0, 0.05], nice=True)),
    text=alt.Text('difference:Q', format='.3s'),
    # color=alt.Color('note_name:N', title='Note Name', scale=alt.Scale(domain=note_names, range=['purple','blue','green','yellow','orange','red'])),
)
(chart + main_chart).properties(height=500,width=200).configure_view(fill='black').configure_axisX(title='D', labels=False, ticks=False)
# Out:
# alt.LayerChart(...)

# %%
metric_to_sort_by_up_to='mean_t_sub'  # 'difference_ratio' or 'mean_t_sub'
# max_number_of_observable_metrics = 
max_considered_periods = 20
top_n_alignments = 3

def get_min_max_t_values_for_each_row(df):

    df['min_t_value'] = df['t_values'].apply(lambda x: min(x)) - 0.0005
    df['max_t_value'] = df['t_values'].apply(lambda x: max(x)) + 0.0005
    return df


def make_white_line_chart(df, chord_label,note_names, top_n_alignments):
    df = get_min_max_t_values_for_each_row(df)
    df['chord_start'] = chord_label
    df['chord_end'] = chord_label + str(2)
    df= df[:top_n_alignments]

    chart = alt.Chart(df).mark_rect(
        clip=True,
        fill='null',
        stroke='white',
        strokeWidth=2).encode(
            x=alt.X('chord_start:N', ),
            x2=alt.X2('chord_end:N', ),
            y=alt.Y('min_t_value:Q', scale=alt.Scale(domain=[0, 0.05], nice=True)),
            y2=alt.Y2('max_t_value:Q', ),
        )
    chart = chart + alt.Chart(df).mark_text(
        color='white',
        align='right',
        baseline='top',
        fontSize=12,
    ).encode(
        x=alt.X('chord_start:N', title= chord_label),
        y=alt.Y('min_t_value:Q', scale=alt.Scale(domain=[0, 0.05], nice=True)),
        text=alt.Text('difference:Q', format='.3s'),
        # color=alt.Color('note_name:N', title='Note Name', scale=alt.Scale(domain=note_names, range=['purple','blue','green','yellow','orange','red'])),
    )
    return chart

def make_point_chart_periods(period_df, chord_label, note_names):
        
    new_pdf = pd.melt(period_df, ignore_index=False).reset_index().rename(columns={'index': 'cycle_or_t', 'variable': 'note_name', 'value': 't_values'})
    new_pdf

    new_pdf['chord_start'] = chord_label
    new_pdf['chord_end']= chord_label +str(2)
    main_chart = (alt.Chart(new_pdf).mark_point(
                clip=True,
                opacity=0.6,
                filled=True,
                strokeWidth=2,
                # background='black',
            ).encode(
                y=alt.Y('t_values', title='T_sub', scale=alt.Scale(domain=[0, 0.05], nice=True)),
                x=alt.X('chord_start:N',),
                color=alt.Color('note_name', title='Note Name', scale=alt.Scale(domain=note_names, range=['purple','blue','green','yellow','orange','red'])),
            ) + alt.Chart(new_pdf).mark_line(
                opacity=0.5,
                strokeWidth=2,
                clip=True).encode(
                    y=alt.Y('t_values'),
                    # ='t_values',
                    x=alt.X('chord_start:N', ),
                    x2=alt.X2('chord_end:N', ),
                    color=alt.Color('note_name', title='Note Name', scale=alt.Scale(domain=note_names, range=['purple','blue','green','yellow','orange','red'])),
                ))
    return main_chart



def return_chart_for_n_chords(chord_array,chord_labels, fundamental_df ,metric_to_sort_by_up_to='mean_t_sub',
                              top_n_alignments=2,max_considered_periods=20):

    for i in range(len(chord_array)):
        
        note_names = mega_chord_array[i]
        chord_label = chord_labels[i]
        period_df = calculate_period_dataframe(note_names,fundamental_df,max=max_considered_periods)
        bound_df = finding_min_difference_with_lower_upper_bound(period_df)
        bound_df.sort_values(by='ratio', ascending=True, inplace=True)
        each_pair = choosing_bounds_binary_search(period_df,bound_df)
        observable_metrics=[]
        for item in each_pair:
            observable_metrics.append(item['observable_metrics'])

        ## first sort the top n alignments, then choose the most aligned
        sorted_observable_metrics = sorted(observable_metrics, key=lambda x: x[metric_to_sort_by_up_to])


        # df = sorted_observable_metrics[:max_number_of_observable_metrics]
        df = sorted_observable_metrics
        df= pd.DataFrame(sorted(df, key=lambda x: x['difference_ratio']))

        main_chart = make_point_chart_periods(period_df, chord_label, note_names)
        white_line_chart = make_white_line_chart(df, chord_label, note_names, top_n_alignments)
        if i == 0:
            chart = (white_line_chart + main_chart).properties(
                title=chord_label,
                width=200,
                height=500
            )
        else:
            chart = (chart | (white_line_chart + main_chart).properties(
                title=chord_label,
                width=200,
                height=500
            )).resolve_scale(
                y='shared').configure_view(
                    fill='black'
                ).configure_axisX( labels=False, ticks=False)
    return chart


chart = return_chart_for_n_chords(mega_chord_array,chord_labels, fundamental_df ,metric_to_sort_by_up_to=metric_to_sort_by_up_to,
                              top_n_alignments=top_n_alignments,max_considered_periods=max_considered_periods)
chart
# Out:
# alt.HConcatChart(...)

# %%
### Recta numérica

# %%
mega_chord_array = [
    ['C3','C4'],
    ['C3','G3'],
    ['C3','E3'],
    ['C3', 'E3','G3'],
    ['C3', 'D#3'],
    ['C3', 'D#3','G3'],
    ['C3','E3','G#3'],
    ['C3', 'G#3' ],
    ['C3','D#3','F#3'],
    ['C3','E3','F#3'],
    ['C3','D3','G3'],
     ['C3','D3'],

]


chord_labels = [
    'Unison',
    'Fifth',
    'Major Third',
    'Major Triad',
    'Minor Third',
    'Minor Triad',
    'Augmented Fifth Triad',
    'Minor Sixth',
    'Diminished Fifth',
    'Flat Fifth Triad',
    'Suspended 2nd Triad',
    'Major 2nd',
]

# %%
metric_to_sort_by_up_to='difference_ratio'  # 'difference_ratio' or 'mean_t_sub'
max_considered_periods = 20

joined_df = pd.DataFrame()
def get_normalized_t_values(df,top_n_alignments=1):


    top_values = df[:top_n_alignments]
    norm_t_values =[]

    for i, row in top_values.iterrows():
        new_row ={}
        new_row['difference'] = abs(row['difference'])
        new_row['mean_t_sub'] = row['mean_t_sub']
        new_row['difference_ratio'] = abs(row['difference']/ row['mean_t_sub'])
        if( new_row['difference_ratio'] == 0):
            new_row['1_over_ratio'] = 0
        else: 
            new_row['1_over_ratio'] = 1/new_row['difference_ratio']
        norm_t_values.append(new_row) 

    return norm_t_values




for i in range(len(mega_chord_array)):

    note_names = mega_chord_array[i]
    chord_label = chord_labels[i]
    period_df = calculate_period_dataframe(note_names,fundamental_df,max=max_considered_periods)
    bound_df = finding_min_difference_with_lower_upper_bound(period_df)

    bound_df.sort_values(by='ratio', ascending=True, inplace=True)
    each_pair = choosing_bounds_binary_search(period_df,bound_df)
    observable_metrics=[]
    for item in each_pair:
        observable_metrics.append(item['observable_metrics'])
    ## first sort the top n alignments, then choose the most aligned
    sorted_observable_metrics = sorted(observable_metrics, key=lambda x: x[metric_to_sort_by_up_to])
    # df = sorted_observable_metrics[:max_number_of_observable_metrics]
    df = sorted_observable_metrics
    df= pd.DataFrame(sorted(df, key=lambda x: x['difference_ratio']))
    new_df = get_normalized_t_values(df,top_n_alignments=1)
    new_df = pd.DataFrame(new_df)
    new_df['chord_label']= chord_label
    joined_df = pd.concat([joined_df, new_df], ignore_index=True)

joined_df.sort_values(by='1_over_ratio', ascending=False, inplace=True)
joined_df
# Out:
#     difference  mean_t_sub  difference_ratio  1_over_ratio  \
# 1     0.000052    0.045893          0.001129    885.541415
# 4     0.000176    0.122224          0.001437    696.118045
# 11    0.000138    0.061225          0.002259    442.770849
# 10    0.000138    0.061225          0.002259    442.770755
# 7     0.000235    0.091617          0.002566    389.743572
# 2     0.000614    0.114975          0.005340    187.276257
# 6     0.000722    0.091415          0.007902    126.552922
# 3     0.000275    0.030509          0.009025    110.809198
# 5     0.000694    0.076705          0.009045    110.559191
# 9     0.000881    0.091546          0.009629    103.856665
# 8     0.000731    0.038210          0.019132     52.267299
# 0     0.000000    0.007645          0.000000      0.000000
#
#               chord_label
# 1                   Fifth
# 4             Minor Third
# 11              Major 2nd
# 10    Suspended 2nd Triad
# 7             Minor Sixth
# 2             Major Third
# 6   Augmented Fifth Triad
# 3             Major Triad
# 5             Minor Triad
# 9        Flat Fifth Triad
# 8        Diminished Fifth
# 0                  Unison

# %%
point = alt.Chart(joined_df).mark_point().encode(
    x=alt.X('difference_ratio:Q', title='Ratio'),)

line= alt.Chart(joined_df).mark_line(
        color='black'
    ).encode(
    x=alt.X('difference_ratio:Q', title='Ratio',))
(point+line).properties(width=500)
# Out:
# alt.LayerChart(...)

# %%
text = alt.Chart(joined_df).mark_text(
        align='right',
        baseline='middle',
        dy=-10,
        # dx=alt.expr(),
        fontSize=12,
        color='black',
        angle=45
    ).encode(
        x=alt.X('difference_ratio:Q', title='Ratio',),

        text=alt.Text('chord_label:N', )
    )

chart = (point + line + text).properties(width=700).configure_axisX(ticks=False).configure_axis(grid=False).configure_view(stroke=None)
chart
# Out:
# alt.LayerChart(...)

# %%
note_names = mega_chord_array[1]
chord_label = chord_labels[1]
period_df = calculate_period_dataframe(note_names,fundamental_df,max=max_considered_periods)
bound_df = finding_min_difference_with_lower_upper_bound(period_df)

bound_df.sort_values(by='ratio', ascending=True, inplace=True)
each_pair = choosing_bounds_binary_search(period_df,bound_df)
observable_metrics=[]
for item in each_pair:
    observable_metrics.append(item['observable_metrics'])
## first sort the top n alignments, then choose the most aligned
sorted_observable_metrics = sorted(observable_metrics, key=lambda x: x[metric_to_sort_by_up_to])
# df = sorted_observable_metrics[:max_number_of_observable_metrics]
df = sorted_observable_metrics
df= pd.DataFrame(sorted(df, key=lambda x: x['difference_ratio']))
df['1_over_ratio'] = 1/df['difference_ratio']
df
# Out:
#                                        t_values  mean_t_sub       indices  \
# 0    [0.04586707719565716, 0.04591890197629254]    0.045893    [5.0, 8.0]
# 1    [0.09173415439131433, 0.09183780395258508]    0.091786  [11.0, 17.0]
# 2   [0.01528902573188572, 0.015306300658764179]    0.015298    [1.0, 2.0]
# 3   [0.03057805146377144, 0.030612601317528357]    0.030595    [3.0, 5.0]
# 4   [0.06115610292754288, 0.061225202635056715]    0.061191   [7.0, 11.0]
# 5      [0.0764451286594286, 0.0765315032938209]    0.076488   [9.0, 14.0]
# 6    [0.09937866725725718, 0.09693990417217313]    0.098159  [12.0, 18.0]
# 7    [0.08408964152537146, 0.08163360351340895]    0.082862  [10.0, 15.0]
# 8    [0.08408964152537146, 0.08673570373299701]    0.085413  [10.0, 16.0]
# 9    [0.06880061579348574, 0.06632730285464478]    0.067564   [8.0, 12.0]
# 10   [0.06880061579348574, 0.07142940307423283]    0.070115   [8.0, 13.0]
# 11  [0.05351159006160002, 0.056123102415468654]    0.054817   [6.0, 10.0]
# 12    [0.05351159006160002, 0.0510210021958806]    0.052266    [6.0, 9.0]
# 13   [0.09173415439131433, 0.08673570373299701]    0.089235  [11.0, 16.0]
# 14    [0.0382225643297143, 0.04081680175670448]    0.039520    [4.0, 7.0]
# 15    [0.0764451286594286, 0.07142940307423283]    0.073937   [9.0, 13.0]
# 16   [0.0382225643297143, 0.035714701537116415]    0.036969    [4.0, 6.0]
# 17   [0.09937866725725718, 0.09183780395258508]    0.095608  [12.0, 17.0]
# 18  [0.06115610292754288, 0.056123102415468654]    0.058640   [7.0, 10.0]
# 19    [0.08408964152537146, 0.0765315032938209]    0.080311  [10.0, 14.0]
# 20    [0.02293353859782858, 0.0255105010979403]    0.024222    [2.0, 4.0]
# 21  [0.06880061579348574, 0.061225202635056715]    0.065013   [8.0, 11.0]
# 22   [0.02293353859782858, 0.02040840087835224]    0.021671    [2.0, 3.0]
# 23   [0.04586707719565716, 0.04081680175670448]    0.043342    [5.0, 7.0]
# 24   [0.05351159006160002, 0.04591890197629254]    0.049715    [6.0, 8.0]
# 25    [0.03057805146377144, 0.0255105010979403]    0.028044    [3.0, 4.0]
# 26   [0.0382225643297143, 0.030612601317528357]    0.034418    [4.0, 5.0]
# 27   [0.00764451286594286, 0.01020420043917612]    0.008924    [0.0, 1.0]
# 28   [0.00764451286594286, 0.00510210021958806]    0.006373    [0.0, 0.0]
# 29   [0.01528902573188572, 0.01020420043917612]    0.012747    [1.0, 1.0]
# 30  [0.02293353859782858, 0.015306300658764179]    0.019120    [2.0, 2.0]
#
#     difference  difference_ratio  1_over_ratio
# 0     0.000052          0.001129    885.541415
# 1     0.000104          0.001129    885.541415
# 2     0.000017          0.001129    885.541415
# 3     0.000035          0.001129    885.541415
# 4     0.000069          0.001129    885.541415
# 5     0.000086          0.001129    885.541415
# 6     0.002439          0.024845     40.249619
# 7     0.002456          0.029640     33.737923
# 8     0.002646          0.030980     32.279163
# 9     0.002473          0.036607     27.317190
# 10    0.002629          0.037493     26.671998
# 11    0.002612          0.047640     20.990652
# 12    0.002491          0.047652     20.985526
# 13    0.004998          0.056015     17.852518
# 14    0.002594          0.065644     15.233642
# 15    0.005016          0.067838     14.741091
# 16    0.002508          0.067838     14.741091
# 17    0.007541          0.078873     12.678686
# 18    0.005033          0.085829     11.651023
# 19    0.007558          0.094111     10.625708
# 20    0.002577          0.106389      9.399446
# 21    0.007575          0.116522      8.582094
# 22    0.002525          0.116522      8.582094
# 23    0.005050          0.116522      8.582094
# 24    0.007593          0.152724      6.547779
# 25    0.005068          0.180698      5.534089
# 26    0.007610          0.221107      4.522700
# 27    0.002560          0.286820      3.486502
# 28    0.002542          0.398916      2.506795
# 29    0.005085          0.398916      2.506795
# 30    0.007627          0.398916      2.506795

# %%
def get_normalized_t_values(df,top_n_alignments=1):


    top_values = df[:top_n_alignments]
    norm_t_values =[]

    for i, row in top_values.iterrows():
        new_row ={}
        new_row['difference'] = row['difference']
        new_row['mean_t_sub'] = row['mean_t_sub']
        new_row['difference_ratio'] = row['difference']/ row['mean_t_sub']
        if( new_row['difference_ratio'] == 0):
            new_row['1_over_ratio'] = 0
        else: 
            new_row['1_over_ratio'] = 1/new_row['difference_ratio']
        norm_t_values.append(new_row) 

    return norm_t_values

# %%
new_df
# Out:
# [{'difference': 0.0,
#   'mean_t_sub': 0.00764451286594286,
#   'difference_ratio': 0.0,
#   '1_over_ratio': 0},
#  {'difference': 0.0,
#   'mean_t_sub': 0.01528902573188572,
#   'difference_ratio': 0.0,
#   '1_over_ratio': 0}]
