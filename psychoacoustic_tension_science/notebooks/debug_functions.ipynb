# %%
import psychoacoustic_tension_chan_module.interharmonic_module as ihm

# %%
note= ['G2','B2']
note_df = ihm.create_harmonic_dataframe(10)
ihm.generalized_chan_method_calculation(note_array_to_compute=note,note_df=note_df,
                                        apply_weights_to_harmonics=False,
                                        limit_delta_frequency=False,
                                        frequency_threshold=170,
                                        include_lower_bound=False)
# Out:
# [[2, 8]]

# %%
note_array_comb=[note,['G3', 'B3'], ['G4', 'B4']]
note_array_comb
# Out:
# [['G2', 'B2'], ['G3', 'B3'], ['G4', 'B4']]

# %%
ihm.normalized_interharmonic_modulations_pipeline(note_combinations_array=note_array_comb,chord_labels_array=['M3', 'M3', 'M3'],harmonics_considered=10)
# Out:
# array_of_modulations_per_region [[2, 8]]
# array_of_modulations_per_region [[2, 8]]
# array_of_modulations_per_region [[2, 8]]
#   note_combination chord_label raw_values_per_combination  \
# 0            G2,B2          M3                     [2, 8]
# 1            G3,B3          M3                     [2, 8]
# 2            G4,B4          M3                     [2, 8]
#
#   weighted_modulations_per_region_in_note_combinations  \
# 0                                               None
# 1                                               None
# 2                                               None
#
#   weighted_sum_per_region_normalized_tension_value  \
# 0                                             None
# 1                                             None
# 2                                             None
#
#    raw_t_score_summed_only_modulations  \
# 0                                   10
# 1                                   10
# 2                                   10
#
# ...

# %%
from scipy.stats import pearsonr

# %%
a = [1,2,3,4,5,6,7,8,9]
b = [9,7.5,6,8,4,4,2,1.5,1]
pearsonr(a,b)
# Out:
# PearsonRResult(statistic=-0.9495482650926292, pvalue=9.038707733312704e-05)
